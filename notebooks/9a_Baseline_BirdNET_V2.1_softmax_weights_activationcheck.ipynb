# %% [markdown]
# ## load model before Quantization

# %%
# %load_ext autoreload
# %autoreload 2

import tensorflow as tf
from tensorflow import keras
from tensorflow.keras.models import Model as Kerasmodel

# load saved Baseline_BirdNET_V2.1_softmax before Quantization

keras_baselineModel_activation_path = "/home/jovyan/models/checkpoints_/baseline_two_class_model_softmax_activation/"

baselineModel_activation_softmax = tf.keras.models.load_model(keras_baselineModel_activation_path)

print("Finished loading model")
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload
# Finished loading model

# %% [markdown]
# ## We hypothesize, the focus might be too small and gets lost during quantization, we analyze the weights of the trained dense layer before quantization

# %% [markdown]
# #### Check model shape
# ---

# %%
baselineModel_activation_softmax.summary()
# Out:
# Model: "model_1"
# __________________________________________________________________________________________________
#  Layer (type)                Output Shape                 Param #   Connected to
# ==================================================================================================
#  INPUT (InputLayer)          [(None, 144000)]             0         []
#
#  ADVANCED_SPEC1 (LinearSpec  (None, 128, 513, 1)          1         ['INPUT[0][0]']
#  Layer)
#
#  BNORM_SPEC_NOQUANT (BatchN  (None, 128, 513, 1)          4         ['ADVANCED_SPEC1[0][0]']
#  ormalization)
#
#  CONV_0 (Conv2D)             (None, 64, 257, 30)          960       ['BNORM_SPEC_NOQUANT[0][0]']
#
#  BNORM_0 (BatchNormalizatio  (None, 64, 257, 30)          120       ['CONV_0[0][0]']
#  n)
#
#  ACT_0 (Activation)          (None, 64, 257, 30)          0         ['BNORM_0[0][0]']
#
#  pool_0_MAX (MaxPooling2D)   (None, 64, 128, 30)          0         ['ACT_0[0][0]']
#
#  pool_0_AVG (AveragePooling  (None, 64, 128, 30)          0         ['ACT_0[0][0]']
#  2D)
#
#  pool_0_CONCAT (Concatenate  (None, 64, 128, 60)          0         ['pool_0_MAX[0][0]',
#  )                                                                   'pool_0_AVG[0][0]']
#
#  pool_0_ACT_QUANT (Activati  (None, 64, 128, 60)          0         ['pool_0_CONCAT[0][0]']
#  on)
#
#  pool_0_CONV (Conv2D)        (None, 64, 128, 30)          1830      ['pool_0_ACT_QUANT[0][0]']
#
#  BLOCK_1-1_CONV_1 (Conv2D)   (None, 32, 64, 60)           16200     ['pool_0_CONV[0][0]']
#
#  BLOCK_1-1_BN_1 (BatchNorma  (None, 32, 64, 60)           240       ['BLOCK_1-1_CONV_1[0][0]']
#  lization)
#
#  BLOCK_1-1_ACT_1 (Activatio  (None, 32, 64, 60)           0         ['BLOCK_1-1_BN_1[0][0]']
#  n)
#
#  BLOCK_1-1_ACT_QUANT (Activ  (None, 32, 64, 60)           0         ['BLOCK_1-1_ACT_1[0][0]']
#  ation)
#
#  BLOCK_1-1_CONV_3 (Conv2D)   (None, 32, 64, 60)           3600      ['BLOCK_1-1_ACT_QUANT[0][0]']
#
#  BLOCK_1-1_BN_3 (BatchNorma  (None, 32, 64, 60)           240       ['BLOCK_1-1_CONV_3[0][0]']
#  lization)
#
#  BLOCK_1-2_CONV_1 (Conv2D)   (None, 32, 64, 60)           32400     ['BLOCK_1-1_BN_3[0][0]']
#
#  BLOCK_1-2_BN_1 (BatchNorma  (None, 32, 64, 60)           240       ['BLOCK_1-2_CONV_1[0][0]']
#  lization)
#
#  BLOCK_1-2_ACT_1 (Activatio  (None, 32, 64, 60)           0         ['BLOCK_1-2_BN_1[0][0]']
#  n)
#
#  BLOCK_1-2_ACT_QUANT (Activ  (None, 32, 64, 60)           0         ['BLOCK_1-2_ACT_1[0][0]']
#  ation)
#
#  BLOCK_1-2_CONV_3 (Conv2D)   (None, 32, 64, 60)           3600      ['BLOCK_1-2_ACT_QUANT[0][0]']
#
#  BLOCK_1-2_BN_3 (BatchNorma  (None, 32, 64, 60)           240       ['BLOCK_1-2_CONV_3[0][0]']
#  lization)
#
#  BLOCK_1-2_ADD (Add)         (None, 32, 64, 60)           0         ['BLOCK_1-2_BN_3[0][0]',
#                                                                      'BLOCK_1-1_BN_3[0][0]']
#
#  BLOCK_1-3_CONV_1 (Conv2D)   (None, 32, 64, 60)           32400     ['BLOCK_1-2_ADD[0][0]']
#
#  BLOCK_1-3_BN_1 (BatchNorma  (None, 32, 64, 60)           240       ['BLOCK_1-3_CONV_1[0][0]']
#  lization)
#
#  BLOCK_1-3_ACT_1 (Activatio  (None, 32, 64, 60)           0         ['BLOCK_1-3_BN_1[0][0]']
#  n)
#
#  BLOCK_1-3_ACT_QUANT (Activ  (None, 32, 64, 60)           0         ['BLOCK_1-3_ACT_1[0][0]']
#  ation)
#
#  BLOCK_1-3_CONV_3 (Conv2D)   (None, 32, 64, 60)           3600      ['BLOCK_1-3_ACT_QUANT[0][0]']
#
#  BLOCK_1-3_BN_3 (BatchNorma  (None, 32, 64, 60)           240       ['BLOCK_1-3_CONV_3[0][0]']
#  lization)
#
#  BLOCK_1-3_ADD (Add)         (None, 32, 64, 60)           0         ['BLOCK_1-3_BN_3[0][0]',
#                                                                      'BLOCK_1-2_ADD[0][0]']
#
#  BLOCK_2-1_CONV_1 (Conv2D)   (None, 16, 32, 240)          129600    ['BLOCK_1-3_ADD[0][0]']
#
#  BLOCK_2-1_BN_1 (BatchNorma  (None, 16, 32, 240)          960       ['BLOCK_2-1_CONV_1[0][0]']
#  lization)
#
#  BLOCK_2-1_ACT_1 (Activatio  (None, 16, 32, 240)          0         ['BLOCK_2-1_BN_1[0][0]']
#  n)
#
#  BLOCK_2-1_ACT_QUANT (Activ  (None, 16, 32, 240)          0         ['BLOCK_2-1_ACT_1[0][0]']
#  ation)
#
#  BLOCK_2-1_CONV_3 (Conv2D)   (None, 16, 32, 120)          28800     ['BLOCK_2-1_ACT_QUANT[0][0]']
#
#  BLOCK_2-1_BN_3 (BatchNorma  (None, 16, 32, 120)          480       ['BLOCK_2-1_CONV_3[0][0]']
#  lization)
#
#  BLOCK_2-2_CONV_1 (Conv2D)   (None, 16, 32, 240)          259200    ['BLOCK_2-1_BN_3[0][0]']
#
#  BLOCK_2-2_BN_1 (BatchNorma  (None, 16, 32, 240)          960       ['BLOCK_2-2_CONV_1[0][0]']
#  lization)
#
#  BLOCK_2-2_ACT_1 (Activatio  (None, 16, 32, 240)          0         ['BLOCK_2-2_BN_1[0][0]']
#  n)
#
#  BLOCK_2-2_ACT_QUANT (Activ  (None, 16, 32, 240)          0         ['BLOCK_2-2_ACT_1[0][0]']
#  ation)
#
#  BLOCK_2-2_CONV_3 (Conv2D)   (None, 16, 32, 120)          28800     ['BLOCK_2-2_ACT_QUANT[0][0]']
#
#  BLOCK_2-2_BN_3 (BatchNorma  (None, 16, 32, 120)          480       ['BLOCK_2-2_CONV_3[0][0]']
#  lization)
#
#  BLOCK_2-2_ADD (Add)         (None, 16, 32, 120)          0         ['BLOCK_2-2_BN_3[0][0]',
#                                                                      'BLOCK_2-1_BN_3[0][0]']
#
#  BLOCK_2-3_CONV_1 (Conv2D)   (None, 16, 32, 240)          259200    ['BLOCK_2-2_ADD[0][0]']
#
#  BLOCK_2-3_BN_1 (BatchNorma  (None, 16, 32, 240)          960       ['BLOCK_2-3_CONV_1[0][0]']
#  lization)
#
#  BLOCK_2-3_ACT_1 (Activatio  (None, 16, 32, 240)          0         ['BLOCK_2-3_BN_1[0][0]']
#  n)
#
#  BLOCK_2-3_ACT_QUANT (Activ  (None, 16, 32, 240)          0         ['BLOCK_2-3_ACT_1[0][0]']
#  ation)
#
#  BLOCK_2-3_CONV_3 (Conv2D)   (None, 16, 32, 120)          28800     ['BLOCK_2-3_ACT_QUANT[0][0]']
#
#  BLOCK_2-3_BN_3 (BatchNorma  (None, 16, 32, 120)          480       ['BLOCK_2-3_CONV_3[0][0]']
#  lization)
#
#  BLOCK_2-3_ADD (Add)         (None, 16, 32, 120)          0         ['BLOCK_2-3_BN_3[0][0]',
#                                                                      'BLOCK_2-2_ADD[0][0]']
#
#  BLOCK_2-4_CONV_1 (Conv2D)   (None, 16, 32, 240)          259200    ['BLOCK_2-3_ADD[0][0]']
#
#  BLOCK_2-4_BN_1 (BatchNorma  (None, 16, 32, 240)          960       ['BLOCK_2-4_CONV_1[0][0]']
#  lization)
#
#  BLOCK_2-4_ACT_1 (Activatio  (None, 16, 32, 240)          0         ['BLOCK_2-4_BN_1[0][0]']
#  n)
#
#  BLOCK_2-4_ACT_QUANT (Activ  (None, 16, 32, 240)          0         ['BLOCK_2-4_ACT_1[0][0]']
#  ation)
#
#  BLOCK_2-4_CONV_3 (Conv2D)   (None, 16, 32, 120)          28800     ['BLOCK_2-4_ACT_QUANT[0][0]']
#
#  BLOCK_2-4_BN_3 (BatchNorma  (None, 16, 32, 120)          480       ['BLOCK_2-4_CONV_3[0][0]']
#  lization)
#
#  BLOCK_2-4_ADD (Add)         (None, 16, 32, 120)          0         ['BLOCK_2-4_BN_3[0][0]',
#                                                                      'BLOCK_2-3_ADD[0][0]']
#
#  BLOCK_3-1_CONV_1 (Conv2D)   (None, 16, 32, 640)          76800     ['BLOCK_2-4_ADD[0][0]']
#
#  BLOCK_3-1_BN_1 (BatchNorma  (None, 16, 32, 640)          2560      ['BLOCK_3-1_CONV_1[0][0]']
#  lization)
#
#  BLOCK_3-1_ACT_1 (Activatio  (None, 16, 32, 640)          0         ['BLOCK_3-1_BN_1[0][0]']
#  n)
#
#  BLOCK_3-1_CONV_2 (Depthwis  (None, 8, 16, 640)           5760      ['BLOCK_3-1_ACT_1[0][0]']
#  eConv2D)
#
#  BLOCK_3-1_BN_2_NOQUANT (Ba  (None, 8, 16, 640)           2560      ['BLOCK_3-1_CONV_2[0][0]']
#  tchNormalization)
#
#  BLOCK_3-1_ACT_2 (Activatio  (None, 8, 16, 640)           0         ['BLOCK_3-1_BN_2_NOQUANT[0][0]
#  n)                                                                 ']
#
#  BLOCK_3-1_SE_AVG_POOL_1 (G  (None, 640)                  0         ['BLOCK_3-1_ACT_2[0][0]']
#  lobalAveragePooling2D)
#
#  BLOCK_3-1_SE_RESHAPE (Resh  (None, 1, 1, 640)            0         ['BLOCK_3-1_SE_AVG_POOL_1[0][0
#  ape)                                                               ]']
#
#  BLOCK_3-1_SE_CONV_1 (Conv2  (None, 1, 1, 40)             25600     ['BLOCK_3-1_SE_RESHAPE[0][0]']
#  D)
#
#  BLOCK_3-1_SE_CONV_2 (Conv2  (None, 1, 1, 640)            25600     ['BLOCK_3-1_SE_CONV_1[0][0]']
#  D)
#
#  BLOCK_3-1_MULTIPLY (Multip  (None, 8, 16, 640)           0         ['BLOCK_3-1_ACT_2[0][0]',
#  ly)                                                                 'BLOCK_3-1_SE_CONV_2[0][0]']
#
#  BLOCK_3-1_ACT_QUANT (Activ  (None, 8, 16, 640)           0         ['BLOCK_3-1_MULTIPLY[0][0]']
#  ation)
#
#  BLOCK_3-1_CONV_3 (Conv2D)   (None, 8, 16, 160)           102400    ['BLOCK_3-1_ACT_QUANT[0][0]']
#
#  BLOCK_3-1_BN_3 (BatchNorma  (None, 8, 16, 160)           640       ['BLOCK_3-1_CONV_3[0][0]']
#  lization)
#
#  BLOCK_3-2_CONV_1 (Conv2D)   (None, 8, 16, 640)           102400    ['BLOCK_3-1_BN_3[0][0]']
#
#  BLOCK_3-2_BN_1 (BatchNorma  (None, 8, 16, 640)           2560      ['BLOCK_3-2_CONV_1[0][0]']
#  lization)
#
#  BLOCK_3-2_ACT_1 (Activatio  (None, 8, 16, 640)           0         ['BLOCK_3-2_BN_1[0][0]']
#  n)
#
#  BLOCK_3-2_CONV_2 (Depthwis  (None, 8, 16, 640)           5760      ['BLOCK_3-2_ACT_1[0][0]']
#  eConv2D)
#
#  BLOCK_3-2_BN_2_NOQUANT (Ba  (None, 8, 16, 640)           2560      ['BLOCK_3-2_CONV_2[0][0]']
#  tchNormalization)
#
#  BLOCK_3-2_ACT_2 (Activatio  (None, 8, 16, 640)           0         ['BLOCK_3-2_BN_2_NOQUANT[0][0]
#  n)                                                                 ']
#
#  BLOCK_3-2_SE_AVG_POOL_1 (G  (None, 640)                  0         ['BLOCK_3-2_ACT_2[0][0]']
#  lobalAveragePooling2D)
#
#  BLOCK_3-2_SE_RESHAPE (Resh  (None, 1, 1, 640)            0         ['BLOCK_3-2_SE_AVG_POOL_1[0][0
#  ape)                                                               ]']
#
#  BLOCK_3-2_SE_CONV_1 (Conv2  (None, 1, 1, 40)             25600     ['BLOCK_3-2_SE_RESHAPE[0][0]']
#  D)
#
#  BLOCK_3-2_SE_CONV_2 (Conv2  (None, 1, 1, 640)            25600     ['BLOCK_3-2_SE_CONV_1[0][0]']
#  D)
#
#  BLOCK_3-2_MULTIPLY (Multip  (None, 8, 16, 640)           0         ['BLOCK_3-2_ACT_2[0][0]',
#  ly)                                                                 'BLOCK_3-2_SE_CONV_2[0][0]']
#
#  BLOCK_3-2_ACT_QUANT (Activ  (None, 8, 16, 640)           0         ['BLOCK_3-2_MULTIPLY[0][0]']
#  ation)
#
#  BLOCK_3-2_CONV_3 (Conv2D)   (None, 8, 16, 160)           102400    ['BLOCK_3-2_ACT_QUANT[0][0]']
#
#  BLOCK_3-2_BN_3 (BatchNorma  (None, 8, 16, 160)           640       ['BLOCK_3-2_CONV_3[0][0]']
#  lization)
#
#  BLOCK_3-2_ADD (Add)         (None, 8, 16, 160)           0         ['BLOCK_3-2_BN_3[0][0]',
#                                                                      'BLOCK_3-1_BN_3[0][0]']
#
#  BLOCK_3-3_CONV_1 (Conv2D)   (None, 8, 16, 640)           102400    ['BLOCK_3-2_ADD[0][0]']
#
#  BLOCK_3-3_BN_1 (BatchNorma  (None, 8, 16, 640)           2560      ['BLOCK_3-3_CONV_1[0][0]']
#  lization)
#
#  BLOCK_3-3_ACT_1 (Activatio  (None, 8, 16, 640)           0         ['BLOCK_3-3_BN_1[0][0]']
#  n)
#
#  BLOCK_3-3_CONV_2 (Depthwis  (None, 8, 16, 640)           5760      ['BLOCK_3-3_ACT_1[0][0]']
#  eConv2D)
#
#  BLOCK_3-3_BN_2_NOQUANT (Ba  (None, 8, 16, 640)           2560      ['BLOCK_3-3_CONV_2[0][0]']
#  tchNormalization)
#
#  BLOCK_3-3_ACT_2 (Activatio  (None, 8, 16, 640)           0         ['BLOCK_3-3_BN_2_NOQUANT[0][0]
#  n)                                                                 ']
#
#  BLOCK_3-3_SE_AVG_POOL_1 (G  (None, 640)                  0         ['BLOCK_3-3_ACT_2[0][0]']
#  lobalAveragePooling2D)
#
#  BLOCK_3-3_SE_RESHAPE (Resh  (None, 1, 1, 640)            0         ['BLOCK_3-3_SE_AVG_POOL_1[0][0
#  ape)                                                               ]']
#
#  BLOCK_3-3_SE_CONV_1 (Conv2  (None, 1, 1, 40)             25600     ['BLOCK_3-3_SE_RESHAPE[0][0]']
#  D)
#
#  BLOCK_3-3_SE_CONV_2 (Conv2  (None, 1, 1, 640)            25600     ['BLOCK_3-3_SE_CONV_1[0][0]']
#  D)
#
#  BLOCK_3-3_MULTIPLY (Multip  (None, 8, 16, 640)           0         ['BLOCK_3-3_ACT_2[0][0]',
#  ly)                                                                 'BLOCK_3-3_SE_CONV_2[0][0]']
#
#  BLOCK_3-3_ACT_QUANT (Activ  (None, 8, 16, 640)           0         ['BLOCK_3-3_MULTIPLY[0][0]']
#  ation)
#
#  BLOCK_3-3_CONV_3 (Conv2D)   (None, 8, 16, 160)           102400    ['BLOCK_3-3_ACT_QUANT[0][0]']
#
#  BLOCK_3-3_BN_3 (BatchNorma  (None, 8, 16, 160)           640       ['BLOCK_3-3_CONV_3[0][0]']
#  lization)
#
#  BLOCK_3-3_ADD (Add)         (None, 8, 16, 160)           0         ['BLOCK_3-3_BN_3[0][0]',
#                                                                      'BLOCK_3-2_ADD[0][0]']
#
#  BLOCK_3-4_CONV_1 (Conv2D)   (None, 8, 16, 640)           102400    ['BLOCK_3-3_ADD[0][0]']
#
#  BLOCK_3-4_BN_1 (BatchNorma  (None, 8, 16, 640)           2560      ['BLOCK_3-4_CONV_1[0][0]']
#  lization)
#
#  BLOCK_3-4_ACT_1 (Activatio  (None, 8, 16, 640)           0         ['BLOCK_3-4_BN_1[0][0]']
#  n)
#
#  BLOCK_3-4_CONV_2 (Depthwis  (None, 8, 16, 640)           5760      ['BLOCK_3-4_ACT_1[0][0]']
#  eConv2D)
#
#  BLOCK_3-4_BN_2_NOQUANT (Ba  (None, 8, 16, 640)           2560      ['BLOCK_3-4_CONV_2[0][0]']
#  tchNormalization)
#
#  BLOCK_3-4_ACT_2 (Activatio  (None, 8, 16, 640)           0         ['BLOCK_3-4_BN_2_NOQUANT[0][0]
#  n)                                                                 ']
#
#  BLOCK_3-4_SE_AVG_POOL_1 (G  (None, 640)                  0         ['BLOCK_3-4_ACT_2[0][0]']
#  lobalAveragePooling2D)
#
#  BLOCK_3-4_SE_RESHAPE (Resh  (None, 1, 1, 640)            0         ['BLOCK_3-4_SE_AVG_POOL_1[0][0
#  ape)                                                               ]']
#
#  BLOCK_3-4_SE_CONV_1 (Conv2  (None, 1, 1, 40)             25600     ['BLOCK_3-4_SE_RESHAPE[0][0]']
#  D)
#
#  BLOCK_3-4_SE_CONV_2 (Conv2  (None, 1, 1, 640)            25600     ['BLOCK_3-4_SE_CONV_1[0][0]']
#  D)
#
#  BLOCK_3-4_MULTIPLY (Multip  (None, 8, 16, 640)           0         ['BLOCK_3-4_ACT_2[0][0]',
#  ly)                                                                 'BLOCK_3-4_SE_CONV_2[0][0]']
#
#  BLOCK_3-4_ACT_QUANT (Activ  (None, 8, 16, 640)           0         ['BLOCK_3-4_MULTIPLY[0][0]']
#  ation)
#
#  BLOCK_3-4_CONV_3 (Conv2D)   (None, 8, 16, 160)           102400    ['BLOCK_3-4_ACT_QUANT[0][0]']
#
#  BLOCK_3-4_BN_3 (BatchNorma  (None, 8, 16, 160)           640       ['BLOCK_3-4_CONV_3[0][0]']
#  lization)
#
#  BLOCK_3-4_ADD (Add)         (None, 8, 16, 160)           0         ['BLOCK_3-4_BN_3[0][0]',
#                                                                      'BLOCK_3-3_ADD[0][0]']
#
#  BLOCK_3-5_CONV_1 (Conv2D)   (None, 8, 16, 640)           102400    ['BLOCK_3-4_ADD[0][0]']
#
#  BLOCK_3-5_BN_1 (BatchNorma  (None, 8, 16, 640)           2560      ['BLOCK_3-5_CONV_1[0][0]']
#  lization)
#
#  BLOCK_3-5_ACT_1 (Activatio  (None, 8, 16, 640)           0         ['BLOCK_3-5_BN_1[0][0]']
#  n)
#
#  BLOCK_3-5_CONV_2 (Depthwis  (None, 8, 16, 640)           5760      ['BLOCK_3-5_ACT_1[0][0]']
#  eConv2D)
#
#  BLOCK_3-5_BN_2_NOQUANT (Ba  (None, 8, 16, 640)           2560      ['BLOCK_3-5_CONV_2[0][0]']
#  tchNormalization)
#
#  BLOCK_3-5_ACT_2 (Activatio  (None, 8, 16, 640)           0         ['BLOCK_3-5_BN_2_NOQUANT[0][0]
#  n)                                                                 ']
#
#  BLOCK_3-5_SE_AVG_POOL_1 (G  (None, 640)                  0         ['BLOCK_3-5_ACT_2[0][0]']
#  lobalAveragePooling2D)
#
#  BLOCK_3-5_SE_RESHAPE (Resh  (None, 1, 1, 640)            0         ['BLOCK_3-5_SE_AVG_POOL_1[0][0
#  ape)                                                               ]']
#
#  BLOCK_3-5_SE_CONV_1 (Conv2  (None, 1, 1, 40)             25600     ['BLOCK_3-5_SE_RESHAPE[0][0]']
#  D)
#
#  BLOCK_3-5_SE_CONV_2 (Conv2  (None, 1, 1, 640)            25600     ['BLOCK_3-5_SE_CONV_1[0][0]']
#  D)
#
#  BLOCK_3-5_MULTIPLY (Multip  (None, 8, 16, 640)           0         ['BLOCK_3-5_ACT_2[0][0]',
#  ly)                                                                 'BLOCK_3-5_SE_CONV_2[0][0]']
#
#  BLOCK_3-5_ACT_QUANT (Activ  (None, 8, 16, 640)           0         ['BLOCK_3-5_MULTIPLY[0][0]']
#  ation)
#
#  BLOCK_3-5_CONV_3 (Conv2D)   (None, 8, 16, 160)           102400    ['BLOCK_3-5_ACT_QUANT[0][0]']
#
#  BLOCK_3-5_BN_3 (BatchNorma  (None, 8, 16, 160)           640       ['BLOCK_3-5_CONV_3[0][0]']
#  lization)
#
#  BLOCK_3-5_ADD (Add)         (None, 8, 16, 160)           0         ['BLOCK_3-5_BN_3[0][0]',
#                                                                      'BLOCK_3-4_ADD[0][0]']
#
#  BLOCK_4-1_CONV_1 (Conv2D)   (None, 8, 16, 1120)          179200    ['BLOCK_3-5_ADD[0][0]']
#
#  BLOCK_4-1_BN_1 (BatchNorma  (None, 8, 16, 1120)          4480      ['BLOCK_4-1_CONV_1[0][0]']
#  lization)
#
#  BLOCK_4-1_ACT_1 (Activatio  (None, 8, 16, 1120)          0         ['BLOCK_4-1_BN_1[0][0]']
#  n)
#
#  BLOCK_4-1_CONV_2 (Depthwis  (None, 4, 8, 1120)           10080     ['BLOCK_4-1_ACT_1[0][0]']
#  eConv2D)
#
#  BLOCK_4-1_BN_2_NOQUANT (Ba  (None, 4, 8, 1120)           4480      ['BLOCK_4-1_CONV_2[0][0]']
#  tchNormalization)
#
#  BLOCK_4-1_ACT_2 (Activatio  (None, 4, 8, 1120)           0         ['BLOCK_4-1_BN_2_NOQUANT[0][0]
#  n)                                                                 ']
#
#  BLOCK_4-1_SE_AVG_POOL_1 (G  (None, 1120)                 0         ['BLOCK_4-1_ACT_2[0][0]']
#  lobalAveragePooling2D)
#
#  BLOCK_4-1_SE_RESHAPE (Resh  (None, 1, 1, 1120)           0         ['BLOCK_4-1_SE_AVG_POOL_1[0][0
#  ape)                                                               ]']
#
#  BLOCK_4-1_SE_CONV_1 (Conv2  (None, 1, 1, 70)             78400     ['BLOCK_4-1_SE_RESHAPE[0][0]']
#  D)
#
#  BLOCK_4-1_SE_CONV_2 (Conv2  (None, 1, 1, 1120)           78400     ['BLOCK_4-1_SE_CONV_1[0][0]']
#  D)
#
#  BLOCK_4-1_MULTIPLY (Multip  (None, 4, 8, 1120)           0         ['BLOCK_4-1_ACT_2[0][0]',
#  ly)                                                                 'BLOCK_4-1_SE_CONV_2[0][0]']
#
#  BLOCK_4-1_ACT_QUANT (Activ  (None, 4, 8, 1120)           0         ['BLOCK_4-1_MULTIPLY[0][0]']
#  ation)
#
#  BLOCK_4-1_CONV_3 (Conv2D)   (None, 4, 8, 280)            313600    ['BLOCK_4-1_ACT_QUANT[0][0]']
#
#  BLOCK_4-1_BN_3 (BatchNorma  (None, 4, 8, 280)            1120      ['BLOCK_4-1_CONV_3[0][0]']
#  lization)
#
#  BLOCK_4-2_CONV_1 (Conv2D)   (None, 4, 8, 1120)           313600    ['BLOCK_4-1_BN_3[0][0]']
#
#  BLOCK_4-2_BN_1 (BatchNorma  (None, 4, 8, 1120)           4480      ['BLOCK_4-2_CONV_1[0][0]']
#  lization)
#
#  BLOCK_4-2_ACT_1 (Activatio  (None, 4, 8, 1120)           0         ['BLOCK_4-2_BN_1[0][0]']
#  n)
#
#  BLOCK_4-2_CONV_2 (Depthwis  (None, 4, 8, 1120)           10080     ['BLOCK_4-2_ACT_1[0][0]']
#  eConv2D)
#
#  BLOCK_4-2_BN_2_NOQUANT (Ba  (None, 4, 8, 1120)           4480      ['BLOCK_4-2_CONV_2[0][0]']
#  tchNormalization)
#
#  BLOCK_4-2_ACT_2 (Activatio  (None, 4, 8, 1120)           0         ['BLOCK_4-2_BN_2_NOQUANT[0][0]
#  n)                                                                 ']
#
#  BLOCK_4-2_SE_AVG_POOL_1 (G  (None, 1120)                 0         ['BLOCK_4-2_ACT_2[0][0]']
#  lobalAveragePooling2D)
#
#  BLOCK_4-2_SE_RESHAPE (Resh  (None, 1, 1, 1120)           0         ['BLOCK_4-2_SE_AVG_POOL_1[0][0
#  ape)                                                               ]']
#
#  BLOCK_4-2_SE_CONV_1 (Conv2  (None, 1, 1, 70)             78400     ['BLOCK_4-2_SE_RESHAPE[0][0]']
#  D)
#
#  BLOCK_4-2_SE_CONV_2 (Conv2  (None, 1, 1, 1120)           78400     ['BLOCK_4-2_SE_CONV_1[0][0]']
#  D)
#
#  BLOCK_4-2_MULTIPLY (Multip  (None, 4, 8, 1120)           0         ['BLOCK_4-2_ACT_2[0][0]',
#  ly)                                                                 'BLOCK_4-2_SE_CONV_2[0][0]']
#
#  BLOCK_4-2_ACT_QUANT (Activ  (None, 4, 8, 1120)           0         ['BLOCK_4-2_MULTIPLY[0][0]']
#  ation)
#
#  BLOCK_4-2_CONV_3 (Conv2D)   (None, 4, 8, 280)            313600    ['BLOCK_4-2_ACT_QUANT[0][0]']
#
#  BLOCK_4-2_BN_3 (BatchNorma  (None, 4, 8, 280)            1120      ['BLOCK_4-2_CONV_3[0][0]']
#  lization)
#
#  BLOCK_4-2_ADD (Add)         (None, 4, 8, 280)            0         ['BLOCK_4-2_BN_3[0][0]',
#                                                                      'BLOCK_4-1_BN_3[0][0]']
#
#  BLOCK_4-3_CONV_1 (Conv2D)   (None, 4, 8, 1120)           313600    ['BLOCK_4-2_ADD[0][0]']
#
#  BLOCK_4-3_BN_1 (BatchNorma  (None, 4, 8, 1120)           4480      ['BLOCK_4-3_CONV_1[0][0]']
#  lization)
#
#  BLOCK_4-3_ACT_1 (Activatio  (None, 4, 8, 1120)           0         ['BLOCK_4-3_BN_1[0][0]']
#  n)
#
#  BLOCK_4-3_CONV_2 (Depthwis  (None, 4, 8, 1120)           10080     ['BLOCK_4-3_ACT_1[0][0]']
#  eConv2D)
#
#  BLOCK_4-3_BN_2_NOQUANT (Ba  (None, 4, 8, 1120)           4480      ['BLOCK_4-3_CONV_2[0][0]']
#  tchNormalization)
#
#  BLOCK_4-3_ACT_2 (Activatio  (None, 4, 8, 1120)           0         ['BLOCK_4-3_BN_2_NOQUANT[0][0]
#  n)                                                                 ']
#
#  BLOCK_4-3_SE_AVG_POOL_1 (G  (None, 1120)                 0         ['BLOCK_4-3_ACT_2[0][0]']
#  lobalAveragePooling2D)
#
#  BLOCK_4-3_SE_RESHAPE (Resh  (None, 1, 1, 1120)           0         ['BLOCK_4-3_SE_AVG_POOL_1[0][0
#  ape)                                                               ]']
#
#  BLOCK_4-3_SE_CONV_1 (Conv2  (None, 1, 1, 70)             78400     ['BLOCK_4-3_SE_RESHAPE[0][0]']
#  D)
#
#  BLOCK_4-3_SE_CONV_2 (Conv2  (None, 1, 1, 1120)           78400     ['BLOCK_4-3_SE_CONV_1[0][0]']
#  D)
#
#  BLOCK_4-3_MULTIPLY (Multip  (None, 4, 8, 1120)           0         ['BLOCK_4-3_ACT_2[0][0]',
#  ly)                                                                 'BLOCK_4-3_SE_CONV_2[0][0]']
#
#  BLOCK_4-3_ACT_QUANT (Activ  (None, 4, 8, 1120)           0         ['BLOCK_4-3_MULTIPLY[0][0]']
#  ation)
#
#  BLOCK_4-3_CONV_3 (Conv2D)   (None, 4, 8, 280)            313600    ['BLOCK_4-3_ACT_QUANT[0][0]']
#
#  BLOCK_4-3_BN_3 (BatchNorma  (None, 4, 8, 280)            1120      ['BLOCK_4-3_CONV_3[0][0]']
#  lization)
#
#  BLOCK_4-3_ADD (Add)         (None, 4, 8, 280)            0         ['BLOCK_4-3_BN_3[0][0]',
#                                                                      'BLOCK_4-2_ADD[0][0]']
#
#  BLOCK_4-4_CONV_1 (Conv2D)   (None, 4, 8, 1120)           313600    ['BLOCK_4-3_ADD[0][0]']
#
#  BLOCK_4-4_BN_1 (BatchNorma  (None, 4, 8, 1120)           4480      ['BLOCK_4-4_CONV_1[0][0]']
#  lization)
#
#  BLOCK_4-4_ACT_1 (Activatio  (None, 4, 8, 1120)           0         ['BLOCK_4-4_BN_1[0][0]']
#  n)
#
#  BLOCK_4-4_CONV_2 (Depthwis  (None, 4, 8, 1120)           10080     ['BLOCK_4-4_ACT_1[0][0]']
#  eConv2D)
#
#  BLOCK_4-4_BN_2_NOQUANT (Ba  (None, 4, 8, 1120)           4480      ['BLOCK_4-4_CONV_2[0][0]']
#  tchNormalization)
#
#  BLOCK_4-4_ACT_2 (Activatio  (None, 4, 8, 1120)           0         ['BLOCK_4-4_BN_2_NOQUANT[0][0]
#  n)                                                                 ']
#
#  BLOCK_4-4_SE_AVG_POOL_1 (G  (None, 1120)                 0         ['BLOCK_4-4_ACT_2[0][0]']
#  lobalAveragePooling2D)
#
#  BLOCK_4-4_SE_RESHAPE (Resh  (None, 1, 1, 1120)           0         ['BLOCK_4-4_SE_AVG_POOL_1[0][0
#  ape)                                                               ]']
#
#  BLOCK_4-4_SE_CONV_1 (Conv2  (None, 1, 1, 70)             78400     ['BLOCK_4-4_SE_RESHAPE[0][0]']
#  D)
#
#  BLOCK_4-4_SE_CONV_2 (Conv2  (None, 1, 1, 1120)           78400     ['BLOCK_4-4_SE_CONV_1[0][0]']
#  D)
#
#  BLOCK_4-4_MULTIPLY (Multip  (None, 4, 8, 1120)           0         ['BLOCK_4-4_ACT_2[0][0]',
#  ly)                                                                 'BLOCK_4-4_SE_CONV_2[0][0]']
#
#  BLOCK_4-4_ACT_QUANT (Activ  (None, 4, 8, 1120)           0         ['BLOCK_4-4_MULTIPLY[0][0]']
#  ation)
#
#  BLOCK_4-4_CONV_3 (Conv2D)   (None, 4, 8, 280)            313600    ['BLOCK_4-4_ACT_QUANT[0][0]']
#
#  BLOCK_4-4_BN_3 (BatchNorma  (None, 4, 8, 280)            1120      ['BLOCK_4-4_CONV_3[0][0]']
#  lization)
#
#  BLOCK_4-4_ADD (Add)         (None, 4, 8, 280)            0         ['BLOCK_4-4_BN_3[0][0]',
#                                                                      'BLOCK_4-3_ADD[0][0]']
#
#  BNORM_POST_NOQUANT (BatchN  (None, 4, 8, 280)            1120      ['BLOCK_4-4_ADD[0][0]']
#  ormalization)
#
#  ACT_POST (Activation)       (None, 4, 8, 280)            0         ['BNORM_POST_NOQUANT[0][0]']
#
#  POST_CONV_1 (Conv2D)        (None, 2, 6, 420)            1058400   ['ACT_POST[0][0]']
#
#  POST_BN_1 (BatchNormalizat  (None, 2, 6, 420)            1680      ['POST_CONV_1[0][0]']
#  ion)
#
#  POST_ACT_1 (Activation)     (None, 2, 6, 420)            0         ['POST_BN_1[0][0]']
#
#  GLOBAL_LME_POOL (GlobalLog  (None, 420)                  1         ['POST_ACT_1[0][0]']
#  ExpPooling2D)
#
#  dense (Dense)               (None, 2)                    842       ['GLOBAL_LME_POOL[0][0]']
#
#  activation (Activation)     (None, 2)                    0         ['dense[0][0]']
#
# ==================================================================================================
# Total params: 6580598 (25.10 MB)
# Trainable params: 842 (3.29 KB)
# Non-trainable params: 6579756 (25.10 MB)
# __________________________________________________________________________________________________

# %%
tflite_baselineModel_softmax_activation_path = "/home/jovyan/models/checkpoints_/baseline_two_class_model_softmax_activation.tflite"

tf.lite.experimental.Analyzer.analyze(model_path=tflite_baselineModel_softmax_activation_path,
                                      model_content=None,
                                      gpu_compatibility=False)
# Out:
# === /home/jovyan/models/checkpoints_/baseline_two_class_model_softmax_activation.tflite ===
#
# Your TFLite model has '1' subgraph(s). In the subgraph description below,
# T# represents the Tensor numbers. For example, in Subgraph#0, the REDUCE_MIN op takes
# tensor #0 and tensor #117 as input and produces tensor #144 as output.
#
# Subgraph#0 main(T#0) -> [T#406]
#   Op#0 REDUCE_MIN(T#0, T#117[1]) -> [T#144]
#   Op#1 SUB(T#0, T#144) -> [T#145]
#   Op#2 REDUCE_MAX(T#145, T#117[1]) -> [T#146]
#   Op#3 DIV(T#145, T#146) -> [T#147]
#   Op#4 SHAPE(T#147) -> [T#148]
#   Op#5 SPLIT_V(T#148, T#125[1, 1, 0], T#137[0]) -> [T#149, T#150, T#151]
#   Op#6 RESHAPE(T#150, T#136[]) -> [T#152]
#   Op#7 FLOOR_DIV(T#152, T#135[8]) -> [T#153]
#   Op#8 PACK(T#153, T#135[8]) -> [T#154]
#   Op#9 MUL(T#153, T#135[8]) -> [T#155]
#   Op#10 RESHAPE(T#155, T#120[1]) -> [T#156]
#   Op#11 CONCATENATION(T#149, T#156) -> [T#157]
#   Op#12 CONCATENATION(T#149, T#154) -> [T#158]
#   Op#13 STRIDED_SLICE(T#147, T#134[0, 0], T#157, T#126[1, 1]) -> [T#159]
#   Op#14 RESHAPE(T#159, T#158) -> [T#160]
#   Op#15 SUB(T#152, T#133[512]) -> [T#161]
#   Op#16 FLOOR_DIV(T#161, T#132[280]) -> [T#162]
#   Op#17 ADD(T#162, T#117[1]) -> [T#163]
#   Op#18 MAXIMUM(T#163, T#137[0]) -> [T#164]
#   Op#19 PACK(T#164, T#117[1]) -> [T#165]
#   Op#20 PACK(T#164, T#133[512]) -> [T#166]
#   Op#21 CONCATENATION(T#149, T#166) -> [T#167]
#   Op#22 RANGE(T#137[0], T#164, T#117[1]) -> [T#168]
#   Op#23 MUL(T#168, T#127[35]) -> [T#169]
#   Op#24 RESHAPE(T#169, T#165) -> [T#170]
#   Op#25 ADD(T#170, T#124[0, 1, 2, 3, 4, ...]) -> [T#171]
#   Op#26 GATHER(T#160, T#171) -> [T#172]
#   Op#27 RESHAPE(T#172, T#167) -> [T#173]
#   Op#28 MUL(T#173, T#123) -> [T#174]
#   Op#29 EXPAND_DIMS(T#174, T#56[-2]) -> [T#175]
#   Op#30 RFFT2D(T#175, T#57[1, 512]) -> [T#176]
#   Op#31 SQUEEZE(T#176) -> [T#177]
#   Op#32 CAST(T#177) -> [T#178]
#   Op#33 STRIDED_SLICE(T#178, T#131[0, 0, 0], T#130[0, 0, 128], T#129[1, 1, 1]) -> [T#179]
#   Op#34 MUL(T#179, T#179) -> [T#180]
#   Op#35 POW(T#180, T#122) -> [T#181]
#   Op#36 TRANSPOSE(T#181, T#128[0, 2, 1]) -> [T#182]
#   Op#37 EXPAND_DIMS(T#182, T#138[-1]) -> [T#183]
#   Op#38 MUL(T#183, T#139) -> [T#184]
#   Op#39 ADD(T#184, T#140) -> [T#185]
#   Op#40 CONV_2D(T#185, T#58, T#1) -> [T#186]
#   Op#41 AVERAGE_POOL_2D(T#186) -> [T#187]
#   Op#42 MAX_POOL_2D(T#186) -> [T#188]
#   Op#43 CONCATENATION(T#188, T#187) -> [T#189]
#   Op#44 CONV_2D(T#189, T#59, T#12) -> [T#190]
#   Op#45 CONV_2D(T#190, T#60, T#13) -> [T#191]
#   Op#46 LOGISTIC(T#191) -> [T#192]
#   Op#47 MUL(T#191, T#192) -> [T#193]
#   Op#48 CONV_2D(T#193, T#61, T#14) -> [T#194]
#   Op#49 CONV_2D(T#194, T#62, T#15) -> [T#195]
#   Op#50 LOGISTIC(T#195) -> [T#196]
#   Op#51 MUL(T#195, T#196) -> [T#197]
#   Op#52 CONV_2D(T#197, T#63, T#16) -> [T#198]
#   Op#53 ADD(T#198, T#194) -> [T#199]
#   Op#54 CONV_2D(T#199, T#64, T#17) -> [T#200]
#   Op#55 LOGISTIC(T#200) -> [T#201]
#   Op#56 MUL(T#200, T#201) -> [T#202]
#   Op#57 CONV_2D(T#202, T#65, T#18) -> [T#203]
#   Op#58 ADD(T#203, T#199) -> [T#204]
#   Op#59 CONV_2D(T#204, T#66, T#19) -> [T#205]
#   Op#60 LOGISTIC(T#205) -> [T#206]
#   Op#61 MUL(T#205, T#206) -> [T#207]
#   Op#62 CONV_2D(T#207, T#67, T#20) -> [T#208]
#   Op#63 CONV_2D(T#208, T#68, T#21) -> [T#209]
#   Op#64 LOGISTIC(T#209) -> [T#210]
#   Op#65 MUL(T#209, T#210) -> [T#211]
#   Op#66 CONV_2D(T#211, T#69, T#22) -> [T#212]
#   Op#67 ADD(T#212, T#208) -> [T#213]
#   Op#68 CONV_2D(T#213, T#70, T#23) -> [T#214]
#   Op#69 LOGISTIC(T#214) -> [T#215]
#   Op#70 MUL(T#214, T#215) -> [T#216]
#   Op#71 CONV_2D(T#216, T#71, T#24) -> [T#217]
#   Op#72 ADD(T#217, T#213) -> [T#218]
#   Op#73 CONV_2D(T#218, T#72, T#25) -> [T#219]
#   Op#74 LOGISTIC(T#219) -> [T#220]
#   Op#75 MUL(T#219, T#220) -> [T#221]
#   Op#76 CONV_2D(T#221, T#73, T#26) -> [T#222]
#   Op#77 ADD(T#222, T#218) -> [T#223]
#   Op#78 CONV_2D(T#223, T#74, T#27) -> [T#224]
#   Op#79 LOGISTIC(T#224) -> [T#225]
#   Op#80 MUL(T#224, T#225) -> [T#226]
#   Op#81 DEPTHWISE_CONV_2D(T#226, T#28, T#2) -> [T#227]
#   Op#82 LOGISTIC(T#227) -> [T#228]
#   Op#83 MUL(T#227, T#228) -> [T#229]
#   Op#84 MEAN(T#229, T#116[1, 2]) -> [T#230]
#   Op#85 SHAPE(T#230) -> [T#231]
#   Op#86 STRIDED_SLICE(T#231, T#119[0], T#120[1], T#120[1]) -> [T#232]
#   Op#87 PACK(T#232, T#117[1], T#117[1], T#118[640]) -> [T#233]
#   Op#88 RESHAPE(T#230, T#233) -> [T#234]
#   Op#89 CONV_2D(T#234, T#76, T#75) -> [T#235]
#   Op#90 LOGISTIC(T#235) -> [T#236]
#   Op#91 MUL(T#235, T#236) -> [T#237]
#   Op#92 CONV_2D(T#237, T#77, T#29) -> [T#238]
#   Op#93 LOGISTIC(T#238) -> [T#239]
#   Op#94 MUL(T#229, T#239) -> [T#240]
#   Op#95 CONV_2D(T#240, T#78, T#30) -> [T#241]
#   Op#96 CONV_2D(T#241, T#79, T#31) -> [T#242]
#   Op#97 LOGISTIC(T#242) -> [T#243]
#   Op#98 MUL(T#242, T#243) -> [T#244]
#   Op#99 DEPTHWISE_CONV_2D(T#244, T#32, T#3) -> [T#245]
#   Op#100 LOGISTIC(T#245) -> [T#246]
#   Op#101 MUL(T#245, T#246) -> [T#247]
#   Op#102 MEAN(T#247, T#116[1, 2]) -> [T#248]
#   Op#103 SHAPE(T#248) -> [T#249]
#   Op#104 STRIDED_SLICE(T#249, T#119[0], T#120[1], T#120[1]) -> [T#250]
#   Op#105 PACK(T#250, T#117[1], T#117[1], T#118[640]) -> [T#251]
#   Op#106 RESHAPE(T#248, T#251) -> [T#252]
#   Op#107 CONV_2D(T#252, T#80, T#75) -> [T#253]
#   Op#108 LOGISTIC(T#253) -> [T#254]
#   Op#109 MUL(T#253, T#254) -> [T#255]
#   Op#110 CONV_2D(T#255, T#81, T#29) -> [T#256]
#   Op#111 LOGISTIC(T#256) -> [T#257]
#   Op#112 MUL(T#247, T#257) -> [T#258]
#   Op#113 CONV_2D(T#258, T#82, T#33) -> [T#259]
#   Op#114 ADD(T#259, T#241) -> [T#260]
#   Op#115 CONV_2D(T#260, T#83, T#34) -> [T#261]
#   Op#116 LOGISTIC(T#261) -> [T#262]
#   Op#117 MUL(T#261, T#262) -> [T#263]
#   Op#118 DEPTHWISE_CONV_2D(T#263, T#35, T#4) -> [T#264]
#   Op#119 LOGISTIC(T#264) -> [T#265]
#   Op#120 MUL(T#264, T#265) -> [T#266]
#   Op#121 MEAN(T#266, T#116[1, 2]) -> [T#267]
#   Op#122 SHAPE(T#267) -> [T#268]
#   Op#123 STRIDED_SLICE(T#268, T#119[0], T#120[1], T#120[1]) -> [T#269]
#   Op#124 PACK(T#269, T#117[1], T#117[1], T#118[640]) -> [T#270]
#   Op#125 RESHAPE(T#267, T#270) -> [T#271]
#   Op#126 CONV_2D(T#271, T#84, T#75) -> [T#272]
#   Op#127 LOGISTIC(T#272) -> [T#273]
#   Op#128 MUL(T#272, T#273) -> [T#274]
#   Op#129 CONV_2D(T#274, T#85, T#29) -> [T#275]
#   Op#130 LOGISTIC(T#275) -> [T#276]
#   Op#131 MUL(T#266, T#276) -> [T#277]
#   Op#132 CONV_2D(T#277, T#86, T#36) -> [T#278]
#   Op#133 ADD(T#278, T#260) -> [T#279]
#   Op#134 CONV_2D(T#279, T#87, T#37) -> [T#280]
#   Op#135 LOGISTIC(T#280) -> [T#281]
#   Op#136 MUL(T#280, T#281) -> [T#282]
#   Op#137 DEPTHWISE_CONV_2D(T#282, T#38, T#5) -> [T#283]
#   Op#138 LOGISTIC(T#283) -> [T#284]
#   Op#139 MUL(T#283, T#284) -> [T#285]
#   Op#140 MEAN(T#285, T#116[1, 2]) -> [T#286]
#   Op#141 SHAPE(T#286) -> [T#287]
#   Op#142 STRIDED_SLICE(T#287, T#119[0], T#120[1], T#120[1]) -> [T#288]
#   Op#143 PACK(T#288, T#117[1], T#117[1], T#118[640]) -> [T#289]
#   Op#144 RESHAPE(T#286, T#289) -> [T#290]
#   Op#145 CONV_2D(T#290, T#88, T#75) -> [T#291]
#   Op#146 LOGISTIC(T#291) -> [T#292]
#   Op#147 MUL(T#291, T#292) -> [T#293]
#   Op#148 CONV_2D(T#293, T#89, T#29) -> [T#294]
#   Op#149 LOGISTIC(T#294) -> [T#295]
#   Op#150 MUL(T#285, T#295) -> [T#296]
#   Op#151 CONV_2D(T#296, T#90, T#39) -> [T#297]
#   Op#152 ADD(T#297, T#279) -> [T#298]
#   Op#153 CONV_2D(T#298, T#91, T#40) -> [T#299]
#   Op#154 LOGISTIC(T#299) -> [T#300]
#   Op#155 MUL(T#299, T#300) -> [T#301]
#   Op#156 DEPTHWISE_CONV_2D(T#301, T#41, T#6) -> [T#302]
#   Op#157 LOGISTIC(T#302) -> [T#303]
#   Op#158 MUL(T#302, T#303) -> [T#304]
#   Op#159 MEAN(T#304, T#116[1, 2]) -> [T#305]
#   Op#160 SHAPE(T#305) -> [T#306]
#   Op#161 STRIDED_SLICE(T#306, T#119[0], T#120[1], T#120[1]) -> [T#307]
#   Op#162 PACK(T#307, T#117[1], T#117[1], T#118[640]) -> [T#308]
#   Op#163 RESHAPE(T#305, T#308) -> [T#309]
#   Op#164 CONV_2D(T#309, T#92, T#75) -> [T#310]
#   Op#165 LOGISTIC(T#310) -> [T#311]
#   Op#166 MUL(T#310, T#311) -> [T#312]
#   Op#167 CONV_2D(T#312, T#93, T#29) -> [T#313]
#   Op#168 LOGISTIC(T#313) -> [T#314]
#   Op#169 MUL(T#304, T#314) -> [T#315]
#   Op#170 CONV_2D(T#315, T#94, T#42) -> [T#316]
#   Op#171 ADD(T#316, T#298) -> [T#317]
#   Op#172 CONV_2D(T#317, T#95, T#43) -> [T#318]
#   Op#173 LOGISTIC(T#318) -> [T#319]
#   Op#174 MUL(T#318, T#319) -> [T#320]
#   Op#175 DEPTHWISE_CONV_2D(T#320, T#44, T#7) -> [T#321]
#   Op#176 LOGISTIC(T#321) -> [T#322]
#   Op#177 MUL(T#321, T#322) -> [T#323]
#   Op#178 MEAN(T#323, T#116[1, 2]) -> [T#324]
#   Op#179 SHAPE(T#324) -> [T#325]
#   Op#180 STRIDED_SLICE(T#325, T#119[0], T#120[1], T#120[1]) -> [T#326]
#   Op#181 PACK(T#326, T#117[1], T#117[1], T#121[1120]) -> [T#327]
#   Op#182 RESHAPE(T#324, T#327) -> [T#328]
#   Op#183 CONV_2D(T#328, T#97, T#96) -> [T#329]
#   Op#184 LOGISTIC(T#329) -> [T#330]
#   Op#185 MUL(T#329, T#330) -> [T#331]
#   Op#186 CONV_2D(T#331, T#98, T#45) -> [T#332]
#   Op#187 LOGISTIC(T#332) -> [T#333]
#   Op#188 MUL(T#323, T#333) -> [T#334]
#   Op#189 CONV_2D(T#334, T#99, T#46) -> [T#335]
#   Op#190 CONV_2D(T#335, T#100, T#47) -> [T#336]
#   Op#191 LOGISTIC(T#336) -> [T#337]
#   Op#192 MUL(T#336, T#337) -> [T#338]
#   Op#193 DEPTHWISE_CONV_2D(T#338, T#48, T#8) -> [T#339]
#   Op#194 LOGISTIC(T#339) -> [T#340]
#   Op#195 MUL(T#339, T#340) -> [T#341]
#   Op#196 MEAN(T#341, T#116[1, 2]) -> [T#342]
#   Op#197 SHAPE(T#342) -> [T#343]
#   Op#198 STRIDED_SLICE(T#343, T#119[0], T#120[1], T#120[1]) -> [T#344]
#   Op#199 PACK(T#344, T#117[1], T#117[1], T#121[1120]) -> [T#345]
#   Op#200 RESHAPE(T#342, T#345) -> [T#346]
#   Op#201 CONV_2D(T#346, T#101, T#96) -> [T#347]
#   Op#202 LOGISTIC(T#347) -> [T#348]
#   Op#203 MUL(T#347, T#348) -> [T#349]
#   Op#204 CONV_2D(T#349, T#102, T#45) -> [T#350]
#   Op#205 LOGISTIC(T#350) -> [T#351]
#   Op#206 MUL(T#341, T#351) -> [T#352]
#   Op#207 CONV_2D(T#352, T#103, T#49) -> [T#353]
#   Op#208 ADD(T#353, T#335) -> [T#354]
#   Op#209 CONV_2D(T#354, T#104, T#50) -> [T#355]
#   Op#210 LOGISTIC(T#355) -> [T#356]
#   Op#211 MUL(T#355, T#356) -> [T#357]
#   Op#212 DEPTHWISE_CONV_2D(T#357, T#51, T#9) -> [T#358]
#   Op#213 LOGISTIC(T#358) -> [T#359]
#   Op#214 MUL(T#358, T#359) -> [T#360]
#   Op#215 MEAN(T#360, T#116[1, 2]) -> [T#361]
#   Op#216 SHAPE(T#361) -> [T#362]
#   Op#217 STRIDED_SLICE(T#362, T#119[0], T#120[1], T#120[1]) -> [T#363]
#   Op#218 PACK(T#363, T#117[1], T#117[1], T#121[1120]) -> [T#364]
#   Op#219 RESHAPE(T#361, T#364) -> [T#365]
#   Op#220 CONV_2D(T#365, T#105, T#96) -> [T#366]
#   Op#221 LOGISTIC(T#366) -> [T#367]
#   Op#222 MUL(T#366, T#367) -> [T#368]
#   Op#223 CONV_2D(T#368, T#106, T#45) -> [T#369]
#   Op#224 LOGISTIC(T#369) -> [T#370]
#   Op#225 MUL(T#360, T#370) -> [T#371]
#   Op#226 CONV_2D(T#371, T#107, T#52) -> [T#372]
#   Op#227 ADD(T#372, T#354) -> [T#373]
#   Op#228 CONV_2D(T#373, T#108, T#53) -> [T#374]
#   Op#229 LOGISTIC(T#374) -> [T#375]
#   Op#230 MUL(T#374, T#375) -> [T#376]
#   Op#231 DEPTHWISE_CONV_2D(T#376, T#54, T#10) -> [T#377]
#   Op#232 LOGISTIC(T#377) -> [T#378]
#   Op#233 MUL(T#377, T#378) -> [T#379]
#   Op#234 MEAN(T#379, T#116[1, 2]) -> [T#380]
#   Op#235 SHAPE(T#380) -> [T#381]
#   Op#236 STRIDED_SLICE(T#381, T#119[0], T#120[1], T#120[1]) -> [T#382]
#   Op#237 PACK(T#382, T#117[1], T#117[1], T#121[1120]) -> [T#383]
#   Op#238 RESHAPE(T#380, T#383) -> [T#384]
#   Op#239 CONV_2D(T#384, T#109, T#96) -> [T#385]
#   Op#240 LOGISTIC(T#385) -> [T#386]
#   Op#241 MUL(T#385, T#386) -> [T#387]
#   Op#242 CONV_2D(T#387, T#110, T#45) -> [T#388]
#   Op#243 LOGISTIC(T#388) -> [T#389]
#   Op#244 MUL(T#379, T#389) -> [T#390]
#   Op#245 CONV_2D(T#390, T#111, T#55) -> [T#391]
#   Op#246 ADD(T#391, T#373) -> [T#392]
#   Op#247 MUL(T#392, T#141) -> [T#393]
#   Op#248 ADD(T#393, T#142) -> [T#394]
#   Op#249 CONV_2D(T#394, T#112, T#11) -> [T#395]
#   Op#250 REDUCE_MAX(T#395, T#116[1, 2]) -> [T#396]
#   Op#251 REDUCE_MAX(T#395, T#116[1, 2]) -> [T#397]
#   Op#252 SUB(T#395, T#396) -> [T#398]
#   Op#253 MUL(T#398, T#113) -> [T#399]
#   Op#254 EXP(T#399) -> [T#400]
#   Op#255 MEAN(T#400, T#116[1, 2]) -> [T#401]
#   Op#256 LOG(T#401) -> [T#402]
#   Op#257 MUL(T#402, T#114) -> [T#403]
#   Op#258 ADD(T#403, T#397) -> [T#404]
#   Op#259 FULLY_CONNECTED(T#404, T#143, T#115) -> [T#405]
#   Op#260 SOFTMAX(T#405) -> [T#406]
#
# Tensors of Subgraph#0
#   T#0(serving_default_INPUT:0) shape_signature:[-1, 144000], type:FLOAT32
#   T#1(model_1/BNORM_0/FusedBatchNormV3) shape:[30], type:FLOAT32 RO 120 bytes, buffer: 2, data:[-0.0201999, 0.021001, -0.00927022, 0.157607, 1.64969, ...]
#   T#2(model_1/BLOCK_3-1_BN_2_NOQUANT/FusedBatchNormV3) shape:[640], type:FLOAT32 RO 2560 bytes, buffer: 3, data:[0.507101, 0.170648, 0.0986953, 0.264744, 0.368448, ...]
#   T#3(model_1/BLOCK_3-2_BN_2_NOQUANT/FusedBatchNormV3) shape:[640], type:FLOAT32 RO 2560 bytes, buffer: 4, data:[0.156241, 0.10379, -0.12009, 0.251382, -0.321336, ...]
#   T#4(model_1/BLOCK_3-3_BN_2_NOQUANT/FusedBatchNormV3) shape:[640], type:FLOAT32 RO 2560 bytes, buffer: 5, data:[-0.052932, -0.15776, -0.162979, -1.74901, -0.0601944, ...]
#   T#5(model_1/BLOCK_3-4_BN_2_NOQUANT/FusedBatchNormV3) shape:[640], type:FLOAT32 RO 2560 bytes, buffer: 6, data:[-0.167197, -0.627172, -0.118439, -0.0867302, -0.0966517, ...]
#   T#6(model_1/BLOCK_3-5_BN_2_NOQUANT/FusedBatchNormV3) shape:[640], type:FLOAT32 RO 2560 bytes, buffer: 7, data:[0.199295, -0.693983, -0.0609956, -0.305395, -0.0527331, ...]
#   T#7(model_1/BLOCK_4-1_BN_2_NOQUANT/FusedBatchNormV3) shape:[1120], type:FLOAT32 RO 4480 bytes, buffer: 8, data:[-0.213642, 0.0989731, 0.289327, 0.228966, -0.0641489, ...]
#   T#8(model_1/BLOCK_4-2_BN_2_NOQUANT/FusedBatchNormV3) shape:[1120], type:FLOAT32 RO 4480 bytes, buffer: 9, data:[0.00732364, -0.15787, -0.631158, -0.106697, 0.0196075, ...]
#   T#9(model_1/BLOCK_4-3_BN_2_NOQUANT/FusedBatchNormV3) shape:[1120], type:FLOAT32 RO 4480 bytes, buffer: 10, data:[0.0843629, -0.0535078, -0.136284, -0.35959, 0.137284, ...]
#   T#10(model_1/BLOCK_4-4_BN_2_NOQUANT/FusedBatchNormV3) shape:[1120], type:FLOAT32 RO 4480 bytes, buffer: 11, data:[0.03562, -0.442556, 0.242526, -0.189173, -0.137097, ...]
#   T#11(model_1/POST_BN_1/FusedBatchNormV3) shape:[420], type:FLOAT32 RO 1680 bytes, buffer: 12, data:[0.703291, 0.151619, 0.929611, 1.05721, -0.0952325, ...]
#   T#12(model_1/pool_0_CONV/BiasAdd/ReadVariableOp) shape:[30], type:FLOAT32 RO 120 bytes, buffer: 13, data:[0.177993, -0.00336044, 1.49043, 0.208713, -0.283743, ...]
#   T#13(model_1/BLOCK_1-1_BN_1/FusedBatchNormV3) shape:[60], type:FLOAT32 RO 240 bytes, buffer: 14, data:[0.994801, 1.30954, 1.39498, 2.66734, 0.875943, ...]
#   T#14(model_1/BLOCK_1-1_BN_3/FusedBatchNormV3) shape:[60], type:FLOAT32 RO 240 bytes, buffer: 15, data:[-0.572335, -0.296768, -1.17371, -0.676895, 1.66753, ...]
#   T#15(model_1/BLOCK_1-2_BN_1/FusedBatchNormV3) shape:[60], type:FLOAT32 RO 240 bytes, buffer: 16, data:[-2.62731, -0.868263, 0.266521, 0.0349529, 0.854639, ...]
#   T#16(model_1/BLOCK_1-2_BN_3/FusedBatchNormV3) shape:[60], type:FLOAT32 RO 240 bytes, buffer: 17, data:[-0.463809, 0.940085, -1.53324, 1.37461, 0.36683, ...]
#   T#17(model_1/BLOCK_1-3_BN_1/FusedBatchNormV3) shape:[60], type:FLOAT32 RO 240 bytes, buffer: 18, data:[1.23824, 1.12686, 1.3523, -0.914098, 1.96378, ...]
#   T#18(model_1/BLOCK_1-3_BN_3/FusedBatchNormV3) shape:[60], type:FLOAT32 RO 240 bytes, buffer: 19, data:[0.224621, -0.89843, -0.404808, 2.08627, 0.154646, ...]
#   T#19(model_1/BLOCK_2-1_BN_1/FusedBatchNormV3) shape:[240], type:FLOAT32 RO 960 bytes, buffer: 20, data:[1.08094, 1.82718, 1.35988, 2.0496, 1.56324, ...]
#   T#20(model_1/BLOCK_2-1_BN_3/FusedBatchNormV3) shape:[120], type:FLOAT32 RO 480 bytes, buffer: 21, data:[0.517984, 1.20353, -0.631186, -0.242215, -0.117523, ...]
#   T#21(model_1/BLOCK_2-2_BN_1/FusedBatchNormV3) shape:[240], type:FLOAT32 RO 960 bytes, buffer: 22, data:[-0.453432, 0.0377011, 0.029025, -1.10252, 1.40118, ...]
#   T#22(model_1/BLOCK_2-2_BN_3/FusedBatchNormV3) shape:[120], type:FLOAT32 RO 480 bytes, buffer: 23, data:[-0.26637, 0.121703, 0.097885, -0.248943, 0.0860163, ...]
#   T#23(model_1/BLOCK_2-3_BN_1/FusedBatchNormV3) shape:[240], type:FLOAT32 RO 960 bytes, buffer: 24, data:[-0.624671, -0.705771, -0.00291157, -0.566265, 0.401846, ...]
#   T#24(model_1/BLOCK_2-3_BN_3/FusedBatchNormV3) shape:[120], type:FLOAT32 RO 480 bytes, buffer: 25, data:[-0.334773, 0.358166, 0.595261, 0.789514, 0.299735, ...]
#   T#25(model_1/BLOCK_2-4_BN_1/FusedBatchNormV3) shape:[240], type:FLOAT32 RO 960 bytes, buffer: 26, data:[-0.0566794, -0.325451, -0.0834246, 0.0485905, -0.249119, ...]
#   T#26(model_1/BLOCK_2-4_BN_3/FusedBatchNormV3) shape:[120], type:FLOAT32 RO 480 bytes, buffer: 27, data:[-1.07128, -0.719374, 0.521283, -0.52695, 0.637195, ...]
#   T#27(model_1/BLOCK_3-1_BN_1/FusedBatchNormV3) shape:[640], type:FLOAT32 RO 2560 bytes, buffer: 28, data:[0.453774, -0.53238, 0.144864, 0.0808757, -0.600901, ...]
#   T#28(model_1/BLOCK_3-1_BN_2_NOQUANT/FusedBatchNormV3;model_1/BLOCK_3-1_CONV_2/depthwise;model_1/BLOCK_3-5_SE_CONV_2/Conv2D) shape:[1, 3, 3, 640], type:FLOAT32 RO 23040 bytes, buffer: 29, data:[-0.251236, 0.372286, -0.59223, -0.1335, 0.312628, ...]
#   T#29(model_1/BLOCK_3-5_SE_CONV_2/Conv2D) shape:[640], type:FLOAT32 RO 2560 bytes, buffer: 30, data:[0, 0, 0, 0, 0, ...]
#   T#30(model_1/BLOCK_3-1_BN_3/FusedBatchNormV3) shape:[160], type:FLOAT32 RO 640 bytes, buffer: 31, data:[0.028477, -0.247231, -0.271764, -0.436009, -0.0308246, ...]
#   T#31(model_1/BLOCK_3-2_BN_1/FusedBatchNormV3) shape:[640], type:FLOAT32 RO 2560 bytes, buffer: 32, data:[-0.530656, 0.133959, 0.382794, -0.28108, -0.106207, ...]
#   T#32(model_1/BLOCK_3-2_BN_2_NOQUANT/FusedBatchNormV3;model_1/BLOCK_3-2_CONV_2/depthwise;model_1/BLOCK_3-5_SE_CONV_2/Conv2D) shape:[1, 3, 3, 640], type:FLOAT32 RO 23040 bytes, buffer: 33, data:[1.23551, -0.0568431, 0.0760742, -0.370292, 0.0261757, ...]
#   T#33(model_1/BLOCK_3-2_BN_3/FusedBatchNormV3) shape:[160], type:FLOAT32 RO 640 bytes, buffer: 34, data:[-0.245983, -0.00641132, -0.0371882, 0.126828, -0.0948737, ...]
#   T#34(model_1/BLOCK_3-3_BN_1/FusedBatchNormV3) shape:[640], type:FLOAT32 RO 2560 bytes, buffer: 35, data:[1.04701, 0.565516, -0.577064, 0.252158, -0.205602, ...]
#   T#35(model_1/BLOCK_3-3_BN_2_NOQUANT/FusedBatchNormV3;model_1/BLOCK_3-3_CONV_2/depthwise;model_1/BLOCK_3-5_SE_CONV_2/Conv2D) shape:[1, 3, 3, 640], type:FLOAT32 RO 23040 bytes, buffer: 36, data:[0.123467, -0.0474579, 0.25923, -0.762767, -0.0930023, ...]
#   T#36(model_1/BLOCK_3-3_BN_3/FusedBatchNormV3) shape:[160], type:FLOAT32 RO 640 bytes, buffer: 37, data:[0.00867989, -0.0112237, -0.166217, 0.266443, -0.436209, ...]
#   T#37(model_1/BLOCK_3-4_BN_1/FusedBatchNormV3) shape:[640], type:FLOAT32 RO 2560 bytes, buffer: 38, data:[-0.280375, 0.916876, -0.271838, 0.260631, 0.065035, ...]
#   T#38(model_1/BLOCK_3-4_BN_2_NOQUANT/FusedBatchNormV3;model_1/BLOCK_3-4_CONV_2/depthwise;model_1/BLOCK_3-5_SE_CONV_2/Conv2D) shape:[1, 3, 3, 640], type:FLOAT32 RO 23040 bytes, buffer: 39, data:[-0.10532, -0.530738, 0.000815318, 0.0100449, 0.0389737, ...]
#   T#39(model_1/BLOCK_3-4_BN_3/FusedBatchNormV3) shape:[160], type:FLOAT32 RO 640 bytes, buffer: 40, data:[0.0162673, -0.223772, -0.0793594, 0.196439, 0.0911259, ...]
#   T#40(model_1/BLOCK_3-5_BN_1/FusedBatchNormV3) shape:[640], type:FLOAT32 RO 2560 bytes, buffer: 41, data:[-1.13443, 0.0416078, -0.161235, -1.03465, -0.414547, ...]
#   T#41(model_1/BLOCK_3-5_BN_2_NOQUANT/FusedBatchNormV3;model_1/BLOCK_3-5_CONV_2/depthwise;model_1/BLOCK_3-5_SE_CONV_2/Conv2D) shape:[1, 3, 3, 640], type:FLOAT32 RO 23040 bytes, buffer: 42, data:[0.358909, -0.200586, 1.62531, 0.189931, 0.597165, ...]
#   T#42(model_1/BLOCK_3-5_BN_3/FusedBatchNormV3) shape:[160], type:FLOAT32 RO 640 bytes, buffer: 43, data:[-0.0729527, -0.140453, -0.256495, 0.00789576, -0.0750102, ...]
#   T#43(model_1/BLOCK_4-1_BN_1/FusedBatchNormV3) shape:[1120], type:FLOAT32 RO 4480 bytes, buffer: 44, data:[-0.501423, -0.781778, -1.06513, -0.807659, -0.451615, ...]
#   T#44(model_1/BLOCK_4-1_BN_2_NOQUANT/FusedBatchNormV3;model_1/BLOCK_4-1_CONV_2/depthwise;model_1/BLOCK_4-4_SE_CONV_2/Conv2D) shape:[1, 3, 3, 1120], type:FLOAT32 RO 40320 bytes, buffer: 45, data:[-0.313297, -0.692159, 1.42914, -0.135559, -0.402629, ...]
#   T#45(model_1/BLOCK_4-4_SE_CONV_2/Conv2D) shape:[1120], type:FLOAT32 RO 4480 bytes, buffer: 46, data:[0, 0, 0, 0, 0, ...]
#   T#46(model_1/BLOCK_4-1_BN_3/FusedBatchNormV3) shape:[280], type:FLOAT32 RO 1120 bytes, buffer: 47, data:[0.00707362, -0.11092, -0.271591, -0.0480711, 0.1141, ...]
#   T#47(model_1/BLOCK_4-2_BN_1/FusedBatchNormV3) shape:[1120], type:FLOAT32 RO 4480 bytes, buffer: 48, data:[0.214278, 0.192685, 0.0268124, -0.538281, -0.227158, ...]
#   T#48(model_1/BLOCK_4-2_BN_2_NOQUANT/FusedBatchNormV3;model_1/BLOCK_4-2_CONV_2/depthwise;model_1/BLOCK_4-4_SE_CONV_2/Conv2D) shape:[1, 3, 3, 1120], type:FLOAT32 RO 40320 bytes, buffer: 49, data:[-0.791778, -0.210047, -0.88355, -0.441906, -0.494887, ...]
#   T#49(model_1/BLOCK_4-2_BN_3/FusedBatchNormV3) shape:[280], type:FLOAT32 RO 1120 bytes, buffer: 50, data:[-0.0310575, -0.01638, -0.0170814, -0.0743111, -0.0226622, ...]
#   T#50(model_1/BLOCK_4-3_BN_1/FusedBatchNormV3) shape:[1120], type:FLOAT32 RO 4480 bytes, buffer: 51, data:[-0.212481, -1.1889, -0.0504375, 0.146119, -0.779445, ...]
#   T#51(model_1/BLOCK_4-3_BN_2_NOQUANT/FusedBatchNormV3;model_1/BLOCK_4-3_CONV_2/depthwise;model_1/BLOCK_4-4_SE_CONV_2/Conv2D) shape:[1, 3, 3, 1120], type:FLOAT32 RO 40320 bytes, buffer: 52, data:[-0.734297, 0.403795, -5.34587, 0.876589, 0.309243, ...]
#   T#52(model_1/BLOCK_4-3_BN_3/FusedBatchNormV3) shape:[280], type:FLOAT32 RO 1120 bytes, buffer: 53, data:[0.0840644, -0.110269, -0.105898, -0.161293, -0.123441, ...]
#   T#53(model_1/BLOCK_4-4_BN_1/FusedBatchNormV3) shape:[1120], type:FLOAT32 RO 4480 bytes, buffer: 54, data:[-1.24407, -0.0376666, -1.2601, -0.504979, -0.504578, ...]
#   T#54(model_1/BLOCK_4-4_BN_2_NOQUANT/FusedBatchNormV3;model_1/BLOCK_4-4_CONV_2/depthwise;model_1/BLOCK_4-4_SE_CONV_2/Conv2D) shape:[1, 3, 3, 1120], type:FLOAT32 RO 40320 bytes, buffer: 55, data:[-0.213518, -0.135148, -0.603809, -0.559516, -0.379189, ...]
#   T#55(model_1/BLOCK_4-4_BN_3/FusedBatchNormV3) shape:[280], type:FLOAT32 RO 1120 bytes, buffer: 56, data:[-0.303293, -0.566926, -0.164678, -0.409574, -0.311323, ...]
#   T#56(stft/rfft;stft/rfft) shape:[], type:INT32 RO 4 bytes, buffer: 57, data:[-2]
#   T#57(stft/rfft;stft/rfft1) shape:[2], type:INT32 RO 8 bytes, buffer: 58, data:[1, 512]
#   T#58(model_1/CONV_0/Conv2D) shape:[30, 4, 8, 1], type:FLOAT32 RO 3840 bytes, buffer: 59, data:[-0.114492, -0.237609, -0.215151, -0.182603, -0.0288566, ...]
#   T#59(model_1/pool_0_CONV/Conv2D) shape:[30, 1, 1, 60], type:FLOAT32 RO 7200 bytes, buffer: 60, data:[0.449749, 0.183205, -0.323894, 0.0894036, 0.0372021, ...]
#   T#60(model_1/BLOCK_1-1_CONV_1/Conv2D) shape:[60, 3, 3, 30], type:FLOAT32 RO 64800 bytes, buffer: 61, data:[-0.024668, 0.0393796, -0.00368801, 0.0139366, 0.0272781, ...]
#   T#61(model_1/BLOCK_1-1_CONV_3/Conv2D) shape:[60, 1, 1, 60], type:FLOAT32 RO 14400 bytes, buffer: 62, data:[0.0903042, -0.0224403, 0.279139, 0.140995, -0.201996, ...]
#   T#62(model_1/BLOCK_1-2_CONV_1/Conv2D) shape:[60, 3, 3, 60], type:FLOAT32 RO 129600 bytes, buffer: 63, data:[0.00565977, -0.0041388, 0.000459343, -0.0186408, 0.00484244, ...]
#   T#63(model_1/BLOCK_1-2_CONV_3/Conv2D) shape:[60, 1, 1, 60], type:FLOAT32 RO 14400 bytes, buffer: 64, data:[-0.0832476, -0.232616, 0.087849, -0.123365, -0.185093, ...]
#   T#64(model_1/BLOCK_1-3_CONV_1/Conv2D) shape:[60, 3, 3, 60], type:FLOAT32 RO 129600 bytes, buffer: 65, data:[0.0081317, 0.0289496, -0.000417384, -0.00211003, 0.0340565, ...]
#   T#65(model_1/BLOCK_1-3_CONV_3/Conv2D) shape:[60, 1, 1, 60], type:FLOAT32 RO 14400 bytes, buffer: 66, data:[-1.06982, 0.00182795, -0.394202, 0.0216375, -0.540149, ...]
#   T#66(model_1/BLOCK_2-1_CONV_1/Conv2D) shape:[240, 3, 3, 60], type:FLOAT32 RO 518400 bytes, buffer: 67, data:[0.00682351, -0.0175564, 0.0204914, 0.0128379, -0.0155376, ...]
#   T#67(model_1/BLOCK_2-1_CONV_3/Conv2D) shape:[120, 1, 1, 240], type:FLOAT32 RO 115200 bytes, buffer: 68, data:[-0.135052, 0.0525188, 0.0256257, 0.037241, 0.0417646, ...]
#   T#68(model_1/BLOCK_2-2_CONV_1/Conv2D) shape:[240, 3, 3, 120], type:FLOAT32 RO 1036800 bytes, buffer: 69, data:[0.00415435, -0.00527662, 0.0250746, 0.00708887, -0.00520974, ...]
#   T#69(model_1/BLOCK_2-2_CONV_3/Conv2D) shape:[120, 1, 1, 240], type:FLOAT32 RO 115200 bytes, buffer: 70, data:[-0.231138, -0.155019, 0.0335709, -0.048346, -0.0636056, ...]
#   T#70(model_1/BLOCK_2-3_CONV_1/Conv2D) shape:[240, 3, 3, 120], type:FLOAT32 RO 1036800 bytes, buffer: 71, data:[-0.00990321, 0.00305605, -0.022679, 0.00943848, 0.0178133, ...]
#   T#71(model_1/BLOCK_2-3_CONV_3/Conv2D) shape:[120, 1, 1, 240], type:FLOAT32 RO 115200 bytes, buffer: 72, data:[0.151803, -0.211548, 0.656866, 0.313801, 0.534047, ...]
#   T#72(model_1/BLOCK_2-4_CONV_1/Conv2D) shape:[240, 3, 3, 120], type:FLOAT32 RO 1036800 bytes, buffer: 73, data:[-0.00882176, -0.00886716, 0.0172686, -0.0173403, -0.0128443, ...]
#   T#73(model_1/BLOCK_2-4_CONV_3/Conv2D) shape:[120, 1, 1, 240], type:FLOAT32 RO 115200 bytes, buffer: 74, data:[0.514776, -0.170025, -0.492848, -0.127949, 0.0632972, ...]
#   T#74(model_1/BLOCK_3-1_CONV_1/Conv2D) shape:[640, 1, 1, 120], type:FLOAT32 RO 307200 bytes, buffer: 75, data:[0.027395, -0.00337426, 0.0371208, 0.0296344, 0.0550245, ...]
#   T#75(model_1/BLOCK_3-5_SE_CONV_1/Conv2D) shape:[40], type:FLOAT32 RO 160 bytes, buffer: 76, data:[0, 0, 0, 0, 0, ...]
#   T#76(model_1/BLOCK_3-1_SE_CONV_1/Conv2D) shape:[40, 1, 1, 640], type:FLOAT32 RO 102400 bytes, buffer: 77, data:[-0.109894, -0.250427, 0.248698, 0.197855, -0.148598, ...]
#   T#77(model_1/BLOCK_3-1_SE_CONV_2/Conv2D) shape:[640, 1, 1, 40], type:FLOAT32 RO 102400 bytes, buffer: 78, data:[0.477402, 0.774508, 0.414591, 0.138802, -0.0958745, ...]
#   T#78(model_1/BLOCK_3-1_CONV_3/Conv2D) shape:[160, 1, 1, 640], type:FLOAT32 RO 409600 bytes, buffer: 79, data:[0.183485, -0.0989058, -0.0867138, -0.158595, 0.155576, ...]
#   T#79(model_1/BLOCK_3-2_CONV_1/Conv2D) shape:[640, 1, 1, 160], type:FLOAT32 RO 409600 bytes, buffer: 80, data:[0.0597176, -0.0259545, -0.000706167, -0.0420036, -0.0490324, ...]
#   T#80(model_1/BLOCK_3-2_SE_CONV_1/Conv2D) shape:[40, 1, 1, 640], type:FLOAT32 RO 102400 bytes, buffer: 81, data:[0.324125, 0.138069, 0.466153, -0.375846, 0.431644, ...]
#   T#81(model_1/BLOCK_3-2_SE_CONV_2/Conv2D) shape:[640, 1, 1, 40], type:FLOAT32 RO 102400 bytes, buffer: 82, data:[0.317052, -0.00767023, -0.111318, -0.0870155, -0.0846622, ...]
#   T#82(model_1/BLOCK_3-2_CONV_3/Conv2D) shape:[160, 1, 1, 640], type:FLOAT32 RO 409600 bytes, buffer: 83, data:[0.0697687, -0.206735, 0.109114, 0.121937, 0.0107974, ...]
#   T#83(model_1/BLOCK_3-3_CONV_1/Conv2D) shape:[640, 1, 1, 160], type:FLOAT32 RO 409600 bytes, buffer: 84, data:[0.0131174, 0.00535706, 0.0266619, -0.0648822, 2.78373e-05, ...]
#   T#84(model_1/BLOCK_3-3_SE_CONV_1/Conv2D) shape:[40, 1, 1, 640], type:FLOAT32 RO 102400 bytes, buffer: 85, data:[0.0227193, -0.0669719, 1.52158, -0.018394, 0.124296, ...]
#   T#85(model_1/BLOCK_3-3_SE_CONV_2/Conv2D) shape:[640, 1, 1, 40], type:FLOAT32 RO 102400 bytes, buffer: 86, data:[0.00274766, 0.154431, -0.3122, -0.710318, -0.0499839, ...]
#   T#86(model_1/BLOCK_3-3_CONV_3/Conv2D) shape:[160, 1, 1, 640], type:FLOAT32 RO 409600 bytes, buffer: 87, data:[0.216798, 0.0985736, 0.122017, 0.0663547, -0.0423421, ...]
#   T#87(model_1/BLOCK_3-4_CONV_1/Conv2D) shape:[640, 1, 1, 160], type:FLOAT32 RO 409600 bytes, buffer: 88, data:[-0.0530763, 0.030002, -0.00109313, 0.00830229, 0.0295681, ...]
#   T#88(model_1/BLOCK_3-4_SE_CONV_1/Conv2D) shape:[40, 1, 1, 640], type:FLOAT32 RO 102400 bytes, buffer: 89, data:[0.335489, -0.0140383, -0.2259, 0.299023, -0.151196, ...]
#   T#89(model_1/BLOCK_3-4_SE_CONV_2/Conv2D) shape:[640, 1, 1, 40], type:FLOAT32 RO 102400 bytes, buffer: 90, data:[-0.275259, 0.620791, -0.201793, -0.390887, 0.389617, ...]
#   T#90(model_1/BLOCK_3-4_CONV_3/Conv2D) shape:[160, 1, 1, 640], type:FLOAT32 RO 409600 bytes, buffer: 91, data:[0.008953, -0.178044, 0.10984, 0.027595, -0.019051, ...]
#   T#91(model_1/BLOCK_3-5_CONV_1/Conv2D) shape:[640, 1, 1, 160], type:FLOAT32 RO 409600 bytes, buffer: 92, data:[-0.0592428, -0.0289971, -0.0524392, 0.0252963, -0.00123223, ...]
#   T#92(model_1/BLOCK_3-5_SE_CONV_1/Conv2D1) shape:[40, 1, 1, 640], type:FLOAT32 RO 102400 bytes, buffer: 93, data:[0.43411, -0.114498, -0.0396519, 0.3074, 0.0421896, ...]
#   T#93(model_1/BLOCK_3-5_SE_CONV_2/Conv2D1) shape:[640, 1, 1, 40], type:FLOAT32 RO 102400 bytes, buffer: 94, data:[-0.297735, 0.290233, -0.57969, 0.101273, 0.230248, ...]
#   T#94(model_1/BLOCK_3-5_CONV_3/Conv2D) shape:[160, 1, 1, 640], type:FLOAT32 RO 409600 bytes, buffer: 95, data:[0.0355608, 0.139506, -0.0253758, -0.116553, -0.247544, ...]
#   T#95(model_1/BLOCK_4-1_CONV_1/Conv2D) shape:[1120, 1, 1, 160], type:FLOAT32 RO 716800 bytes, buffer: 96, data:[-0.0420035, 0.0268913, 0.0743375, -0.00304259, 0.0097754, ...]
#   T#96(model_1/BLOCK_4-4_SE_CONV_1/Conv2D) shape:[70], type:FLOAT32 RO 280 bytes, buffer: 97, data:[0, 0, 0, 0, 0, ...]
#   T#97(model_1/BLOCK_4-1_SE_CONV_1/Conv2D) shape:[70, 1, 1, 1120], type:FLOAT32 RO 313600 bytes, buffer: 98, data:[-0.114728, -0.486454, -0.0725451, -0.105543, 0.206242, ...]
#   T#98(model_1/BLOCK_4-1_SE_CONV_2/Conv2D) shape:[1120, 1, 1, 70], type:FLOAT32 RO 313600 bytes, buffer: 99, data:[0.0107329, -0.25262, 0.189735, 0.519728, 0.306989, ...]
#   T#99(model_1/BLOCK_4-1_CONV_3/Conv2D) shape:[280, 1, 1, 1120], type:FLOAT32 RO 1254400 bytes, buffer: 100, data:[0.155144, 0.03334, -0.0436219, -0.0635754, -0.0201717, ...]
#   T#100(model_1/BLOCK_4-2_CONV_1/Conv2D) shape:[1120, 1, 1, 280], type:FLOAT32 RO 1254400 bytes, buffer: 101, data:[0.0775721, 0.0300743, 0.0787118, 0.033277, 0.0518173, ...]
#   T#101(model_1/BLOCK_4-2_SE_CONV_1/Conv2D) shape:[70, 1, 1, 1120], type:FLOAT32 RO 313600 bytes, buffer: 102, data:[-0.432114, -0.0357772, -0.146629, 0.377912, -0.445993, ...]
#   T#102(model_1/BLOCK_4-2_SE_CONV_2/Conv2D) shape:[1120, 1, 1, 70], type:FLOAT32 RO 313600 bytes, buffer: 103, data:[-0.0556371, 0.0161514, -0.236468, 0.562922, 0.757015, ...]
#   T#103(model_1/BLOCK_4-2_CONV_3/Conv2D) shape:[280, 1, 1, 1120], type:FLOAT32 RO 1254400 bytes, buffer: 104, data:[-0.0254576, -0.0813834, 0.019934, -0.0212499, 0.0630072, ...]
#   T#104(model_1/BLOCK_4-3_CONV_1/Conv2D) shape:[1120, 1, 1, 280], type:FLOAT32 RO 1254400 bytes, buffer: 105, data:[0.084308, -0.104739, -0.11943, 0.137802, -0.100788, ...]
#   T#105(model_1/BLOCK_4-3_SE_CONV_1/Conv2D) shape:[70, 1, 1, 1120], type:FLOAT32 RO 313600 bytes, buffer: 106, data:[-0.480569, -0.185401, -0.246157, -0.254998, 0.0226147, ...]
#   T#106(model_1/BLOCK_4-3_SE_CONV_2/Conv2D) shape:[1120, 1, 1, 70], type:FLOAT32 RO 313600 bytes, buffer: 107, data:[0.76853, 0.272858, -0.0406274, 0.128225, -0.261265, ...]
#   T#107(model_1/BLOCK_4-3_CONV_3/Conv2D) shape:[280, 1, 1, 1120], type:FLOAT32 RO 1254400 bytes, buffer: 108, data:[-0.103587, 0.0651307, 0.0905246, 0.0311029, 0.0932062, ...]
#   T#108(model_1/BLOCK_4-4_CONV_1/Conv2D) shape:[1120, 1, 1, 280], type:FLOAT32 RO 1254400 bytes, buffer: 109, data:[0.140507, 0.0259408, -0.00318167, 0.0121001, 0.0472033, ...]
#   T#109(model_1/BLOCK_4-4_SE_CONV_1/Conv2D1) shape:[70, 1, 1, 1120], type:FLOAT32 RO 313600 bytes, buffer: 110, data:[-0.0174236, -0.051295, -0.0601223, 0.0875765, 0.0552255, ...]
#   T#110(model_1/BLOCK_4-4_SE_CONV_2/Conv2D1) shape:[1120, 1, 1, 70], type:FLOAT32 RO 313600 bytes, buffer: 111, data:[-0.212755, -0.172498, -0.269743, -0.014416, -0.32258, ...]
#   T#111(model_1/BLOCK_4-4_CONV_3/Conv2D) shape:[280, 1, 1, 1120], type:FLOAT32 RO 1254400 bytes, buffer: 112, data:[0.0212589, 0.056527, 0.0380439, 0.0511093, -0.128075, ...]
#   T#112(model_1/POST_CONV_1/Conv2D) shape:[420, 3, 3, 280], type:FLOAT32 RO 4233600 bytes, buffer: 113, data:[-0.0291094, -0.0061691, 0.0503138, 0.0581343, 0.0575725, ...]
#   T#113(ReadVariableOp;ReadVariableOp) shape:[1], type:FLOAT32 RO 4 bytes, buffer: 114, data:[1.46607]
#   T#114(truediv;truediv;ReadVariableOp;ReadVariableOp) shape:[1], type:FLOAT32 RO 4 bytes, buffer: 115, data:[0.682098]
#   T#115(model_1/dense/BiasAdd/ReadVariableOp) shape:[2], type:FLOAT32 RO 8 bytes, buffer: 116, data:[0.0144904, -0.016352]
#   T#116(model_1/BLOCK_3-1_SE_AVG_POOL_1/Mean/reduction_indices) shape:[2], type:INT32 RO 8 bytes, buffer: 117, data:[1, 2]
#   T#117(model_1/BLOCK_3-1_SE_RESHAPE/Reshape/shape/1) shape:[], type:INT32 RO 4 bytes, buffer: 118, data:[1]
#   T#118(model_1/BLOCK_3-1_SE_RESHAPE/Reshape/shape/3) shape:[], type:INT32 RO 4 bytes, buffer: 119, data:[640]
#   T#119(model_1/BLOCK_3-1_SE_RESHAPE/strided_slice/stack) shape:[1], type:INT32 RO 4 bytes, buffer: 120, data:[0]
#   T#120(model_1/BLOCK_3-1_SE_RESHAPE/strided_slice/stack_1) shape:[1], type:INT32 RO 4 bytes, buffer: 118, data:[1]
#   T#121(model_1/BLOCK_4-1_SE_RESHAPE/Reshape/shape/3) shape:[], type:INT32 RO 4 bytes, buffer: 122, data:[1120]
#   T#122(truediv_1;truediv_1) shape:[], type:FLOAT32 RO 4 bytes, buffer: 123, data:[0.262867]
#   T#123(stft/hann_window/sub_2;stft/hann_window/sub_2) shape:[512], type:FLOAT32 RO 2048 bytes, buffer: 124, data:[0, 3.76403e-05, 0.000150591, 0.000338793, 0.000602275, ...]
#   T#124(stft/frame/Reshape_3;stft/frame/Reshape_3) shape:[1, 64], type:INT32 RO 256 bytes, buffer: 125, data:[0, 1, 2, 3, 4, ...]
#   T#125(stft/frame/packed;stft/frame/packed) shape:[3], type:INT32 RO 12 bytes, buffer: 126, data:[1, 1, 0]
#   T#126(stft/frame/ones_like;stft/frame/ones_like) shape:[2], type:INT32 RO 8 bytes, buffer: 127, data:[1, 1]
#   T#127(stft/frame/floordiv_2;stft/frame/floordiv_2) shape:[], type:INT32 RO 4 bytes, buffer: 128, data:[35]
#   T#128(transpose/perm;transpose/perm) shape:[3], type:INT32 RO 12 bytes, buffer: 129, data:[0, 2, 1]
#   T#129(strided_slice/stack_2;strided_slice/stack_2) shape:[3], type:INT32 RO 12 bytes, buffer: 130, data:[1, 1, 1]
#   T#130(strided_slice/stack_1;strided_slice/stack_1) shape:[3], type:INT32 RO 12 bytes, buffer: 131, data:[0, 0, 128]
#   T#131(strided_slice/stack;strided_slice/stack) shape:[3], type:INT32 RO 12 bytes, buffer: 132, data:[0, 0, 0]
#   T#132(stft/frame_step;stft/frame_step) shape:[], type:INT32 RO 4 bytes, buffer: 133, data:[280]
#   T#133(stft/frame_length;stft/frame_length) shape:[], type:INT32 RO 4 bytes, buffer: 134, data:[512]
#   T#134(stft/frame/zeros_like;stft/frame/zeros_like) shape:[2], type:INT32 RO 8 bytes, buffer: 135, data:[0, 0]
#   T#135(stft/frame/concat_1/values_1/1;stft/frame/concat_1/values_1/1) shape:[], type:INT32 RO 4 bytes, buffer: 136, data:[8]
#   T#136(stft/frame/Reshape/shape_1;stft/frame/Reshape/shape_1) shape:[0], type:INT32
#   T#137(stft/frame/Maximum/x;stft/frame/Maximum/x) shape:[], type:INT32 RO 4 bytes, buffer: 120, data:[0]
#   T#138(ExpandDims/dim;ExpandDims/dim) shape:[], type:INT32 RO 4 bytes, buffer: 139, data:[-1]
#   T#139(model_1/BNORM_SPEC_NOQUANT/FusedBatchNormV3) shape:[1], type:FLOAT32 RO 4 bytes, buffer: 140, data:[1.24676]
#   T#140(model_1/BNORM_SPEC_NOQUANT/FusedBatchNormV31) shape:[1], type:FLOAT32 RO 4 bytes, buffer: 141, data:[-0.118066]
#   T#141(model_1/BNORM_POST_NOQUANT/FusedBatchNormV3) shape:[280], type:FLOAT32 RO 1120 bytes, buffer: 142, data:[0.346286, 0.419046, 0.374378, 0.392926, 0.321534, ...]
#   T#142(model_1/BNORM_POST_NOQUANT/FusedBatchNormV31) shape:[280], type:FLOAT32 RO 1120 bytes, buffer: 143, data:[0.374975, 0.296045, 0.377884, 0.231385, 0.356721, ...]
#   T#143(model_1/dense/MatMul) shape:[2, 420], type:FLOAT32 RO 3360 bytes, buffer: 144, data:[0.00493107, 0.0835277, 0.109784, 0.129706, -0.102322, ...]
#   T#144(Min;Min) shape_signature:[-1, 1], type:FLOAT32
#   T#145(Sub;Sub) shape_signature:[-1, 144000], type:FLOAT32
#   T#146(Max;Max) shape_signature:[-1, 1], type:FLOAT32
#   T#147(truediv;truediv) shape_signature:[-1, 144000], type:FLOAT32
#   T#148(stft/frame/Shape;stft/frame/Shape) shape:[2], type:INT32
#   T#149(stft/frame/split;stft/frame/split) shape:[1], type:INT32
#   T#150(stft/frame/split;stft/frame/split1) shape:[1], type:INT32
#   T#151(stft/frame/split;stft/frame/split2) shape:[0], type:INT32
#   T#152(stft/frame/Reshape;stft/frame/Reshape) shape:[], type:INT32
#   T#153(stft/frame/floordiv_3;stft/frame/floordiv_3) shape:[], type:INT32
#   T#154(stft/frame/concat_1/values_1;stft/frame/concat_1/values_1) shape:[2], type:INT32
#   T#155(stft/frame/mul;stft/frame/mul) shape:[], type:INT32
#   T#156(stft/frame/concat/values_1;stft/frame/concat/values_1) shape:[1], type:INT32
#   T#157(stft/frame/concat;stft/frame/concat) shape:[2], type:INT32
#   T#158(stft/frame/concat_1;stft/frame/concat_1) shape:[3], type:INT32
#   T#159(stft/frame/StridedSlice;stft/frame/StridedSlice) shape_signature:[-1, -1], type:FLOAT32
#   T#160(stft/frame/Reshape_1;stft/frame/Reshape_1) shape_signature:[-1, -1, 8], type:FLOAT32
#   T#161(stft/frame/sub_2;stft/frame/sub_2) shape:[], type:INT32
#   T#162(stft/frame/floordiv;stft/frame/floordiv) shape:[], type:INT32
#   T#163(stft/frame/add;stft/frame/add) shape:[], type:INT32
#   T#164(stft/frame/Maximum;stft/frame/Maximum) shape:[], type:INT32
#   T#165(stft/frame/Reshape_2/shape;stft/frame/Reshape_2/shape) shape:[2], type:INT32
#   T#166(stft/frame/concat_2/values_1;stft/frame/concat_2/values_1) shape:[2], type:INT32
#   T#167(stft/frame/concat_2;stft/frame/concat_2) shape:[3], type:INT32
#   T#168(stft/frame/range_1;stft/frame/range_1) shape_signature:[-1], type:INT32
#   T#169(stft/frame/mul_1;stft/frame/mul_1) shape_signature:[-1], type:INT32
#   T#170(stft/frame/Reshape_2;stft/frame/Reshape_2) shape_signature:[-1, 1], type:INT32
#   T#171(stft/frame/add_1;stft/frame/add_1) shape_signature:[-1, 64], type:INT32
#   T#172(stft/frame/GatherV2;stft/frame/GatherV2;model_1/BLOCK_3-1_SE_RESHAPE/Reshape/shape/1) shape_signature:[-1, -1, 64, 8], type:FLOAT32
#   T#173(stft/frame/Reshape_4;stft/frame/Reshape_4) shape_signature:[-1, -1, 512], type:FLOAT32
#   T#174(stft/mul;stft/mul) shape_signature:[-1, -1, 512], type:FLOAT32
#   T#175(stft/rfft;stft/rfft2) shape_signature:[-1, -1, 1, 512], type:FLOAT32
#   T#176(stft/rfft;stft/rfft3) shape_signature:[-1, -1, 1, 257], type:COMPLEX64
#   T#177(stft/rfft;stft/rfft4) shape_signature:[-1, -1, 257], type:COMPLEX64
#   T#178(Cast;Cast) shape_signature:[-1, -1, 257], type:FLOAT32
#   T#179(strided_slice;strided_slice) shape_signature:[-1, -1, 128], type:FLOAT32
#   T#180(Pow;Pow;Pow/y;Pow/y) shape_signature:[-1, -1, 128], type:FLOAT32
#   T#181(Pow_1;Pow_1) shape_signature:[-1, -1, 128], type:FLOAT32
#   T#182(transpose;transpose) shape_signature:[-1, 128, -1], type:FLOAT32
#   T#183(ExpandDims;ExpandDims) shape_signature:[-1, 128, -1, 1], type:FLOAT32
#   T#184(model_1/BNORM_SPEC_NOQUANT/FusedBatchNormV32) shape_signature:[-1, 128, -1, 1], type:FLOAT32
#   T#185(model_1/BNORM_SPEC_NOQUANT/FusedBatchNormV33) shape_signature:[-1, 128, -1, 1], type:FLOAT32
#   T#186(model_1/ACT_0/Relu;model_1/BNORM_0/FusedBatchNormV3;model_1/pool_0_CONV/Conv2D;model_1/CONV_0/Conv2D) shape_signature:[-1, 64, -1, 30], type:FLOAT32
#   T#187(model_1/pool_0_AVG/AvgPool) shape_signature:[-1, 64, -1, 30], type:FLOAT32
#   T#188(model_1/pool_0_MAX/MaxPool) shape_signature:[-1, 64, -1, 30], type:FLOAT32
#   T#189(model_1/pool_0_CONCAT/concat) shape_signature:[-1, 64, -1, 60], type:FLOAT32
#   T#190(model_1/pool_0_CONV/BiasAdd;model_1/pool_0_CONV/Conv2D;model_1/pool_0_CONV/BiasAdd/ReadVariableOp) shape_signature:[-1, 64, -1, 30], type:FLOAT32
#   T#191(model_1/BLOCK_1-1_BN_1/FusedBatchNormV3;model_1/BLOCK_1-3_CONV_3/Conv2D;model_1/BLOCK_1-1_CONV_1/Conv2D) shape_signature:[-1, 32, -1, 60], type:FLOAT32
#   T#192(model_1/BLOCK_1-1_ACT_1/Sigmoid) shape_signature:[-1, 32, -1, 60], type:FLOAT32
#   T#193(model_1/BLOCK_1-1_ACT_1/mul_1) shape_signature:[-1, 32, -1, 60], type:FLOAT32
#   T#194(model_1/BLOCK_1-1_BN_3/FusedBatchNormV3;model_1/BLOCK_1-3_CONV_3/Conv2D;model_1/BLOCK_1-1_CONV_3/Conv2D) shape_signature:[-1, 32, -1, 60], type:FLOAT32
#   T#195(model_1/BLOCK_1-2_BN_1/FusedBatchNormV3;model_1/BLOCK_1-3_CONV_3/Conv2D;model_1/BLOCK_1-2_CONV_1/Conv2D) shape_signature:[-1, 32, -1, 60], type:FLOAT32
#   T#196(model_1/BLOCK_1-2_ACT_1/Sigmoid) shape_signature:[-1, 32, -1, 60], type:FLOAT32
#   T#197(model_1/BLOCK_1-2_ACT_1/mul_1) shape_signature:[-1, 32, -1, 60], type:FLOAT32
#   T#198(model_1/BLOCK_1-2_BN_3/FusedBatchNormV3;model_1/BLOCK_1-3_CONV_3/Conv2D;model_1/BLOCK_1-2_CONV_3/Conv2D) shape_signature:[-1, 32, -1, 60], type:FLOAT32
#   T#199(model_1/BLOCK_1-2_ADD/add) shape_signature:[-1, 32, -1, 60], type:FLOAT32
#   T#200(model_1/BLOCK_1-3_BN_1/FusedBatchNormV3;model_1/BLOCK_1-3_CONV_3/Conv2D;model_1/BLOCK_1-3_CONV_1/Conv2D) shape_signature:[-1, 32, -1, 60], type:FLOAT32
#   T#201(model_1/BLOCK_1-3_ACT_1/Sigmoid) shape_signature:[-1, 32, -1, 60], type:FLOAT32
#   T#202(model_1/BLOCK_1-3_ACT_1/mul_1) shape_signature:[-1, 32, -1, 60], type:FLOAT32
#   T#203(model_1/BLOCK_1-3_BN_3/FusedBatchNormV3;model_1/BLOCK_1-3_CONV_3/Conv2D) shape_signature:[-1, 32, -1, 60], type:FLOAT32
#   T#204(model_1/BLOCK_1-3_ADD/add) shape_signature:[-1, 32, -1, 60], type:FLOAT32
#   T#205(model_1/BLOCK_2-1_BN_1/FusedBatchNormV3;model_1/BLOCK_2-4_CONV_1/Conv2D;model_1/BLOCK_2-1_CONV_1/Conv2D) shape_signature:[-1, 16, -1, 240], type:FLOAT32
#   T#206(model_1/BLOCK_2-1_ACT_1/Sigmoid) shape_signature:[-1, 16, -1, 240], type:FLOAT32
#   T#207(model_1/BLOCK_2-1_ACT_1/mul_1) shape_signature:[-1, 16, -1, 240], type:FLOAT32
#   T#208(model_1/BLOCK_2-1_BN_3/FusedBatchNormV3;model_1/BLOCK_2-4_CONV_3/Conv2D;model_1/BLOCK_2-1_CONV_3/Conv2D) shape_signature:[-1, 16, -1, 120], type:FLOAT32
#   T#209(model_1/BLOCK_2-2_BN_1/FusedBatchNormV3;model_1/BLOCK_2-4_CONV_1/Conv2D;model_1/BLOCK_2-2_CONV_1/Conv2D) shape_signature:[-1, 16, -1, 240], type:FLOAT32
#   T#210(model_1/BLOCK_2-2_ACT_1/Sigmoid) shape_signature:[-1, 16, -1, 240], type:FLOAT32
#   T#211(model_1/BLOCK_2-2_ACT_1/mul_1) shape_signature:[-1, 16, -1, 240], type:FLOAT32
#   T#212(model_1/BLOCK_2-2_BN_3/FusedBatchNormV3;model_1/BLOCK_2-4_CONV_3/Conv2D;model_1/BLOCK_2-2_CONV_3/Conv2D) shape_signature:[-1, 16, -1, 120], type:FLOAT32
#   T#213(model_1/BLOCK_2-2_ADD/add) shape_signature:[-1, 16, -1, 120], type:FLOAT32
#   T#214(model_1/BLOCK_2-3_BN_1/FusedBatchNormV3;model_1/BLOCK_2-4_CONV_1/Conv2D;model_1/BLOCK_2-3_CONV_1/Conv2D) shape_signature:[-1, 16, -1, 240], type:FLOAT32
#   T#215(model_1/BLOCK_2-3_ACT_1/Sigmoid) shape_signature:[-1, 16, -1, 240], type:FLOAT32
#   T#216(model_1/BLOCK_2-3_ACT_1/mul_1) shape_signature:[-1, 16, -1, 240], type:FLOAT32
#   T#217(model_1/BLOCK_2-3_BN_3/FusedBatchNormV3;model_1/BLOCK_2-4_CONV_3/Conv2D;model_1/BLOCK_2-3_CONV_3/Conv2D) shape_signature:[-1, 16, -1, 120], type:FLOAT32
#   T#218(model_1/BLOCK_2-3_ADD/add) shape_signature:[-1, 16, -1, 120], type:FLOAT32
#   T#219(model_1/BLOCK_2-4_BN_1/FusedBatchNormV3;model_1/BLOCK_2-4_CONV_1/Conv2D) shape_signature:[-1, 16, -1, 240], type:FLOAT32
#   T#220(model_1/BLOCK_2-4_ACT_1/Sigmoid) shape_signature:[-1, 16, -1, 240], type:FLOAT32
#   T#221(model_1/BLOCK_2-4_ACT_1/mul_1) shape_signature:[-1, 16, -1, 240], type:FLOAT32
#   T#222(model_1/BLOCK_2-4_BN_3/FusedBatchNormV3;model_1/BLOCK_2-4_CONV_3/Conv2D) shape_signature:[-1, 16, -1, 120], type:FLOAT32
#   T#223(model_1/BLOCK_2-4_ADD/add) shape_signature:[-1, 16, -1, 120], type:FLOAT32
#   T#224(model_1/BLOCK_3-1_BN_1/FusedBatchNormV3;model_1/BLOCK_3-5_SE_CONV_2/Conv2D;model_1/BLOCK_3-1_CONV_1/Conv2D) shape_signature:[-1, 16, -1, 640], type:FLOAT32
#   T#225(model_1/BLOCK_3-1_ACT_1/Sigmoid) shape_signature:[-1, 16, -1, 640], type:FLOAT32
#   T#226(model_1/BLOCK_3-1_ACT_1/mul_1) shape_signature:[-1, 16, -1, 640], type:FLOAT32
#   T#227(model_1/BLOCK_3-1_BN_2_NOQUANT/FusedBatchNormV3;model_1/BLOCK_3-5_SE_CONV_2/Conv2D;model_1/BLOCK_3-1_CONV_2/depthwise) shape_signature:[-1, 8, -1, 640], type:FLOAT32
#   T#228(model_1/BLOCK_3-1_ACT_2/Sigmoid) shape_signature:[-1, 8, -1, 640], type:FLOAT32
#   T#229(model_1/BLOCK_3-1_ACT_2/mul_1) shape_signature:[-1, 8, -1, 640], type:FLOAT32
#   T#230(model_1/BLOCK_3-1_SE_AVG_POOL_1/Mean) shape_signature:[-1, 640], type:FLOAT32
#   T#231(model_1/BLOCK_3-1_SE_RESHAPE/Shape) shape:[2], type:INT32
#   T#232(model_1/BLOCK_3-1_SE_RESHAPE/strided_slice) shape:[], type:INT32
#   T#233(model_1/BLOCK_3-1_SE_RESHAPE/Reshape/shape) shape:[4], type:INT32
#   T#234(model_1/BLOCK_3-1_SE_RESHAPE/Reshape) shape_signature:[-1, 1, 1, 640], type:FLOAT32
#   T#235(model_1/BLOCK_3-1_SE_CONV_1/Conv2D1) shape_signature:[-1, 1, 1, 40], type:FLOAT32
#   T#236(model_1/BLOCK_3-1_SE_CONV_1/Sigmoid) shape_signature:[-1, 1, 1, 40], type:FLOAT32
#   T#237(model_1/BLOCK_3-1_SE_CONV_1/mul_1) shape_signature:[-1, 1, 1, 40], type:FLOAT32
#   T#238(model_1/BLOCK_3-1_SE_CONV_2/Conv2D1) shape_signature:[-1, 1, 1, 640], type:FLOAT32
#   T#239(model_1/BLOCK_3-1_SE_CONV_2/Sigmoid) shape_signature:[-1, 1, 1, 640], type:FLOAT32
#   T#240(model_1/BLOCK_3-1_MULTIPLY/mul) shape_signature:[-1, 8, -1, 640], type:FLOAT32
#   T#241(model_1/BLOCK_3-1_BN_3/FusedBatchNormV3;model_1/BLOCK_3-5_CONV_3/Conv2D;model_1/BLOCK_3-1_CONV_3/Conv2D) shape_signature:[-1, 8, -1, 160], type:FLOAT32
#   T#242(model_1/BLOCK_3-2_BN_1/FusedBatchNormV3;model_1/BLOCK_3-5_SE_CONV_2/Conv2D;model_1/BLOCK_3-2_CONV_1/Conv2D) shape_signature:[-1, 8, -1, 640], type:FLOAT32
#   T#243(model_1/BLOCK_3-2_ACT_1/Sigmoid) shape_signature:[-1, 8, -1, 640], type:FLOAT32
#   T#244(model_1/BLOCK_3-2_ACT_1/mul_1) shape_signature:[-1, 8, -1, 640], type:FLOAT32
#   T#245(model_1/BLOCK_3-2_BN_2_NOQUANT/FusedBatchNormV3;model_1/BLOCK_3-5_SE_CONV_2/Conv2D;model_1/BLOCK_3-2_CONV_2/depthwise) shape_signature:[-1, 8, -1, 640], type:FLOAT32
#   T#246(model_1/BLOCK_3-2_ACT_2/Sigmoid) shape_signature:[-1, 8, -1, 640], type:FLOAT32
#   T#247(model_1/BLOCK_3-2_ACT_2/mul_1) shape_signature:[-1, 8, -1, 640], type:FLOAT32
#   T#248(model_1/BLOCK_3-2_SE_AVG_POOL_1/Mean) shape_signature:[-1, 640], type:FLOAT32
#   T#249(model_1/BLOCK_3-2_SE_RESHAPE/Shape) shape:[2], type:INT32
#   T#250(model_1/BLOCK_3-2_SE_RESHAPE/strided_slice) shape:[], type:INT32
#   T#251(model_1/BLOCK_3-2_SE_RESHAPE/Reshape/shape) shape:[4], type:INT32
#   T#252(model_1/BLOCK_3-2_SE_RESHAPE/Reshape) shape_signature:[-1, 1, 1, 640], type:FLOAT32
#   T#253(model_1/BLOCK_3-2_SE_CONV_1/Conv2D1) shape_signature:[-1, 1, 1, 40], type:FLOAT32
#   T#254(model_1/BLOCK_3-2_SE_CONV_1/Sigmoid) shape_signature:[-1, 1, 1, 40], type:FLOAT32
#   T#255(model_1/BLOCK_3-2_SE_CONV_1/mul_1) shape_signature:[-1, 1, 1, 40], type:FLOAT32
#   T#256(model_1/BLOCK_3-2_SE_CONV_2/Conv2D1) shape_signature:[-1, 1, 1, 640], type:FLOAT32
#   T#257(model_1/BLOCK_3-2_SE_CONV_2/Sigmoid) shape_signature:[-1, 1, 1, 640], type:FLOAT32
#   T#258(model_1/BLOCK_3-2_MULTIPLY/mul) shape_signature:[-1, 8, -1, 640], type:FLOAT32
#   T#259(model_1/BLOCK_3-2_BN_3/FusedBatchNormV3;model_1/BLOCK_3-5_CONV_3/Conv2D;model_1/BLOCK_3-2_CONV_3/Conv2D) shape_signature:[-1, 8, -1, 160], type:FLOAT32
#   T#260(model_1/BLOCK_3-2_ADD/add) shape_signature:[-1, 8, -1, 160], type:FLOAT32
#   T#261(model_1/BLOCK_3-3_BN_1/FusedBatchNormV3;model_1/BLOCK_3-5_SE_CONV_2/Conv2D;model_1/BLOCK_3-3_CONV_1/Conv2D) shape_signature:[-1, 8, -1, 640], type:FLOAT32
#   T#262(model_1/BLOCK_3-3_ACT_1/Sigmoid) shape_signature:[-1, 8, -1, 640], type:FLOAT32
#   T#263(model_1/BLOCK_3-3_ACT_1/mul_1) shape_signature:[-1, 8, -1, 640], type:FLOAT32
#   T#264(model_1/BLOCK_3-3_BN_2_NOQUANT/FusedBatchNormV3;model_1/BLOCK_3-5_SE_CONV_2/Conv2D;model_1/BLOCK_3-3_CONV_2/depthwise) shape_signature:[-1, 8, -1, 640], type:FLOAT32
#   T#265(model_1/BLOCK_3-3_ACT_2/Sigmoid) shape_signature:[-1, 8, -1, 640], type:FLOAT32
#   T#266(model_1/BLOCK_3-3_ACT_2/mul_1) shape_signature:[-1, 8, -1, 640], type:FLOAT32
#   T#267(model_1/BLOCK_3-3_SE_AVG_POOL_1/Mean) shape_signature:[-1, 640], type:FLOAT32
#   T#268(model_1/BLOCK_3-3_SE_RESHAPE/Shape) shape:[2], type:INT32
#   T#269(model_1/BLOCK_3-3_SE_RESHAPE/strided_slice) shape:[], type:INT32
#   T#270(model_1/BLOCK_3-3_SE_RESHAPE/Reshape/shape) shape:[4], type:INT32
#   T#271(model_1/BLOCK_3-3_SE_RESHAPE/Reshape) shape_signature:[-1, 1, 1, 640], type:FLOAT32
#   T#272(model_1/BLOCK_3-3_SE_CONV_1/Conv2D1) shape_signature:[-1, 1, 1, 40], type:FLOAT32
#   T#273(model_1/BLOCK_3-3_SE_CONV_1/Sigmoid) shape_signature:[-1, 1, 1, 40], type:FLOAT32
#   T#274(model_1/BLOCK_3-3_SE_CONV_1/mul_1) shape_signature:[-1, 1, 1, 40], type:FLOAT32
#   T#275(model_1/BLOCK_3-3_SE_CONV_2/Conv2D1) shape_signature:[-1, 1, 1, 640], type:FLOAT32
#   T#276(model_1/BLOCK_3-3_SE_CONV_2/Sigmoid) shape_signature:[-1, 1, 1, 640], type:FLOAT32
#   T#277(model_1/BLOCK_3-3_MULTIPLY/mul) shape_signature:[-1, 8, -1, 640], type:FLOAT32
#   T#278(model_1/BLOCK_3-3_BN_3/FusedBatchNormV3;model_1/BLOCK_3-5_CONV_3/Conv2D;model_1/BLOCK_3-3_CONV_3/Conv2D) shape_signature:[-1, 8, -1, 160], type:FLOAT32
#   T#279(model_1/BLOCK_3-3_ADD/add) shape_signature:[-1, 8, -1, 160], type:FLOAT32
#   T#280(model_1/BLOCK_3-4_BN_1/FusedBatchNormV3;model_1/BLOCK_3-5_SE_CONV_2/Conv2D;model_1/BLOCK_3-4_CONV_1/Conv2D) shape_signature:[-1, 8, -1, 640], type:FLOAT32
#   T#281(model_1/BLOCK_3-4_ACT_1/Sigmoid) shape_signature:[-1, 8, -1, 640], type:FLOAT32
#   T#282(model_1/BLOCK_3-4_ACT_1/mul_1) shape_signature:[-1, 8, -1, 640], type:FLOAT32
#   T#283(model_1/BLOCK_3-4_BN_2_NOQUANT/FusedBatchNormV3;model_1/BLOCK_3-5_SE_CONV_2/Conv2D;model_1/BLOCK_3-4_CONV_2/depthwise) shape_signature:[-1, 8, -1, 640], type:FLOAT32
#   T#284(model_1/BLOCK_3-4_ACT_2/Sigmoid) shape_signature:[-1, 8, -1, 640], type:FLOAT32
#   T#285(model_1/BLOCK_3-4_ACT_2/mul_1) shape_signature:[-1, 8, -1, 640], type:FLOAT32
#   T#286(model_1/BLOCK_3-4_SE_AVG_POOL_1/Mean) shape_signature:[-1, 640], type:FLOAT32
#   T#287(model_1/BLOCK_3-4_SE_RESHAPE/Shape) shape:[2], type:INT32
#   T#288(model_1/BLOCK_3-4_SE_RESHAPE/strided_slice) shape:[], type:INT32
#   T#289(model_1/BLOCK_3-4_SE_RESHAPE/Reshape/shape) shape:[4], type:INT32
#   T#290(model_1/BLOCK_3-4_SE_RESHAPE/Reshape) shape_signature:[-1, 1, 1, 640], type:FLOAT32
#   T#291(model_1/BLOCK_3-4_SE_CONV_1/Conv2D1) shape_signature:[-1, 1, 1, 40], type:FLOAT32
#   T#292(model_1/BLOCK_3-4_SE_CONV_1/Sigmoid) shape_signature:[-1, 1, 1, 40], type:FLOAT32
#   T#293(model_1/BLOCK_3-4_SE_CONV_1/mul_1) shape_signature:[-1, 1, 1, 40], type:FLOAT32
#   T#294(model_1/BLOCK_3-4_SE_CONV_2/Conv2D1) shape_signature:[-1, 1, 1, 640], type:FLOAT32
#   T#295(model_1/BLOCK_3-4_SE_CONV_2/Sigmoid) shape_signature:[-1, 1, 1, 640], type:FLOAT32
#   T#296(model_1/BLOCK_3-4_MULTIPLY/mul) shape_signature:[-1, 8, -1, 640], type:FLOAT32
#   T#297(model_1/BLOCK_3-4_BN_3/FusedBatchNormV3;model_1/BLOCK_3-5_CONV_3/Conv2D;model_1/BLOCK_3-4_CONV_3/Conv2D) shape_signature:[-1, 8, -1, 160], type:FLOAT32
#   T#298(model_1/BLOCK_3-4_ADD/add) shape_signature:[-1, 8, -1, 160], type:FLOAT32
#   T#299(model_1/BLOCK_3-5_BN_1/FusedBatchNormV3;model_1/BLOCK_3-5_SE_CONV_2/Conv2D;model_1/BLOCK_3-5_CONV_1/Conv2D) shape_signature:[-1, 8, -1, 640], type:FLOAT32
#   T#300(model_1/BLOCK_3-5_ACT_1/Sigmoid) shape_signature:[-1, 8, -1, 640], type:FLOAT32
#   T#301(model_1/BLOCK_3-5_ACT_1/mul_1) shape_signature:[-1, 8, -1, 640], type:FLOAT32
#   T#302(model_1/BLOCK_3-5_BN_2_NOQUANT/FusedBatchNormV3;model_1/BLOCK_3-5_SE_CONV_2/Conv2D;model_1/BLOCK_3-5_CONV_2/depthwise) shape_signature:[-1, 8, -1, 640], type:FLOAT32
#   T#303(model_1/BLOCK_3-5_ACT_2/Sigmoid) shape_signature:[-1, 8, -1, 640], type:FLOAT32
#   T#304(model_1/BLOCK_3-5_ACT_2/mul_1) shape_signature:[-1, 8, -1, 640], type:FLOAT32
#   T#305(model_1/BLOCK_3-5_SE_AVG_POOL_1/Mean) shape_signature:[-1, 640], type:FLOAT32
#   T#306(model_1/BLOCK_3-5_SE_RESHAPE/Shape) shape:[2], type:INT32
#   T#307(model_1/BLOCK_3-5_SE_RESHAPE/strided_slice) shape:[], type:INT32
#   T#308(model_1/BLOCK_3-5_SE_RESHAPE/Reshape/shape) shape:[4], type:INT32
#   T#309(model_1/BLOCK_3-5_SE_RESHAPE/Reshape) shape_signature:[-1, 1, 1, 640], type:FLOAT32
#   T#310(model_1/BLOCK_3-5_SE_CONV_1/Conv2D2) shape_signature:[-1, 1, 1, 40], type:FLOAT32
#   T#311(model_1/BLOCK_3-5_SE_CONV_1/Sigmoid) shape_signature:[-1, 1, 1, 40], type:FLOAT32
#   T#312(model_1/BLOCK_3-5_SE_CONV_1/mul_1) shape_signature:[-1, 1, 1, 40], type:FLOAT32
#   T#313(model_1/BLOCK_3-5_SE_CONV_2/Conv2D2) shape_signature:[-1, 1, 1, 640], type:FLOAT32
#   T#314(model_1/BLOCK_3-5_SE_CONV_2/Sigmoid) shape_signature:[-1, 1, 1, 640], type:FLOAT32
#   T#315(model_1/BLOCK_3-5_MULTIPLY/mul) shape_signature:[-1, 8, -1, 640], type:FLOAT32
#   T#316(model_1/BLOCK_3-5_BN_3/FusedBatchNormV3;model_1/BLOCK_3-5_CONV_3/Conv2D) shape_signature:[-1, 8, -1, 160], type:FLOAT32
#   T#317(model_1/BLOCK_3-5_ADD/add) shape_signature:[-1, 8, -1, 160], type:FLOAT32
#   T#318(model_1/BLOCK_4-1_BN_1/FusedBatchNormV3;model_1/BLOCK_4-4_SE_CONV_2/Conv2D;model_1/BLOCK_4-1_CONV_1/Conv2D) shape_signature:[-1, 8, -1, 1120], type:FLOAT32
#   T#319(model_1/BLOCK_4-1_ACT_1/Sigmoid) shape_signature:[-1, 8, -1, 1120], type:FLOAT32
#   T#320(model_1/BLOCK_4-1_ACT_1/mul_1) shape_signature:[-1, 8, -1, 1120], type:FLOAT32
#   T#321(model_1/BLOCK_4-1_BN_2_NOQUANT/FusedBatchNormV3;model_1/BLOCK_4-4_SE_CONV_2/Conv2D;model_1/BLOCK_4-1_CONV_2/depthwise) shape_signature:[-1, 4, -1, 1120], type:FLOAT32
#   T#322(model_1/BLOCK_4-1_ACT_2/Sigmoid) shape_signature:[-1, 4, -1, 1120], type:FLOAT32
#   T#323(model_1/BLOCK_4-1_ACT_2/mul_1) shape_signature:[-1, 4, -1, 1120], type:FLOAT32
#   T#324(model_1/BLOCK_4-1_SE_AVG_POOL_1/Mean) shape_signature:[-1, 1120], type:FLOAT32
#   T#325(model_1/BLOCK_4-1_SE_RESHAPE/Shape) shape:[2], type:INT32
#   T#326(model_1/BLOCK_4-1_SE_RESHAPE/strided_slice) shape:[], type:INT32
#   T#327(model_1/BLOCK_4-1_SE_RESHAPE/Reshape/shape) shape:[4], type:INT32
#   T#328(model_1/BLOCK_4-1_SE_RESHAPE/Reshape) shape_signature:[-1, 1, 1, 1120], type:FLOAT32
#   T#329(model_1/BLOCK_4-1_SE_CONV_1/Conv2D1) shape_signature:[-1, 1, 1, 70], type:FLOAT32
#   T#330(model_1/BLOCK_4-1_SE_CONV_1/Sigmoid) shape_signature:[-1, 1, 1, 70], type:FLOAT32
#   T#331(model_1/BLOCK_4-1_SE_CONV_1/mul_1) shape_signature:[-1, 1, 1, 70], type:FLOAT32
#   T#332(model_1/BLOCK_4-1_SE_CONV_2/Conv2D1) shape_signature:[-1, 1, 1, 1120], type:FLOAT32
#   T#333(model_1/BLOCK_4-1_SE_CONV_2/Sigmoid) shape_signature:[-1, 1, 1, 1120], type:FLOAT32
#   T#334(model_1/BLOCK_4-1_MULTIPLY/mul) shape_signature:[-1, 4, -1, 1120], type:FLOAT32
#   T#335(model_1/BLOCK_4-1_BN_3/FusedBatchNormV3;model_1/BLOCK_4-4_CONV_3/Conv2D;model_1/BLOCK_4-1_CONV_3/Conv2D) shape_signature:[-1, 4, -1, 280], type:FLOAT32
#   T#336(model_1/BLOCK_4-2_BN_1/FusedBatchNormV3;model_1/BLOCK_4-4_SE_CONV_2/Conv2D;model_1/BLOCK_4-2_CONV_1/Conv2D) shape_signature:[-1, 4, -1, 1120], type:FLOAT32
#   T#337(model_1/BLOCK_4-2_ACT_1/Sigmoid) shape_signature:[-1, 4, -1, 1120], type:FLOAT32
#   T#338(model_1/BLOCK_4-2_ACT_1/mul_1) shape_signature:[-1, 4, -1, 1120], type:FLOAT32
#   T#339(model_1/BLOCK_4-2_BN_2_NOQUANT/FusedBatchNormV3;model_1/BLOCK_4-4_SE_CONV_2/Conv2D;model_1/BLOCK_4-2_CONV_2/depthwise) shape_signature:[-1, 4, -1, 1120], type:FLOAT32
#   T#340(model_1/BLOCK_4-2_ACT_2/Sigmoid) shape_signature:[-1, 4, -1, 1120], type:FLOAT32
#   T#341(model_1/BLOCK_4-2_ACT_2/mul_1) shape_signature:[-1, 4, -1, 1120], type:FLOAT32
#   T#342(model_1/BLOCK_4-2_SE_AVG_POOL_1/Mean) shape_signature:[-1, 1120], type:FLOAT32
#   T#343(model_1/BLOCK_4-2_SE_RESHAPE/Shape) shape:[2], type:INT32
#   T#344(model_1/BLOCK_4-2_SE_RESHAPE/strided_slice) shape:[], type:INT32
#   T#345(model_1/BLOCK_4-2_SE_RESHAPE/Reshape/shape) shape:[4], type:INT32
#   T#346(model_1/BLOCK_4-2_SE_RESHAPE/Reshape) shape_signature:[-1, 1, 1, 1120], type:FLOAT32
#   T#347(model_1/BLOCK_4-2_SE_CONV_1/Conv2D1) shape_signature:[-1, 1, 1, 70], type:FLOAT32
#   T#348(model_1/BLOCK_4-2_SE_CONV_1/Sigmoid) shape_signature:[-1, 1, 1, 70], type:FLOAT32
#   T#349(model_1/BLOCK_4-2_SE_CONV_1/mul_1) shape_signature:[-1, 1, 1, 70], type:FLOAT32
#   T#350(model_1/BLOCK_4-2_SE_CONV_2/Conv2D1) shape_signature:[-1, 1, 1, 1120], type:FLOAT32
#   T#351(model_1/BLOCK_4-2_SE_CONV_2/Sigmoid) shape_signature:[-1, 1, 1, 1120], type:FLOAT32
#   T#352(model_1/BLOCK_4-2_MULTIPLY/mul) shape_signature:[-1, 4, -1, 1120], type:FLOAT32
#   T#353(model_1/BLOCK_4-2_BN_3/FusedBatchNormV3;model_1/BLOCK_4-4_CONV_3/Conv2D;model_1/BLOCK_4-2_CONV_3/Conv2D) shape_signature:[-1, 4, -1, 280], type:FLOAT32
#   T#354(model_1/BLOCK_4-2_ADD/add) shape_signature:[-1, 4, -1, 280], type:FLOAT32
#   T#355(model_1/BLOCK_4-3_BN_1/FusedBatchNormV3;model_1/BLOCK_4-4_SE_CONV_2/Conv2D;model_1/BLOCK_4-3_CONV_1/Conv2D) shape_signature:[-1, 4, -1, 1120], type:FLOAT32
#   T#356(model_1/BLOCK_4-3_ACT_1/Sigmoid) shape_signature:[-1, 4, -1, 1120], type:FLOAT32
#   T#357(model_1/BLOCK_4-3_ACT_1/mul_1) shape_signature:[-1, 4, -1, 1120], type:FLOAT32
#   T#358(model_1/BLOCK_4-3_BN_2_NOQUANT/FusedBatchNormV3;model_1/BLOCK_4-4_SE_CONV_2/Conv2D;model_1/BLOCK_4-3_CONV_2/depthwise) shape_signature:[-1, 4, -1, 1120], type:FLOAT32
#   T#359(model_1/BLOCK_4-3_ACT_2/Sigmoid) shape_signature:[-1, 4, -1, 1120], type:FLOAT32
#   T#360(model_1/BLOCK_4-3_ACT_2/mul_1) shape_signature:[-1, 4, -1, 1120], type:FLOAT32
#   T#361(model_1/BLOCK_4-3_SE_AVG_POOL_1/Mean) shape_signature:[-1, 1120], type:FLOAT32
#   T#362(model_1/BLOCK_4-3_SE_RESHAPE/Shape) shape:[2], type:INT32
#   T#363(model_1/BLOCK_4-3_SE_RESHAPE/strided_slice) shape:[], type:INT32
#   T#364(model_1/BLOCK_4-3_SE_RESHAPE/Reshape/shape) shape:[4], type:INT32
#   T#365(model_1/BLOCK_4-3_SE_RESHAPE/Reshape) shape_signature:[-1, 1, 1, 1120], type:FLOAT32
#   T#366(model_1/BLOCK_4-3_SE_CONV_1/Conv2D1) shape_signature:[-1, 1, 1, 70], type:FLOAT32
#   T#367(model_1/BLOCK_4-3_SE_CONV_1/Sigmoid) shape_signature:[-1, 1, 1, 70], type:FLOAT32
#   T#368(model_1/BLOCK_4-3_SE_CONV_1/mul_1) shape_signature:[-1, 1, 1, 70], type:FLOAT32
#   T#369(model_1/BLOCK_4-3_SE_CONV_2/Conv2D1) shape_signature:[-1, 1, 1, 1120], type:FLOAT32
#   T#370(model_1/BLOCK_4-3_SE_CONV_2/Sigmoid) shape_signature:[-1, 1, 1, 1120], type:FLOAT32
#   T#371(model_1/BLOCK_4-3_MULTIPLY/mul) shape_signature:[-1, 4, -1, 1120], type:FLOAT32
#   T#372(model_1/BLOCK_4-3_BN_3/FusedBatchNormV3;model_1/BLOCK_4-4_CONV_3/Conv2D;model_1/BLOCK_4-3_CONV_3/Conv2D) shape_signature:[-1, 4, -1, 280], type:FLOAT32
#   T#373(model_1/BLOCK_4-3_ADD/add) shape_signature:[-1, 4, -1, 280], type:FLOAT32
#   T#374(model_1/BLOCK_4-4_BN_1/FusedBatchNormV3;model_1/BLOCK_4-4_SE_CONV_2/Conv2D;model_1/BLOCK_4-4_CONV_1/Conv2D) shape_signature:[-1, 4, -1, 1120], type:FLOAT32
#   T#375(model_1/BLOCK_4-4_ACT_1/Sigmoid) shape_signature:[-1, 4, -1, 1120], type:FLOAT32
#   T#376(model_1/BLOCK_4-4_ACT_1/mul_1) shape_signature:[-1, 4, -1, 1120], type:FLOAT32
#   T#377(model_1/BLOCK_4-4_BN_2_NOQUANT/FusedBatchNormV3;model_1/BLOCK_4-4_SE_CONV_2/Conv2D;model_1/BLOCK_4-4_CONV_2/depthwise) shape_signature:[-1, 4, -1, 1120], type:FLOAT32
#   T#378(model_1/BLOCK_4-4_ACT_2/Sigmoid) shape_signature:[-1, 4, -1, 1120], type:FLOAT32
#   T#379(model_1/BLOCK_4-4_ACT_2/mul_1) shape_signature:[-1, 4, -1, 1120], type:FLOAT32
#   T#380(model_1/BLOCK_4-4_SE_AVG_POOL_1/Mean) shape_signature:[-1, 1120], type:FLOAT32
#   T#381(model_1/BLOCK_4-4_SE_RESHAPE/Shape) shape:[2], type:INT32
#   T#382(model_1/BLOCK_4-4_SE_RESHAPE/strided_slice) shape:[], type:INT32
#   T#383(model_1/BLOCK_4-4_SE_RESHAPE/Reshape/shape) shape:[4], type:INT32
#   T#384(model_1/BLOCK_4-4_SE_RESHAPE/Reshape) shape_signature:[-1, 1, 1, 1120], type:FLOAT32
#   T#385(model_1/BLOCK_4-4_SE_CONV_1/Conv2D2) shape_signature:[-1, 1, 1, 70], type:FLOAT32
#   T#386(model_1/BLOCK_4-4_SE_CONV_1/Sigmoid) shape_signature:[-1, 1, 1, 70], type:FLOAT32
#   T#387(model_1/BLOCK_4-4_SE_CONV_1/mul_1) shape_signature:[-1, 1, 1, 70], type:FLOAT32
#   T#388(model_1/BLOCK_4-4_SE_CONV_2/Conv2D2) shape_signature:[-1, 1, 1, 1120], type:FLOAT32
#   T#389(model_1/BLOCK_4-4_SE_CONV_2/Sigmoid) shape_signature:[-1, 1, 1, 1120], type:FLOAT32
#   T#390(model_1/BLOCK_4-4_MULTIPLY/mul) shape_signature:[-1, 4, -1, 1120], type:FLOAT32
#   T#391(model_1/BLOCK_4-4_BN_3/FusedBatchNormV3;model_1/BLOCK_4-4_CONV_3/Conv2D) shape_signature:[-1, 4, -1, 280], type:FLOAT32
#   T#392(model_1/BLOCK_4-4_ADD/add) shape_signature:[-1, 4, -1, 280], type:FLOAT32
#   T#393(model_1/BNORM_POST_NOQUANT/FusedBatchNormV32) shape_signature:[-1, 4, -1, 280], type:FLOAT32
#   T#394(model_1/ACT_POST/Relu;model_1/BNORM_POST_NOQUANT/FusedBatchNormV3) shape_signature:[-1, 4, -1, 280], type:FLOAT32
#   T#395(model_1/POST_ACT_1/Relu;model_1/POST_BN_1/FusedBatchNormV3;model_1/POST_CONV_1/Conv2D) shape_signature:[-1, 2, -1, 420], type:FLOAT32
#   T#396(Max;Max1) shape_signature:[-1, 1, 1, 420], type:FLOAT32
#   T#397(Max_1;Max_1) shape_signature:[-1, 420], type:FLOAT32
#   T#398(sub;sub) shape_signature:[-1, 2, -1, 420], type:FLOAT32
#   T#399(mul;mul) shape_signature:[-1, 2, -1, 420], type:FLOAT32
#   T#400(Exp;Exp) shape_signature:[-1, 2, -1, 420], type:FLOAT32
#   T#401(Mean;Mean) shape_signature:[-1, 420], type:FLOAT32
#   T#402(Log;Log) shape_signature:[-1, 420], type:FLOAT32
#   T#403(truediv;truediv;ReadVariableOp;ReadVariableOp1) shape_signature:[-1, 420], type:FLOAT32
#   T#404(add;add) shape_signature:[-1, 420], type:FLOAT32
#   T#405(model_1/dense/MatMul;model_1/dense/BiasAdd) shape_signature:[-1, 2], type:FLOAT32
#   T#406(StatefulPartitionedCall:0) shape_signature:[-1, 2], type:FLOAT32
#
# ---------------------------------------------------------------
# Your TFLite model has '1' signature_def(s).
#
# Signature#0 key: 'serving_default'
# - Subgraph: Subgraph#0
# - Inputs:
#     'INPUT' : T#0
# - Outputs:
#     'activation' : T#406
#
# ---------------------------------------------------------------
#               Model size:   26159668 bytes
#     Non-data buffer size:      63864 bytes (00.24 %)
#   Total data buffer size:   26095804 bytes (99.76 %)
#     (Zero value buffers):       7504 bytes (00.03 %)
#
# * Buffers of TFLite model are mostly used for constant tensors.
#   And zero value buffers are buffers filled with zeros.
#   Non-data buffers area are used to store operators, subgraphs and etc.
#   You can find more details from https://github.com/tensorflow/tensorflow/blob/master/tensorflow/lite/schema/schema.fbs

# %% [markdown]
# ## Heatmap for weights in dense layer, scale both on non-target

# %%
import numpy as np
import matplotlib.pyplot as plt

# Extract weights
weights = baselineModel_activation_softmax.get_layer('dense').get_weights()[0]

# Determine bins based on the overall range of data
bins = np.linspace(weights.min(), weights.max(), 50)

# Compute histogram for both vectors
hist1, _ = np.histogram(weights[:, 0], bins=bins)
hist2, _ = np.histogram(weights[:, 1], bins=bins)

fig, axarr = plt.subplots(1, 2, figsize=(15, 5))

# Define color scale range based on the first vector's distribution
vmin = hist1.min()
vmax = hist1.max()

# Draw heatmaps
cax1 = axarr[0].matshow(hist1.reshape(-1, 1).T, cmap="viridis", aspect="auto", extent=[bins.min(), bins.max(), 0, 1], vmin=vmin, vmax=vmax)
axarr[0].set_title("Non-Target")
axarr[0].set_xlabel("Value Range")
axarr[0].xaxis.set_ticks_position('bottom')  # Move x-axis ticks to the bottom
axarr[0].yaxis.set_visible(False)  # Hide the y-axis
plt.colorbar(cax1, ax=axarr[0])

cax2 = axarr[1].matshow(hist2.reshape(-1, 1).T, cmap="viridis", aspect="auto", extent=[bins.min(), bins.max(), 0, 1], vmin=vmin, vmax=vmax)
axarr[1].set_title("Target")
axarr[1].set_xlabel("Value Range")
axarr[1].xaxis.set_ticks_position('bottom')  # Move x-axis ticks to the bottom
axarr[1].yaxis.set_visible(False)  # Hide the y-axis
plt.colorbar(cax2, ax=axarr[1])

plt.tight_layout()
plt.show()

# %% [markdown]
# ### --> no obivious issue of very focussed areas

# %% [markdown]
# ### Scale both on Target

# %%
import numpy as np
import matplotlib.pyplot as plt

# Extract weights
weights = baselineModel_activation_softmax.get_layer('dense').get_weights()[0]

# Determine bins based on the overall range of data
bins = np.linspace(weights.min(), weights.max(), 50)

# Compute histogram for both vectors
hist1, _ = np.histogram(weights[:, 0], bins=bins)
hist2, _ = np.histogram(weights[:, 1], bins=bins)

fig, axarr = plt.subplots(1, 2, figsize=(15, 5))

# Define color scale range based on the "Target" vector's distribution
vmin = hist2.min()
vmax = hist2.max()

# Draw heatmaps
cax1 = axarr[0].matshow(hist1.reshape(-1, 1).T, cmap="viridis", aspect="auto", extent=[bins.min(), bins.max(), 0, 1], vmin=vmin, vmax=vmax)
axarr[0].set_title("Non-Target")
axarr[0].set_xlabel("Value Range")
axarr[0].xaxis.set_ticks_position('bottom')
axarr[0].yaxis.set_visible(False)
plt.colorbar(cax1, ax=axarr[0])

cax2 = axarr[1].matshow(hist2.reshape(-1, 1).T, cmap="viridis", aspect="auto", extent=[bins.min(), bins.max(), 0, 1], vmin=vmin, vmax=vmax)
axarr[1].set_title("Target")
axarr[1].set_xlabel("Value Range")
axarr[1].xaxis.set_ticks_position('bottom')
axarr[1].yaxis.set_visible(False)
plt.colorbar(cax2, ax=axarr[1])

plt.tight_layout()
plt.show()

# %% [markdown]
# ### --> no obivious issue of very focussed areas

# %% [markdown]
# ## Try different vizualization

# %%
import numpy as np
import matplotlib.pyplot as plt

# Extract weights
weights = baselineModel_activation_softmax.get_layer('dense').get_weights()[0]

# Determine bins based on the overall range of data
bins = np.linspace(weights.min(), weights.max(), 50)

# Compute histogram for both vectors
hist1, _ = np.histogram(weights[:, 0], bins=bins)
hist2, _ = np.histogram(weights[:, 1], bins=bins)

fig, axarr = plt.subplots(1, 2, figsize=(15, 5))

# Plot histograms
axarr[0].bar(bins[:-1], hist1, width=np.diff(bins), align="edge", alpha=0.7, color='blue')
axarr[0].set_title("Non-Target")
axarr[0].set_ylabel("Count")
axarr[0].set_xlabel("Value Range")

axarr[1].bar(bins[:-1], hist2, width=np.diff(bins), align="edge", alpha=0.7, color='red')
axarr[1].set_title("Target")
axarr[1].set_ylabel("Count")
axarr[1].set_xlabel("Value Range")

plt.tight_layout()
plt.show()

# %% [markdown]
# ## Distribution of weighting in Dense Layer, window size for smoothing

# %%
import numpy as np
import matplotlib.pyplot as plt

# Extract weights
weights = baselineModel_activation_softmax.get_layer('dense').get_weights()[0]

# function to compute a rolling average
def rolling_average(data, window_size):
    cumsum = np.cumsum(data)
    cumsum[window_size:] = cumsum[window_size:] - cumsum[:-window_size]
    return cumsum[window_size - 1:] / window_size

# window size for rolling average
window_size = 200

smoothed_non_target = rolling_average(weights[:, 0], window_size)
smoothed_target = rolling_average(weights[:, 1], window_size)

fig, axarr = plt.subplots(1, 2, figsize=(15, 5))

# Plot weights for Non-Target
axarr[0].plot(smoothed_non_target, color='blue')
axarr[0].set_title("Non-Target")
axarr[0].set_ylabel("Weight Value")
axarr[0].set_xlabel("Emedding")

# Plot weights for Target
axarr[1].plot(smoothed_target, color='red')
axarr[1].set_title("Target")
axarr[1].set_ylabel("Weight Value")
axarr[1].set_xlabel("Embedding")

plt.tight_layout()
plt.show()

# %% [markdown]
# ### -->  this looks almost mirrored which is good

# %%
import numpy as np
import matplotlib.pyplot as plt
import os

# Extract weights
weights = baselineModel_activation_softmax.get_layer('dense').get_weights()[0]

def rolling_average_resampled(data, window_size):
    half_window = window_size // 2
    smoothed_data = []

    # Handle the start of the data
    for i in range(half_window):
        smoothed_data.append(np.mean(data[:i+half_window+1]))

    # Handle the main portion of the data
    for i in range(half_window, len(data) - half_window):
        smoothed_data.append(np.mean(data[i-half_window:i+half_window+1]))

    # Handle the end of the data
    for i in range(len(data) - half_window, len(data)):
        smoothed_data.append(np.mean(data[i-half_window:]))

    return np.array(smoothed_data)

# Window size for rolling average
window_size = 100
half_window = window_size // 2

smoothed_non_target = rolling_average_resampled(weights[:, 0], window_size)
smoothed_target = rolling_average_resampled(weights[:, 1], window_size)

# Plotting
plt.figure(figsize=(15, 5))

# Determine the overall y-axis limits
ymin = min(smoothed_non_target[half_window:-half_window].min(), smoothed_target[half_window:-half_window].min())
ymax = max(smoothed_non_target[half_window:-half_window].max(), smoothed_target[half_window:-half_window].max())

# Plot weights for Non-Target
plt.plot(range(half_window, len(smoothed_non_target) - half_window), smoothed_non_target[half_window:-half_window], color='blue', label='Non-Target')

# Plot weights for Target
plt.plot(range(half_window, len(smoothed_target) - half_window), smoothed_target[half_window:-half_window], color='red', label='Target')

# labels, legend, etc.
plt.ylabel("Weight Value")
plt.xlabel("Weight Index")
plt.xlim(0, len(smoothed_target))
plt.ylim(ymin, ymax)
plt.legend(loc='upper right')

image_folder = 'Image'
os.makedirs(image_folder, exist_ok=True)
image_path = os.path.join(image_folder, 'weight_values_windowsize100')
plt.savefig(f"{image_path}.pdf")

plt.show()

# %% [markdown]
# ### --> this looks as expected, almost mirrored, therefore distiguishing should be possible before quantization

# %% [markdown]
# ## After Quantization of Convolutional layers and dense layer
# ---

# %% [markdown]
# ### load model

# %%
import tensorflow as tf

tflite_model_path = "/home/jovyan/models/checkpoints_/quantization_aware_Conv_depth_dense_INT8.tflite"
interpreter = tf.lite.Interpreter(model_path=tflite_model_path)
interpreter.allocate_tensors()

print('Done Loading Model')
# Out:
# Done Loading Model

# %% [markdown]
# ### Combine both, before and after Quantization

# %%
import numpy as np
import matplotlib.pyplot as plt
import os

def rolling_average_resampled(data, window_size):
    half_window = window_size // 2
    smoothed_data = []

    for i in range(half_window):
        smoothed_data.append(np.mean(data[:i+half_window+1]))

    for i in range(half_window, len(data) - half_window):
        smoothed_data.append(np.mean(data[i-half_window:i+half_window+1]))

    for i in range(len(data) - half_window, len(data)):
        smoothed_data.append(np.mean(data[i-half_window:]))

    return np.array(smoothed_data)

# Window size for rolling average
window_size = 100
half_window = window_size // 2

# Get weights from baseline model
weights_baseline = baselineModel_activation_softmax.get_layer('dense').get_weights()[0]
smoothed_non_target_baseline = rolling_average_resampled(weights_baseline[:, 0], window_size)
smoothed_target_baseline = rolling_average_resampled(weights_baseline[:, 1], window_size)

# Get weights from TFLite model
weights_tflite = interpreter.get_tensor(127).T
smoothed_non_target_tflite = rolling_average_resampled(weights_tflite[:, 0], window_size)
smoothed_target_tflite = rolling_average_resampled(weights_tflite[:, 1], window_size)



fig, ax = plt.subplots(figsize=(15, 7))

# Determine the overall y-axis limits
ymin = min(smoothed_non_target_baseline[half_window:-half_window].min(),
           smoothed_target_baseline[half_window:-half_window].min(),
           smoothed_non_target_tflite[half_window:-half_window].min(),
           smoothed_target_tflite[half_window:-half_window].max())
ymax = max(smoothed_non_target_baseline[half_window:-half_window].max(),
           smoothed_target_baseline[half_window:-half_window].max(),
           smoothed_non_target_tflite[half_window:-half_window].max(),
           smoothed_target_tflite[half_window:-half_window].max())

# Set font sizes
label_font_size = 18
legend_font_size = 20


# Plot weights for baseline model (Before Quantization - Blue color)
ax.plot(range(half_window, len(smoothed_non_target_baseline) - half_window), smoothed_non_target_baseline[half_window:-half_window], 'b--', label='Non-target (Before quantization)')
ax.plot(range(half_window, len(smoothed_target_baseline) - half_window), smoothed_target_baseline[half_window:-half_window], 'b-', label='Target (Before quantization)')

# Plot weights for TFLite model (After Quantization - Red color)
ax.plot(range(half_window, len(smoothed_non_target_tflite) - half_window), smoothed_non_target_tflite[half_window:-half_window], 'r--', label='Non-target (After quantization)')
ax.plot(range(half_window, len(smoothed_target_tflite) - half_window), smoothed_target_tflite[half_window:-half_window], 'r-', label='Target (After quantization)')

ax.set_ylabel("Weight value", fontsize=label_font_size)
ax.set_xlabel("Weight index", fontsize=label_font_size)


# clearer labeld for thesis
custom_lines = [
    plt.Line2D([0], [0], color='blue', ls='--'),
    plt.Line2D([0], [0], color='blue', lw=2),
    plt.Line2D([0], [0], color='red', ls='--'),
    plt.Line2D([0], [0], color='red', lw=2)
]


# Custom legend
legend = ax.legend(custom_lines, [' Non-Target', 'Target', 'Non-Target', 'Target'],      
          title= 'Before Quantization:                          After Quantization:                          ', 
          loc='upper center', bbox_to_anchor=(0.5, -0.25), 
          fontsize=legend_font_size, frameon=True, ncol=4)

legend.get_title().set_fontsize(legend_font_size)

ax.set_ylim(ymin, ymax)

ax.tick_params(axis='both', labelsize=14)

ax.margins(x=0.02) 

plt.tight_layout()

image_folder = 'Image'
os.makedirs(image_folder, exist_ok=True)
image_path = os.path.join(image_folder, 'combined_weight_values_windowsize100_in_one_plot')
plt.savefig(f"{image_path}.pdf", bbox_inches='tight')

plt.show()

# %% [markdown]
# # We check the activations before the Dense Layer with standard deviation
# ---

# %% [markdown]
# ## Before Quantization
# ---

# %% [markdown]
# ### build model with LME Pool output

# %%
from keras.models import Model

# build model with LME output
activation_model = Model(inputs=baselineModel_activation_softmax.input,
                         outputs=baselineModel_activation_softmax.get_layer('GLOBAL_LME_POOL').output)

print('Done')
# Out:
# Done

# %% [markdown]
# ### Load 5 Activations from Target Class

# %%
import os
import audio

# function to load audio data and extract activations
def get_activations_from_file(file_path, model):
    # Load the audio file using the provided function
    input_data, sample_rate = audio.openAudioFile(file_path)
    
    
    input_data = np.expand_dims(input_data, axis=0)
    if len(input_data.shape) == 2:  # If data is 2D (batch_size, audio_length)
        input_data = np.expand_dims(input_data, axis=-1)  # Expand to 3D (batch_size, audio_length, 1)
    
    # Retrieve activations from the model
    activations = model.predict(input_data)
    return activations

folder_path = "/home/jovyan/cut-data/testing/target/"

# List all audio files in the target folder, but limit to first 5 for testing
file_paths = [os.path.join(folder_path, f) for f in os.listdir(folder_path) if f.endswith('.wav')][:5]

activations_list = []
for file_path in file_paths:
    act = get_activations_from_file(file_path, activation_model)
    activations_list.append(act)
    print(f"First 3 values for {file_path.split('/')[-1]}: {act[0, :3]}")

# Combine all activations into an array
activations_array = np.vstack(activations_list)
# Out:
# 1/1 [==============================] - 1s 824ms/step
# First 3 values for 0.970_0093_669234.wav: [0.8466564  0.46071112 0.806841  ]
# 1/1 [==============================] - 0s 49ms/step
# First 3 values for 0.940_0023_324445651.wav: [1.3941029 0.5681002 0.853912 ]
# 1/1 [==============================] - 0s 48ms/step
# First 3 values for 0.950_0002_556972.wav: [0.4038818  1.1463783  0.55604625]
# 1/1 [==============================] - 0s 54ms/step
# First 3 values for 0.920_0035_365517.wav: [0.9785464 0.7548368 0.4874674]
# 1/1 [==============================] - 0s 48ms/step
# First 3 values for 0.950_0039_402581791.wav: [0.6692315  1.1404216  0.69575584]

# %% [markdown]
# ### Calculate a standard deviation between target file activations

# %%
import numpy as np

# Calculate pairwise standard deviation among target activations
std_dev_target = []

num_files = len(activations_list)
for i in range(num_files):
    for j in range(i+1, num_files):  # Avoid duplicate pairs
        std_dev = np.std(activations_list[i] - activations_list[j])
        std_dev_target.append(std_dev)
        print(f"Standard deviation between target activation {i} and target activation {j}: {std_dev}")

# Compute the average of the pairwise standard deviations
average_std_dev = np.mean(std_dev_target)

print(f"Average pairwise standard deviation among target activations: {average_std_dev}")
# Out:
# Standard deviation between target activation 0 and target activation 1: 0.40651845932006836
# Standard deviation between target activation 0 and target activation 2: 0.3810955882072449
# Standard deviation between target activation 0 and target activation 3: 0.3417450785636902
# Standard deviation between target activation 0 and target activation 4: 0.37170177698135376
# Standard deviation between target activation 1 and target activation 2: 0.33595016598701477
# Standard deviation between target activation 1 and target activation 3: 0.3239469826221466
# Standard deviation between target activation 1 and target activation 4: 0.33908289670944214
# Standard deviation between target activation 2 and target activation 3: 0.3547174036502838
# Standard deviation between target activation 2 and target activation 4: 0.37233954668045044
# Standard deviation between target activation 3 and target activation 4: 0.307804137468338
# Average pairwise standard deviation among target activations: 0.3534902036190033

# %% [markdown]
# ### Load 5 Activations from Non_Target Class

# %%
import os
import audio

# load audio data
def get_activations_from_file_non_target(file_path, model):
    # Load the audio file using the provided function
    input_data, sample_rate = audio.openAudioFile(file_path)
    

    input_data = np.expand_dims(input_data, axis=0)
    if len(input_data.shape) == 2:  # If data is 2D (batch_size, audio_length)
        input_data = np.expand_dims(input_data, axis=-1)  # Expand to 3D (batch_size, audio_length, 1)
    
    # Retrieve activations from the model
    activations = model.predict(input_data)
    return activations

folder_path_non_target = "/home/jovyan/cut-data/testing/non_target/"

# List all audio files in the non-target folder, limit 5
file_paths_non_target = [os.path.join(folder_path_non_target, f) for f in os.listdir(folder_path_non_target) if f.endswith('.wav')][:5]

activations_list_non_target = []
for file_path in file_paths_non_target:
    act = get_activations_from_file_non_target(file_path, activation_model)
    activations_list_non_target.append(act)
    print(f"First 3 values for {file_path.split('/')[-1]}: {act[0, :3]}")
# Out:
# 1/1 [==============================] - 0s 48ms/step
# First 3 values for 0.940_0022_310083.wav: [0.91503197 0.0353909  0.9679333 ]
# 1/1 [==============================] - 0s 56ms/step
# First 3 values for 1.000_0002_-MZx1np1Ddc_30.wav: [0.7869046  0.65177023 0.6756823 ]
# 1/1 [==============================] - 0s 45ms/step
# First 3 values for 1.000_0003_-6RN8skIHU4_20.wav: [0.7139114 1.0290542 0.2103306]
# 1/1 [==============================] - 0s 57ms/step
# First 3 values for 1.000_0003_2RG9rOHHYWY_30.wav: [0.02469289 0.17907098 1.14387   ]
# 1/1 [==============================] - 0s 57ms/step
# First 3 values for 0.940_0047_664265.wav: [0.16580918 0.5723457  0.45046932]

# %% [markdown]
# ### Calculate a standard deviation between Target and Non-Target file activations

# %%
# Compute pairwise standard deviations for differences between activations
pairwise_std_devs = []

for act_target, act_non_target in zip(activations_list, activations_list_non_target):
    # Compute element-wise differences
    differences = act_target - act_non_target
    std_dev = np.std(differences)
    pairwise_std_devs.append(std_dev)

# Compute an overall measure of deviation using the mean of the standard deviations
average_std_dev = np.mean(pairwise_std_devs)

# Display results
for idx, std_dev in enumerate(pairwise_std_devs):
    print(f"Standard deviation for file pair {idx + 1}: {std_dev}")
print(f"Average standard deviation across all file pairs: {average_std_dev}")
# Out:
# Standard deviation for file pair 1: 0.6041926741600037
# Standard deviation for file pair 2: 0.5851749777793884
# Standard deviation for file pair 3: 0.54717618227005
# Standard deviation for file pair 4: 0.6083200573921204
# Standard deviation for file pair 5: 0.5144789218902588
# Average standard deviation across all file pairs: 0.5718685388565063

# %% [markdown]
# ## After Quantization Aware Training
# ---

# %% [markdown]
# ### build model with LME Pool output

# %%
import tensorflow as tf

tflite_model_path = "/home/jovyan/models/checkpoints_/quantization_aware_Conv_depth_dense_INT8.tflite"
interpreter = tf.lite.Interpreter(model_path=tflite_model_path)
interpreter.allocate_tensors()

print('Done Loading Model')
# Out:
# Done Loading Model

# %% [markdown]
# ### Load same files as above and get Activation from Tensor of Dense Layer Input #685

# %%
import tensorflow as tf
import os
import audio

# load audio data
def get_activations_from_file_tflite(file_path, interpreter, tensor_index=685):
    # Load the audio file using the provided function
    input_data, sample_rate = audio.openAudioFile(file_path)

   
    if len(input_data.shape) == 1:  # If data is 1D (audio_length)
        input_data = np.expand_dims(input_data, axis=0)  # Expand to 2D (batch_size, audio_length)
    
    # Setting the input tensor
    input_details = interpreter.get_input_details()[0]
    if input_data.shape != tuple(input_details['shape']):
        raise ValueError(f"Expected input shape {tuple(input_details['shape'])} but got {input_data.shape}")

    input_tensor = interpreter.tensor(input_details["index"])
    input_tensor()[:] = input_data

    # Run inference
    interpreter.invoke()

    # Retrieve activations from the interpreter
    activations = interpreter.get_tensor(tensor_index)
    return activations



# For the target class
folder_path = "/home/jovyan/cut-data/testing/target/"
file_paths = [os.path.join(folder_path, f) for f in os.listdir(folder_path) if f.endswith('.wav')][:5]

activations_list_tflite_target = []
for file_path in file_paths:
    act = get_activations_from_file_tflite(file_path, interpreter)
    activations_list_tflite_target.append(act)
    print(f"First 3 values for {file_path.split('/')[-1]}: {act[0, :3]}")

# For the non-target class
folder_path_non_target = "/home/jovyan/cut-data/testing/non_target/"
file_paths_non_target = [os.path.join(folder_path_non_target, f) for f in os.listdir(folder_path_non_target) if f.endswith('.wav')][:5]

activations_list_tflite_non_target = []
for file_path in file_paths_non_target:
    act = get_activations_from_file_tflite(file_path, interpreter)
    activations_list_tflite_non_target.append(act)
    print(f"First 3 values for {file_path.split('/')[-1]}: {act[0, :3]}")
# Out:
# First 3 values for 0.970_0093_669234.wav: [0.88671875 0.11328125 0.68937075]
# First 3 values for 0.940_0023_324445651.wav: [0.875     0.125     0.6923874]
# First 3 values for 0.950_0002_556972.wav: [0.8671875 0.1328125 0.7232218]
# First 3 values for 0.920_0035_365517.wav: [0.8671875 0.1328125 0.7139195]
# First 3 values for 0.950_0039_402581791.wav: [0.8671875  0.1328125  0.76275194]
# First 3 values for 0.940_0022_310083.wav: [0.87890625 0.12109375 0.6770806 ]
# First 3 values for 1.000_0002_-MZx1np1Ddc_30.wav: [0.8828125 0.1171875 0.7178284]
# First 3 values for 1.000_0003_-6RN8skIHU4_20.wav: [0.875     0.125     0.6618434]
# First 3 values for 1.000_0003_2RG9rOHHYWY_30.wav: [0.87890625 0.12109375 0.672988  ]
# First 3 values for 0.940_0047_664265.wav: [0.875     0.125     0.7230976]

# %% [markdown]
# ### Calculate a standard deviation between Target file activations

# %%
import numpy as np

# Calculate pairwise standard deviation among target activations
std_dev_target2 = []
for i in range(len(activations_list_tflite_target)):
    for j in range(i+1, len(activations_list_tflite_target)):
        std_dev = np.std(activations_list_tflite_target[i] - activations_list_tflite_target[j])
        std_dev_target2.append(std_dev)
        print(f"Standard deviation between target activation {i} and target activation {j}: {std_dev}")

mean_std_dev_target = np.mean(std_dev_target2)
print(f"Average pairwise standard deviation among target activations: {mean_std_dev_target}")
# Out:
# Standard deviation between target activation 0 and target activation 1: 0.024844534695148468
# Standard deviation between target activation 0 and target activation 2: 0.026832491159439087
# Standard deviation between target activation 0 and target activation 3: 0.02488277293741703
# Standard deviation between target activation 0 and target activation 4: 0.028761539608240128
# Standard deviation between target activation 1 and target activation 2: 0.02715800330042839
# Standard deviation between target activation 1 and target activation 3: 0.023942017927765846
# Standard deviation between target activation 1 and target activation 4: 0.02350475639104843
# Standard deviation between target activation 2 and target activation 3: 0.023991921916604042
# Standard deviation between target activation 2 and target activation 4: 0.02942527085542679
# Standard deviation between target activation 3 and target activation 4: 0.025622345507144928
# Average pairwise standard deviation among target activations: 0.02589656412601471

# %% [markdown]
# ### Calculate a standard deviation between Target and Non-Target file activations

# %%
import numpy as np

# Calculate pairwise standard deviation between corresponding target and non-target activations
std_dev_target_vs_nontarget = []
for i in range(min(len(activations_list_tflite_target), len(activations_list_tflite_non_target))):
    std_dev = np.std(activations_list_tflite_target[i] - activations_list_tflite_non_target[i])
    std_dev_target_vs_nontarget.append(std_dev)
    print(f"Standard deviation between target activation {i+1} and non-target activation {i+1}: {std_dev}")

mean_std_dev_target_vs_nontarget = np.mean(std_dev_target_vs_nontarget)
print(f"Average standard deviation between corresponding target and non-target activations: {mean_std_dev_target_vs_nontarget}")
# Out:
# Standard deviation between target activation 1 and non-target activation 1: 0.024160319939255714
# Standard deviation between target activation 2 and non-target activation 2: 0.026953784748911858
# Standard deviation between target activation 3 and non-target activation 3: 0.03090292029082775
# Standard deviation between target activation 4 and non-target activation 4: 0.026028741151094437
# Standard deviation between target activation 5 and non-target activation 5: 0.02910560928285122
# Average standard deviation between corresponding target and non-target activations: 0.027430275455117226

# %% [markdown]
# # We compare the activations before the Dense Layer with Euclidean distance
# ---

# %% [markdown]
# ## Before Quantization

# %% [markdown]
# ### build model with LME Pool output

# %%
from keras.models import Model

# build model without quantization
activation_model = Model(inputs=baselineModel_activation_softmax.input,
                         outputs=baselineModel_activation_softmax.get_layer('GLOBAL_LME_POOL').output)

print('Done')
# Out:
# Done

# %% [markdown]
# ### Load 100 files each and get Activation from Tensor of Dense Layer Input #685 before quantizaion

# %%
import os
import audio
import numpy as np

# function to load audio data and extract activations
def get_activations_from_file(file_path, model):
    # Load the audio file using the provided function
    input_data, sample_rate = audio.openAudioFile(file_path)
    
    input_data = np.expand_dims(input_data, axis=0)
    if len(input_data.shape) == 2:  # If data is 2D (batch_size, audio_length)
        input_data = np.expand_dims(input_data, axis=-1)  # Expand to 3D (batch_size, audio_length, 1)
    
    # Retrieve activations from the model
    activations = model.predict(input_data)
    return activations

# Load target class activations
folder_path_target = "/home/jovyan/cut-data/testing/target/"
file_paths_target = [os.path.join(folder_path_target, f) for f in os.listdir(folder_path_target) if f.endswith('.wav')][:100]

activations_list_target = []
for idx, file_path in enumerate(file_paths_target):
    act = get_activations_from_file(file_path, activation_model)
    activations_list_target.append(act)
    if idx < 5:
        print(f"Target - First 3 values for {file_path.split('/')[-1]}: {act[0, :3]}")

# Load non-target class activations
folder_path_non_target = "/home/jovyan/cut-data/testing/non_target/"
file_paths_non_target = [os.path.join(folder_path_non_target, f) for f in os.listdir(folder_path_non_target) if f.endswith('.wav')][:100]

activations_list_non_target = []
for idx, file_path in enumerate(file_paths_non_target):
    act = get_activations_from_file(file_path, activation_model)
    activations_list_non_target.append(act)
    if idx < 5:
        print(f"Non-Target - First 3 values for {file_path.split('/')[-1]}: {act[0, :3]}")

print('Done')
# Out:
# 1/1 [==============================] - 0s 47ms/step
# Target - First 3 values for 0.970_0093_669234.wav: [0.8466564  0.46071112 0.806841  ]
# 1/1 [==============================] - 0s 42ms/step
# Target - First 3 values for 0.940_0023_324445651.wav: [1.3941029 0.5681002 0.853912 ]
# 1/1 [==============================] - 0s 50ms/step
# Target - First 3 values for 0.950_0002_556972.wav: [0.4038818  1.1463783  0.55604625]
# 1/1 [==============================] - 0s 48ms/step
# Target - First 3 values for 0.920_0035_365517.wav: [0.9785464 0.7548368 0.4874674]
# 1/1 [==============================] - 0s 46ms/step
# Target - First 3 values for 0.950_0039_402581791.wav: [0.6692315  1.1404216  0.69575584]
# 1/1 [==============================] - 0s 56ms/step
# 1/1 [==============================] - 0s 47ms/step
# 1/1 [==============================] - 0s 49ms/step
# 1/1 [==============================] - 0s 50ms/step
# 1/1 [==============================] - 0s 53ms/step
# 1/1 [==============================] - 0s 57ms/step
# 1/1 [==============================] - 0s 50ms/step
# 1/1 [==============================] - 0s 49ms/step
# 1/1 [==============================] - 0s 49ms/step
# 1/1 [==============================] - 0s 49ms/step
# 1/1 [==============================] - 0s 53ms/step
# 1/1 [==============================] - 0s 50ms/step
# 1/1 [==============================] - 0s 45ms/step
# 1/1 [==============================] - 0s 51ms/step
# 1/1 [==============================] - 0s 50ms/step
# 1/1 [==============================] - 0s 50ms/step
# 1/1 [==============================] - 0s 47ms/step
# 1/1 [==============================] - 0s 48ms/step
# 1/1 [==============================] - 0s 45ms/step
# 1/1 [==============================] - 0s 50ms/step
# 1/1 [==============================] - 0s 50ms/step
# 1/1 [==============================] - 0s 47ms/step
# 1/1 [==============================] - 0s 49ms/step
# 1/1 [==============================] - 0s 52ms/step
# 1/1 [==============================] - 0s 46ms/step
# 1/1 [==============================] - 0s 49ms/step
# 1/1 [==============================] - 0s 48ms/step
# 1/1 [==============================] - 0s 49ms/step
# 1/1 [==============================] - 0s 49ms/step
# 1/1 [==============================] - 0s 49ms/step
# 1/1 [==============================] - 0s 47ms/step
# 1/1 [==============================] - 0s 48ms/step
# 1/1 [==============================] - 0s 48ms/step
# 1/1 [==============================] - 0s 48ms/step
# 1/1 [==============================] - 0s 52ms/step
# 1/1 [==============================] - 0s 50ms/step
# 1/1 [==============================] - 0s 49ms/step
# 1/1 [==============================] - 0s 48ms/step
# 1/1 [==============================] - 0s 49ms/step
# 1/1 [==============================] - 0s 53ms/step
# 1/1 [==============================] - 0s 51ms/step
# 1/1 [==============================] - 0s 49ms/step
# 1/1 [==============================] - 0s 48ms/step
# 1/1 [==============================] - 0s 70ms/step
# 1/1 [==============================] - 0s 53ms/step
# 1/1 [==============================] - 0s 84ms/step
# 1/1 [==============================] - 0s 54ms/step
# 1/1 [==============================] - 0s 52ms/step
# 1/1 [==============================] - 0s 49ms/step
# 1/1 [==============================] - 0s 54ms/step
# 1/1 [==============================] - 0s 49ms/step
# 1/1 [==============================] - 0s 48ms/step
# 1/1 [==============================] - 0s 50ms/step
# 1/1 [==============================] - 0s 51ms/step
# 1/1 [==============================] - 0s 54ms/step
# 1/1 [==============================] - 0s 51ms/step
# 1/1 [==============================] - 0s 55ms/step
# 1/1 [==============================] - 0s 49ms/step
# 1/1 [==============================] - 0s 47ms/step
# 1/1 [==============================] - 0s 48ms/step
# 1/1 [==============================] - 0s 46ms/step
# 1/1 [==============================] - 0s 47ms/step
# 1/1 [==============================] - 0s 48ms/step
# 1/1 [==============================] - 0s 50ms/step
# 1/1 [==============================] - 0s 47ms/step
# 1/1 [==============================] - 0s 47ms/step
# 1/1 [==============================] - 0s 49ms/step
# 1/1 [==============================] - 0s 50ms/step
# 1/1 [==============================] - 0s 50ms/step
# 1/1 [==============================] - 0s 55ms/step
# 1/1 [==============================] - 0s 52ms/step
# 1/1 [==============================] - 0s 47ms/step
# 1/1 [==============================] - 0s 52ms/step
# 1/1 [==============================] - 0s 50ms/step
# 1/1 [==============================] - 0s 48ms/step
# 1/1 [==============================] - 0s 48ms/step
# 1/1 [==============================] - 0s 50ms/step
# 1/1 [==============================] - 0s 48ms/step
# 1/1 [==============================] - 0s 49ms/step
# 1/1 [==============================] - 0s 51ms/step
# 1/1 [==============================] - 0s 50ms/step
# 1/1 [==============================] - 0s 47ms/step
# 1/1 [==============================] - 0s 46ms/step
# 1/1 [==============================] - 0s 51ms/step
# 1/1 [==============================] - 0s 48ms/step
# 1/1 [==============================] - 0s 47ms/step
# 1/1 [==============================] - 0s 50ms/step
# 1/1 [==============================] - 0s 48ms/step
# 1/1 [==============================] - 0s 47ms/step
# 1/1 [==============================] - 0s 52ms/step
# 1/1 [==============================] - 0s 49ms/step
# 1/1 [==============================] - 0s 48ms/step
# 1/1 [==============================] - 0s 47ms/step
# 1/1 [==============================] - 0s 46ms/step
# 1/1 [==============================] - 0s 48ms/step
# 1/1 [==============================] - 0s 48ms/step
# Non-Target - First 3 values for 0.940_0022_310083.wav: [0.91503197 0.0353909  0.9679333 ]
# 1/1 [==============================] - 0s 46ms/step
# Non-Target - First 3 values for 1.000_0002_-MZx1np1Ddc_30.wav: [0.7869046  0.65177023 0.6756823 ]
# 1/1 [==============================] - 0s 49ms/step
# Non-Target - First 3 values for 1.000_0003_-6RN8skIHU4_20.wav: [0.7139114 1.0290542 0.2103306]
# 1/1 [==============================] - 0s 48ms/step
# Non-Target - First 3 values for 1.000_0003_2RG9rOHHYWY_30.wav: [0.02469289 0.17907098 1.14387   ]
# 1/1 [==============================] - 0s 47ms/step
# Non-Target - First 3 values for 0.940_0047_664265.wav: [0.16580918 0.5723457  0.45046932]
# 1/1 [==============================] - 0s 50ms/step
# 1/1 [==============================] - 0s 47ms/step
# 1/1 [==============================] - 0s 51ms/step
# 1/1 [==============================] - 0s 53ms/step
# 1/1 [==============================] - 0s 48ms/step
# 1/1 [==============================] - 0s 47ms/step
# 1/1 [==============================] - 0s 49ms/step
# 1/1 [==============================] - 0s 47ms/step
# 1/1 [==============================] - 0s 46ms/step
# 1/1 [==============================] - 0s 50ms/step
# 1/1 [==============================] - 0s 48ms/step
# 1/1 [==============================] - 0s 52ms/step
# 1/1 [==============================] - 0s 51ms/step
# 1/1 [==============================] - 0s 48ms/step
# 1/1 [==============================] - 0s 46ms/step
# 1/1 [==============================] - 0s 53ms/step
# 1/1 [==============================] - 0s 47ms/step
# 1/1 [==============================] - 0s 46ms/step
# 1/1 [==============================] - 0s 47ms/step
# 1/1 [==============================] - 0s 45ms/step
# 1/1 [==============================] - 0s 51ms/step
# 1/1 [==============================] - 0s 50ms/step
# 1/1 [==============================] - 0s 46ms/step
# 1/1 [==============================] - 0s 50ms/step
# 1/1 [==============================] - 0s 49ms/step
# 1/1 [==============================] - 0s 47ms/step
# 1/1 [==============================] - 0s 48ms/step
# 1/1 [==============================] - 0s 53ms/step
# 1/1 [==============================] - 0s 50ms/step
# 1/1 [==============================] - 0s 51ms/step
# 1/1 [==============================] - 0s 48ms/step
# 1/1 [==============================] - 0s 50ms/step
# 1/1 [==============================] - 0s 47ms/step
# 1/1 [==============================] - 0s 48ms/step
# 1/1 [==============================] - 0s 47ms/step
# 1/1 [==============================] - 0s 50ms/step
# 1/1 [==============================] - 0s 48ms/step
# 1/1 [==============================] - 0s 47ms/step
# 1/1 [==============================] - 0s 49ms/step
# 1/1 [==============================] - 0s 48ms/step
# 1/1 [==============================] - 0s 47ms/step
# 1/1 [==============================] - 0s 49ms/step
# 1/1 [==============================] - 0s 48ms/step
# 1/1 [==============================] - 0s 47ms/step
# 1/1 [==============================] - 0s 49ms/step
# 1/1 [==============================] - 0s 52ms/step
# 1/1 [==============================] - 0s 49ms/step
# 1/1 [==============================] - 0s 49ms/step
# 1/1 [==============================] - 0s 48ms/step
# 1/1 [==============================] - 0s 48ms/step
# 1/1 [==============================] - 0s 49ms/step
# 1/1 [==============================] - 0s 47ms/step
# 1/1 [==============================] - 0s 47ms/step
# 1/1 [==============================] - 0s 51ms/step
# 1/1 [==============================] - 0s 46ms/step
# 1/1 [==============================] - 0s 47ms/step
# 1/1 [==============================] - 0s 50ms/step
# 1/1 [==============================] - 0s 44ms/step
# 1/1 [==============================] - 0s 50ms/step
# 1/1 [==============================] - 0s 48ms/step
# 1/1 [==============================] - 0s 48ms/step
# 1/1 [==============================] - 0s 47ms/step
# 1/1 [==============================] - 0s 45ms/step
# 1/1 [==============================] - 0s 47ms/step
# 1/1 [==============================] - 0s 45ms/step
# 1/1 [==============================] - 0s 50ms/step
# 1/1 [==============================] - 0s 47ms/step
# 1/1 [==============================] - 0s 49ms/step
# 1/1 [==============================] - 0s 51ms/step
# 1/1 [==============================] - 0s 49ms/step
# 1/1 [==============================] - 0s 47ms/step
# 1/1 [==============================] - 0s 50ms/step
# 1/1 [==============================] - 0s 47ms/step
# 1/1 [==============================] - 0s 47ms/step
# 1/1 [==============================] - 0s 53ms/step
# 1/1 [==============================] - 0s 50ms/step
# 1/1 [==============================] - 0s 52ms/step
# 1/1 [==============================] - 0s 47ms/step
# 1/1 [==============================] - 0s 51ms/step
# 1/1 [==============================] - 0s 50ms/step
# 1/1 [==============================] - 0s 49ms/step
# 1/1 [==============================] - 0s 46ms/step
# 1/1 [==============================] - 0s 46ms/step
# 1/1 [==============================] - 0s 81ms/step
# 1/1 [==============================] - 0s 50ms/step
# 1/1 [==============================] - 0s 44ms/step
# 1/1 [==============================] - 0s 48ms/step
# 1/1 [==============================] - 0s 48ms/step
# 1/1 [==============================] - 0s 46ms/step
# 1/1 [==============================] - 0s 48ms/step
# 1/1 [==============================] - 0s 47ms/step
# 1/1 [==============================] - 0s 51ms/step
# 1/1 [==============================] - 0s 49ms/step
# 1/1 [==============================] - 0s 47ms/step
# 1/1 [==============================] - 0s 53ms/step
# Done

# %% [markdown]
# ### Calculate Euclidean distance between target file activations

# %%
import numpy as np

# Calculate pairwise Euclidean distance among target activations
euclidean_distances_target = []
for i in range(len(activations_list_target)):
    for j in range(i+1, len(activations_list_target)):
        distance = np.linalg.norm(activations_list_target[i] - activations_list_target[j])
        euclidean_distances_target.append(distance)
        if i < 5 and j < 5:
            print(f"Euclidean distance between target activation {i} and target activation {j}: {distance}")

average_distance_target = np.mean(euclidean_distances_target)
print(f"Average Euclidean distance among target activations: {average_distance_target}")
# Out:
# Euclidean distance between target activation 0 and target activation 1: 8.384279251098633
# Euclidean distance between target activation 0 and target activation 2: 8.395585060119629
# Euclidean distance between target activation 0 and target activation 3: 7.039058685302734
# Euclidean distance between target activation 0 and target activation 4: 7.705931663513184
# Euclidean distance between target activation 1 and target activation 2: 7.2091965675354
# Euclidean distance between target activation 1 and target activation 3: 6.643188953399658
# Euclidean distance between target activation 1 and target activation 4: 6.95264196395874
# Euclidean distance between target activation 2 and target activation 3: 7.647811412811279
# Euclidean distance between target activation 2 and target activation 4: 7.86777925491333
# Euclidean distance between target activation 3 and target activation 4: 6.324751853942871
# Average Euclidean distance among target activations: 8.731480598449707

# %% [markdown]
# ### Calculate  Euclidean distancen between Target and Non-Target file activations

# %%
# Calculate pairwise Euclidean distance between corresponding target and non-target activations
euclidean_distances_target_vs_nontarget = []
for i in range(min(len(activations_list_target), len(activations_list_non_target))):
    distance = np.linalg.norm(activations_list_target[i] - activations_list_non_target[i])
    euclidean_distances_target_vs_nontarget.append(distance)
    if i < 5:
        print(f"Euclidean distance between target activation {i+1} and non-target activation {i+1}: {distance}")

average_distance_target_vs_nontarget = np.mean(euclidean_distances_target_vs_nontarget)
print(f"Average Euclidean distance between corresponding target and non-target activations: {average_distance_target_vs_nontarget}")
# Out:
# Euclidean distance between target activation 1 and non-target activation 1: 12.394902229309082
# Euclidean distance between target activation 2 and non-target activation 2: 12.215434074401855
# Euclidean distance between target activation 3 and non-target activation 3: 11.216044425964355
# Euclidean distance between target activation 4 and non-target activation 4: 12.848539352416992
# Euclidean distance between target activation 5 and non-target activation 5: 10.546712875366211
# Average Euclidean distance between corresponding target and non-target activations: 12.017701148986816

# %% [markdown]
# ## After Quantization Aware Training
# ---

# %% [markdown]
# ### load model after quant

# %%
import tensorflow as tf

# load model after quantization
tflite_model_path = "/home/jovyan/models/checkpoints_/quantization_aware_Conv_depth_dense_INT8.tflite"
interpreter = tf.lite.Interpreter(model_path=tflite_model_path)
interpreter.allocate_tensors()

print('Done Loading Model')

# %% [markdown]
# ### Load 100 files each and get Activation from Tensor of Dense Layer Input #685 after quantizaion

# %%
import tensorflow as tf
import os
import audio
import numpy as np

# load audio data
def get_activations_from_file_tflite(file_path, interpreter, tensor_index=685):
    # Load the audio file using the provided function
    input_data, sample_rate = audio.openAudioFile(file_path)

    if len(input_data.shape) == 1:  # If data is 1D (audio_length)
        input_data = np.expand_dims(input_data, axis=0)  # Expand to 2D (batch_size, audio_length)
    
    # Setting the input tensor
    input_details = interpreter.get_input_details()[0]
    if input_data.shape != tuple(input_details['shape']):
        return None

    input_tensor = interpreter.tensor(input_details["index"])
    input_tensor()[:] = input_data

    # Run inference
    interpreter.invoke()

    # Retrieve activations from the interpreter
    activations = interpreter.get_tensor(tensor_index)
    return activations

NUM_SAMPLES = 100

# For the target class
folder_path = "/home/jovyan/cut-data/testing/target/"
file_paths = [os.path.join(folder_path, f) for f in os.listdir(folder_path) if f.endswith('.wav')][:NUM_SAMPLES]

activations_list_tflite_target = []
skipped_files_target = []
for file_path in file_paths:
    act = get_activations_from_file_tflite(file_path, interpreter)
    if act is None:
        skipped_files_target.append(file_path)
        continue
    activations_list_tflite_target.append(act)
    print(f"First 3 values for {file_path.split('/')[-1]}: {act[0, :3]}")

# For the non-target class
folder_path_non_target = "/home/jovyan/cut-data/testing/non_target/"
file_paths_non_target = [os.path.join(folder_path_non_target, f) for f in os.listdir(folder_path_non_target) if f.endswith('.wav')][:NUM_SAMPLES]

activations_list_tflite_non_target = []
skipped_files_non_target = []
for file_path in file_paths_non_target:
    act = get_activations_from_file_tflite(file_path, interpreter)
    if act is None:
        skipped_files_non_target.append(file_path)
        continue
    activations_list_tflite_non_target.append(act)
    print(f"First 3 values for {file_path.split('/')[-1]}: {act[0, :3]}")

# Print skipped files info
print("\nSkipped files for target class:")
for f in skipped_files_target:
    print(f)
print(f"Total skipped for target: {len(skipped_files_target)}")

print("\nSkipped files for non-target class:")
for f in skipped_files_non_target:
    print(f)
print(f"Total skipped for non-target: {len(skipped_files_non_target)}")
# Out:
# First 3 values for 0.970_0093_669234.wav: [0.88671875 0.11328125 0.68937075]
# First 3 values for 0.940_0023_324445651.wav: [0.875     0.125     0.6923874]
# First 3 values for 0.950_0002_556972.wav: [0.8671875 0.1328125 0.7232218]
# First 3 values for 0.920_0035_365517.wav: [0.8671875 0.1328125 0.7139195]
# First 3 values for 0.950_0039_402581791.wav: [0.8671875  0.1328125  0.76275194]
# First 3 values for 0.950_0070_R21_2022_02_25_08_01_06.wav: [0.87890625 0.12109375 0.7392428 ]
# First 3 values for 0.920_0021_R21_2022_02_22_07_34_44.wav: [0.87890625 0.12109375 0.7565424 ]
# First 3 values for 0.930_0042_696775.wav: [0.8671875  0.1328125  0.73879147]
# First 3 values for 0.950_0008_384110291.wav: [0.87890625 0.12109375 0.72337085]
# First 3 values for 0.920_0005_R21_2022_02_23_09_26_54.wav: [0.8671875 0.1328125 0.6661207]
# First 3 values for 0.920_0024_206237.wav: [0.875      0.125      0.68415815]
# First 3 values for 0.920_0119_R21_2022_02_25_08_07_04.wav: [0.86328125 0.13671875 0.7650075 ]
# First 3 values for 0.930_0171_366916.wav: [0.87890625 0.12109375 0.7117106 ]
# First 3 values for 0.930_0060_529781.wav: [0.875     0.125     0.7096862]
# First 3 values for 0.950_0065_306109.wav: [0.8671875 0.1328125 0.7029295]
# First 3 values for 0.940_0076_555571531.wav: [0.875     0.125     0.7263167]
# First 3 values for 0.940_0039_27576.wav: [0.85546875 0.14453125 0.6781295 ]
# First 3 values for 0.940_0053_86288.wav: [0.8671875 0.1328125 0.6953783]
# First 3 values for 0.970_0038_27576.wav: [0.87890625 0.12109375 0.67902124]
# First 3 values for 0.920_0010_134074.wav: [0.875      0.125      0.67298144]
# First 3 values for 0.940_0001_200626_1731_2.wav: [0.8828125  0.1171875  0.68232524]
# First 3 values for 0.950_0023_471815.wav: [0.87890625 0.12109375 0.7518933 ]
# First 3 values for 0.930_0092_669234.wav: [0.87890625 0.12109375 0.70086086]
# First 3 values for 0.950_0010_676693.wav: [0.8671875  0.1328125  0.73577285]
# First 3 values for 0.940_0009_784426.wav: [0.86328125 0.13671875 0.6899046 ]
# First 3 values for 0.930_0018_451126651.wav: [0.8671875 0.1328125 0.7117895]
# First 3 values for 0.940_0013_695697.wav: [0.8671875  0.1328125  0.74915475]
# First 3 values for 0.950_0009_549369731.wav: [0.86328125 0.13671875 0.733343  ]
# First 3 values for 0.960_0043_384110291.wav: [0.8671875  0.1328125  0.68277925]
# First 3 values for 0.940_0047_365517.wav: [0.8671875 0.1328125 0.7517606]
# First 3 values for 0.930_0206_R21_2022_02_22_08_10_47.wav: [0.87890625 0.12109375 0.7125298 ]
# First 3 values for 0.970_0071_669234.wav: [0.875     0.125     0.7399534]
# First 3 values for 0.960_0064_R21_2022_02_26_08_25_32.wav: [0.875      0.125      0.66357386]
# First 3 values for 0.920_0282_R21_2022_02_25_08_07_04.wav: [0.875      0.125      0.68165433]
# First 3 values for 0.960_0073_R21_2022_02_26_08_25_32.wav: [0.8671875 0.1328125 0.7032448]
# First 3 values for 0.930_0283_R21_2022_02_25_08_07_04.wav: [0.87890625 0.12109375 0.7110987 ]
# First 3 values for 0.960_0084_R21_2022_02_27_07_09_30.wav: [0.88671875 0.11328125 0.6337645 ]
# First 3 values for 0.920_0007_384110291.wav: [0.8671875  0.1328125  0.78044903]
# First 3 values for 0.950_0197_R21_2022_02_23_07_59_47.wav: [0.875      0.125      0.70143855]
# First 3 values for 0.960_0016_419564251.wav: [0.87890625 0.12109375 0.68398225]
# First 3 values for 0.940_0002_420358.wav: [0.87890625 0.12109375 0.6567307 ]
# First 3 values for 0.970_0212_R21_2022_02_23_07_59_47.wav: [0.8671875 0.1328125 0.7083597]
# First 3 values for 0.960_0008_156747.wav: [0.8671875 0.1328125 0.6861709]
# First 3 values for 0.920_0026_245689.wav: [0.87890625 0.12109375 0.75237894]
# First 3 values for 0.950_0171_R21_2022_02_23_07_59_47.wav: [0.8828125 0.1171875 0.7865944]
# First 3 values for 0.950_0079_555571531.wav: [0.86328125 0.13671875 0.7531572 ]
# First 3 values for 0.920_0123_127306.wav: [0.8828125  0.1171875  0.65633476]
# First 3 values for 0.930_0011_695697.wav: [0.875     0.125     0.6568564]
# First 3 values for 0.960_0010_436601051.wav: [0.8671875 0.1328125 0.7143809]
# First 3 values for 0.970_0002_312888.wav: [0.875     0.125     0.7342397]
# First 3 values for 0.930_0113_555571531.wav: [0.875     0.125     0.7293854]
# First 3 values for 0.950_0040_402581791.wav: [0.86328125 0.13671875 0.7029124 ]
# First 3 values for 0.940_0032_420358.wav: [0.87890625 0.12109375 0.7315521 ]
# First 3 values for 0.930_0139_R21_2022_02_25_08_22_06.wav: [0.875      0.125      0.75642097]
# First 3 values for 0.970_0016_436601051.wav: [0.8671875 0.1328125 0.692155 ]
# First 3 values for 0.980_0028_384110291.wav: [0.8671875  0.1328125  0.70569336]
# First 3 values for 0.930_0060_R21_2022_02_23_07_59_47.wav: [0.8671875 0.1328125 0.7053244]
# First 3 values for 0.920_0051_148498.wav: [0.87890625 0.12109375 0.6839826 ]
# First 3 values for 0.970_0062_R21_2022_02_26_08_25_32.wav: [0.875     0.125     0.7337208]
# First 3 values for 0.950_0152_R21_2022_02_23_07_59_47.wav: [0.87890625 0.12109375 0.7055186 ]
# First 3 values for 0.960_0019_368033.wav: [0.875    0.125    0.701156]
# First 3 values for 0.960_0024_156747.wav: [0.8671875 0.1328125 0.750924 ]
# First 3 values for 0.970_0011_556987.wav: [0.875     0.125     0.7299898]
# First 3 values for 0.930_0085_307770.wav: [0.8671875 0.1328125 0.7083725]
# First 3 values for 0.920_0035_402581791.wav: [0.8828125 0.1171875 0.7027855]
# First 3 values for 0.920_0042_R21_2022_02_22_09_01_51.wav: [0.875     0.125     0.7046396]
# First 3 values for 0.970_0149_R21_2022_02_23_07_59_47.wav: [0.88671875 0.11328125 0.7277875 ]
# First 3 values for 0.960_0196_R21_2022_02_23_07_59_47.wav: [0.86328125 0.13671875 0.68867254]
# First 3 values for 0.940_0066_307769.wav: [0.875     0.125     0.6779629]
# First 3 values for 0.960_0076_R21_2022_02_23_08_14_49.wav: [0.8671875 0.1328125 0.6666124]
# First 3 values for 0.980_0173_R21_2022_02_23_07_59_47.wav: [0.875     0.125     0.6872058]
# First 3 values for 0.920_0047_206237.wav: [0.875    0.125    0.715584]
# First 3 values for 0.920_0050_471935.wav: [0.8671875 0.1328125 0.6586461]
# First 3 values for 0.930_0017_R21_2022_02_25_08_01_06.wav: [0.8671875 0.1328125 0.7354086]
# First 3 values for 0.980_0065_R21_2022_02_23_07_59_47.wav: [0.87890625 0.12109375 0.6920567 ]
# First 3 values for 0.930_0003_R21_2022_02_23_08_14_49.wav: [0.8828125  0.1171875  0.73513395]
# First 3 values for 0.920_0053_517125591.wav: [0.875      0.125      0.64673126]
# First 3 values for 0.980_0011_436601051.wav: [0.87890625 0.12109375 0.69685173]
# First 3 values for 0.940_0003_471574.wav: [0.875     0.125     0.6725749]
# First 3 values for 0.950_0018_436601051.wav: [0.875     0.125     0.7583744]
# First 3 values for 0.940_0052_784936.wav: [0.875      0.125      0.66568774]
# First 3 values for 0.930_0011_556979.wav: [0.86328125 0.13671875 0.79882526]
# First 3 values for 0.960_0018_558294.wav: [0.86328125 0.13671875 0.7182908 ]
# First 3 values for 0.940_0033_558294.wav: [0.8671875 0.1328125 0.6790376]
# First 3 values for 0.930_0174_R21_2022_02_23_07_59_47.wav: [0.8671875 0.1328125 0.7384063]
# First 3 values for 0.930_0024_R21_2022_02_22_08_10_47.wav: [0.875      0.125      0.71534777]
# First 3 values for 0.950_0061_R21_2022_02_26_08_25_32.wav: [0.87890625 0.12109375 0.6834977 ]
# First 3 values for 0.930_0059_529781.wav: [0.8671875 0.1328125 0.7575344]
# First 3 values for 0.960_0172_R21_2022_02_25_08_07_04.wav: [0.87890625 0.12109375 0.72367597]
# First 3 values for 0.980_0150_R21_2022_02_23_07_59_47.wav: [0.8671875 0.1328125 0.6510407]
# First 3 values for 0.950_0064_736736.wav: [0.87890625 0.12109375 0.668243  ]
# First 3 values for 0.940_0031_715777.wav: [0.875     0.125     0.6905722]
# First 3 values for 0.960_0066_R21_2022_02_23_07_59_47.wav: [0.8671875 0.1328125 0.7300427]
# First 3 values for 0.920_0207_R21_2022_02_22_08_10_47.wav: [0.8828125 0.1171875 0.7350302]
# First 3 values for 0.950_0026_556972.wav: [0.875     0.125     0.7443242]
# First 3 values for 0.960_0071_R21_2022_02_23_08_14_49.wav: [0.87890625 0.12109375 0.72438556]
# First 3 values for 0.940_0022_310083.wav: [0.87890625 0.12109375 0.6770806 ]
# First 3 values for 1.000_0002_-MZx1np1Ddc_30.wav: [0.8828125 0.1171875 0.7178284]
# First 3 values for 1.000_0003_-6RN8skIHU4_20.wav: [0.875     0.125     0.6618434]
# First 3 values for 1.000_0003_2RG9rOHHYWY_30.wav: [0.87890625 0.12109375 0.672988  ]
# First 3 values for 0.940_0047_664265.wav: [0.875     0.125     0.7230976]
# First 3 values for 1.000_0001_2ZfwEg4JaiU_0.wav: [0.875     0.125     0.7579151]
# First 3 values for 0.930_0006_304198.wav: [0.86328125 0.13671875 0.73759186]
# First 3 values for 1.000_0002_0_hH79HnEdo_30.wav: [0.875     0.125     0.6407032]
# First 3 values for 0.940_0017_560152.wav: [0.875      0.125      0.65690595]
# First 3 values for 1.000_0001_2FGfxOMZoK4_100.wav: [0.87890625 0.12109375 0.7034178 ]
# First 3 values for 0.920_0041_207264171.wav: [0.87890625 0.12109375 0.68726724]
# First 3 values for 1.000_0003_0Rqmp6q4wFk_30.wav: [0.87890625 0.12109375 0.7052319 ]
# First 3 values for 1.000_0001_-3HYdaJyF4U_30.wav: [0.8828125 0.1171875 0.6146511]
# First 3 values for 0.920_0021_633267.wav: [0.875     0.125     0.7411711]
# First 3 values for 1.000_0003_04JKX_vlePE_90.wav: [0.87890625 0.12109375 0.6597058 ]
# First 3 values for 0.940_0004_356707351.wav: [0.8671875 0.1328125 0.7376735]
# First 3 values for 1.000_0001_7JE2eBK1f9M_110.wav: [0.8671875  0.1328125  0.66876024]
# First 3 values for 0.950_0038_103739801.wav: [0.87890625 0.12109375 0.7186619 ]
# First 3 values for 1.000_0001_-RZ01HFrafg_6.wav: [0.88671875 0.11328125 0.7063416 ]
# First 3 values for 0.950_0024_727214.wav: [0.87890625 0.12109375 0.68926597]
# First 3 values for 0.930_0021_282279391.wav: [0.875      0.125      0.67532724]
# First 3 values for 1.000_0002_29KLLDM-b3s_30.wav: [0.86328125 0.13671875 0.6986487 ]
# First 3 values for 0.920_0014_505800201.wav: [0.87890625 0.12109375 0.6707653 ]
# First 3 values for 0.920_0047_282324.wav: [0.875    0.125    0.627164]
# First 3 values for 1.000_0001_-o0ZtQIkM60_30.wav: [0.87890625 0.12109375 0.75457406]
# First 3 values for 1.000_0001_5-aS_pyXesM_20.wav: [0.8828125 0.1171875 0.70969  ]
# First 3 values for 1.000_0002_-iOW_HtK5iM_110.wav: [0.8828125  0.1171875  0.69390905]
# First 3 values for 0.930_0008_718263.wav: [0.8671875 0.1328125 0.6545849]
# First 3 values for 1.000_0001_-t_n44IaDBw_0.wav: [0.8671875  0.1328125  0.73705184]
# First 3 values for 1.000_0002_2-dg-PYfz2U_110.wav: [0.875      0.125      0.66441894]
# First 3 values for 1.000_0003_56_1qrWVNIw_430.wav: [0.87890625 0.12109375 0.7018938 ]
# First 3 values for 0.920_0005_309226.wav: [0.875      0.125      0.69653535]
# First 3 values for 1.000_0001_-450EsuQYao_110.wav: [0.875     0.125     0.7152917]
# First 3 values for 0.950_0024_457390981.wav: [0.86328125 0.13671875 0.6186589 ]
# First 3 values for 0.930_0003_309708.wav: [0.87890625 0.12109375 0.72425324]
# First 3 values for 0.960_0006_727214.wav: [0.86328125 0.13671875 0.7110874 ]
# First 3 values for 1.000_0001_0ADP-O_V3vA_30.wav: [0.87890625 0.12109375 0.7024881 ]
# First 3 values for 0.950_0027_297732.wav: [0.875     0.125     0.7200935]
# First 3 values for 1.000_0003_39MksqVeLdY_390.wav: [0.87890625 0.12109375 0.7434498 ]
# First 3 values for 0.950_0007_306355621.wav: [0.86328125 0.13671875 0.68757313]
# First 3 values for 0.950_0055_555156.wav: [0.8671875 0.1328125 0.6899646]
# First 3 values for 1.000_0003_-J2WJaG1Dd4_30.wav: [0.87890625 0.12109375 0.6780417 ]
# First 3 values for 1.000_0002_-CxGRjAwd3I_30.wav: [0.86328125 0.13671875 0.7250892 ]
# First 3 values for 0.960_0007_493460971.wav: [0.87890625 0.12109375 0.68008447]
# First 3 values for 0.920_0002_305397.wav: [0.8671875 0.1328125 0.7412395]
# First 3 values for 1.000_0002_-z0q4AgXQwo_30.wav: [0.8828125 0.1171875 0.7192509]
# First 3 values for 0.920_0009_785215.wav: [0.87890625 0.12109375 0.7022804 ]
# First 3 values for 0.940_0002_321405.wav: [0.875     0.125     0.7191309]
# First 3 values for 0.940_0021_637104.wav: [0.8671875 0.1328125 0.74547  ]
# First 3 values for 1.000_0002_49XGcP0ztSE_30.wav: [0.8828125 0.1171875 0.663002 ]
# First 3 values for 0.930_0025_103739801.wav: [0.85546875 0.14453125 0.693854  ]
# First 3 values for 0.930_0037_97454371.wav: [0.87890625 0.12109375 0.75489974]
# First 3 values for 0.940_0018_722476.wav: [0.875      0.125      0.77440053]
# First 3 values for 0.940_0034_451859491.wav: [0.8671875  0.1328125  0.78073514]
# First 3 values for 1.000_0001_2Mnl9foj-Ok_30.wav: [0.87890625 0.12109375 0.69453186]
# First 3 values for 0.950_0038_734587.wav: [0.86328125 0.13671875 0.6883805 ]
# First 3 values for 0.940_0027_451859491.wav: [0.875     0.125     0.7236382]
# First 3 values for 0.930_0060_140045.wav: [0.8671875 0.1328125 0.7118336]
# First 3 values for 0.920_0025_207218.wav: [0.87890625 0.12109375 0.72623724]
# First 3 values for 0.930_0014_184847.wav: [0.87890625 0.12109375 0.667398  ]
# First 3 values for 1.000_0001_0DSVOjk2NfA_30.wav: [0.87890625 0.12109375 0.6929039 ]
# First 3 values for 0.960_0010_207218.wav: [0.8671875  0.1328125  0.70566905]
# First 3 values for 1.000_0002_-q1pzc3VMrg_60.wav: [0.8671875 0.1328125 0.7208599]
# First 3 values for 0.930_0028_457390981.wav: [0.875     0.125     0.6901485]
# First 3 values for 1.000_0003_-m5ZlWziIeA_200.wav: [0.875     0.125     0.7062323]
# First 3 values for 0.950_0003_6F3YIb0Uw4I_30.wav: [0.87890625 0.12109375 0.70345914]
# First 3 values for 0.930_0005_306355621.wav: [0.875      0.125      0.70415914]
# First 3 values for 0.960_0003_592110.wav: [0.8828125 0.1171875 0.6830863]
# First 3 values for 1.000_0002_7W08vmriHkA_30.wav: [0.8828125 0.1171875 0.6591402]
# First 3 values for 1.000_0003_-CnsvTDIXdE_20.wav: [0.88671875 0.11328125 0.6631113 ]
# First 3 values for 1.000_0003_0hdanhk-EdE_50.wav: [0.88671875 0.11328125 0.6750018 ]
# First 3 values for 0.920_0019_352118591.wav: [0.875    0.125    0.667536]
# First 3 values for 0.930_0009_137959861.wav: [0.87890625 0.12109375 0.72881305]
# First 3 values for 1.000_0003_11nYg-lGu3g_30.wav: [0.87890625 0.12109375 0.6579205 ]
# First 3 values for 1.000_0003_06IU9WsEp3s_130.wav: [0.87890625 0.12109375 0.6716242 ]
# First 3 values for 0.930_0039_216120301.wav: [0.87890625 0.12109375 0.7195558 ]
# First 3 values for 0.970_0021_310083.wav: [0.875      0.125      0.75563157]
# First 3 values for 1.000_0002_-DWgE5OnEVY_150.wav: [0.87890625 0.12109375 0.61893046]
# First 3 values for 1.000_0002_1qABIRAKQoM_10.wav: [0.875     0.125     0.7249142]
# First 3 values for 1.000_0002_-oSw8wNpLcY_60.wav: [0.8828125  0.1171875  0.70818937]
# First 3 values for 1.000_0002_-mA_bqD1tgU_30.wav: [0.87890625 0.12109375 0.69265735]
# First 3 values for 0.930_0016_782604.wav: [0.87890625 0.12109375 0.65920275]
# First 3 values for 1.000_0003_2MIXPd5lbc4_10.wav: [0.8828125 0.1171875 0.6652374]
# First 3 values for 0.930_0017_427405661.wav: [0.8671875 0.1328125 0.7324195]
# First 3 values for 0.950_0002_385854.wav: [0.8828125  0.1171875  0.71035284]
# First 3 values for 1.000_0002_6Wamq3ehaAU_30.wav: [0.87890625 0.12109375 0.733214  ]
# First 3 values for 0.960_0130_310083.wav: [0.875     0.125     0.6880748]
# First 3 values for 1.000_0002_-b_10b-orX4_50.wav: [0.875      0.125      0.67634714]
# First 3 values for 1.000_0001_15htpcg-ii4_230.wav: [0.87890625 0.12109375 0.7176259 ]
# First 3 values for 0.930_0009_37544.wav: [0.8671875 0.1328125 0.6809355]
# First 3 values for 1.000_0001_7bjeYrzsTk4_30.wav: [0.87890625 0.12109375 0.67588353]
# First 3 values for 0.960_0004_595388.wav: [0.875     0.125     0.6895822]
# First 3 values for 0.950_0036_578425.wav: [0.875     0.125     0.7113077]
# First 3 values for 0.960_0037_207264171.wav: [0.8671875 0.1328125 0.6674294]
# First 3 values for 0.930_0011_121693.wav: [0.86328125 0.13671875 0.6762784 ]
# First 3 values for 1.000_0002_1C6VhOCffIE_60.wav: [0.87890625 0.12109375 0.68841004]
# First 3 values for 0.960_0005_703671.wav: [0.8671875  0.1328125  0.69299984]
# First 3 values for 1.000_0003_1tt5hIKEBYo_21.wav: [0.875      0.125      0.72427726]
#
# Skipped files for target class:
# /home/jovyan/cut-data/testing/target/0.840_0001_200615_1527_13.wav
# /home/jovyan/cut-data/testing/target/0.540_0001_200624_1647_11.wav
# /home/jovyan/cut-data/testing/target/0.750_0001_200615_1520_17.wav
# /home/jovyan/cut-data/testing/target/0.800_0001_200615_1572_4.wav
# Total skipped for target: 4
#
# Skipped files for non-target class:
# /home/jovyan/cut-data/testing/non_target/1.000_0003_3JPyYTmVc0U_0.wav
# /home/jovyan/cut-data/testing/non_target/1.000_0002_2dsY_AHDFc8_0.wav
# Total skipped for non-target: 2

# %% [markdown]
# ### Calculate Euclidean distance between target file activations

# %%
import numpy as np

# Calculate pairwise Euclidean distance among target activations
euclidean_distances_target = []
for i in range(len(activations_list_tflite_target)):
    for j in range(i+1, len(activations_list_tflite_target)):
        distance = np.linalg.norm(activations_list_tflite_target[i] - activations_list_tflite_target[j])
        euclidean_distances_target.append(distance)
        if i < 5 and j < 5:
            print(f"Euclidean distance between target activation {i} and target activation {j}: {distance}")

average_distance_target = np.mean(euclidean_distances_target)
print(f"Average Euclidean distance among target activations: {average_distance_target}")
# Out:
# Euclidean distance between target activation 0 and target activation 1: 0.5123829245567322
# Euclidean distance between target activation 0 and target activation 2: 0.5508667230606079
# Euclidean distance between target activation 0 and target activation 3: 0.5104351043701172
# Euclidean distance between target activation 0 and target activation 4: 0.5895726680755615
# Euclidean distance between target activation 1 and target activation 2: 0.5571251511573792
# Euclidean distance between target activation 1 and target activation 3: 0.49191248416900635
# Euclidean distance between target activation 1 and target activation 4: 0.48677122592926025
# Euclidean distance between target activation 2 and target activation 3: 0.49179428815841675
# Euclidean distance between target activation 2 and target activation 4: 0.6047350764274597
# Euclidean distance between target activation 3 and target activation 4: 0.5262699723243713
# Average Euclidean distance among target activations: 0.5544940233230591

# %% [markdown]
# ### Calculate  Euclidean distancen between Target and Non-Target file activations

# %%
# Calculate pairwise Euclidean distance between corresponding target and non-target activations
euclidean_distances_target_vs_nontarget = []
for i in range(min(len(activations_list_tflite_target), len(activations_list_tflite_non_target))):
    distance = np.linalg.norm(activations_list_tflite_target[i] - activations_list_tflite_non_target[i])
    euclidean_distances_target_vs_nontarget.append(distance)
    if i < 5:
        print(f"Euclidean distance between target activation {i+1} and non-target activation {i+1}: {distance}")

average_distance_target_vs_nontarget = np.mean(euclidean_distances_target_vs_nontarget)
print(f"Average Euclidean distance between corresponding target and non-target activations: {average_distance_target_vs_nontarget}")
# Out:
# Euclidean distance between target activation 1 and non-target activation 1: 0.49566850066185
# Euclidean distance between target activation 2 and non-target activation 2: 0.5534607172012329
# Euclidean distance between target activation 3 and non-target activation 3: 0.6348714232444763
# Euclidean distance between target activation 4 and non-target activation 4: 0.5358163118362427
# Euclidean distance between target activation 5 and non-target activation 5: 0.5988997220993042
# Average Euclidean distance between corresponding target and non-target activations: 0.5784992575645447
